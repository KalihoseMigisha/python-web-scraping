# %% [markdown]
# <a href="https://colab.research.google.com/github/KalihoseMigisha/python-web-scraping/blob/main/notebooks/Python_Web_Scraping_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1 Problem Statement
# - In today's data-driven world, extracting relevant information from websites is essential for research, business intelligence, and decision-making. However, manually collecting and organizing web data is time-consuming and inefficient. This project aims to develop a Python-based web scraping solution from scratch, specifically for static web pages, using BeautifulSoup. While tools like Selenium and Scrapy excel at scraping dynamic websites, BeautifulSoup is ideal for efficiently parsing and extracting data from static HTML content. The project will provide a structured approach to automated data extraction, processing, and storage while adhering to ethical and legal considerations.

# %% [markdown]
# #2 Mount Google Drive (Connection)

# %%
# Mount Google Drive in Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Here are the steps We'll follow:**
#
# - We're going to scrape https://github.com/topics
# - We'll get a list of topics.
# - For each topic, we'll get topic title, topic page URL and topic description
# - For each topic, we'll get the top 25 repositories in the topic from the topic page
# - For each repository, we'll grab the **repo name, username, stars and repo URL**
# - For each topic we'll create a CSV file in the following format:**Repo Name,Username,Stars,Repo URL.**
# - Example:
#         - three.js,mrdoob,69700,https://github.com/mrdoob/three.js
# libgdx,libgdx,18300,https://github.com/libgdx/libgdx

# %% [markdown]
# **website link**
#   - https://github.com/topics

# %% [markdown]
# **Beautiful Soup and Requests**

# %%
# Importing BeautifulSoup from the bs4 module to parse HTML and extract data
from bs4 import BeautifulSoup

# Importing the requests library to send HTTP requests and retrieve web page content
import requests

# %%
# URL of the website to be scraped
url = 'https://github.com/topics'

# %%
# Send a GET request to retrieve the content of the specified URL
requests.get(url)
# Out:
# <Response [200]>

# %% [markdown]
# #3 HTTP Responses:
#     # 200 OK: The request was successful, and the server returned the requested page.
#     # 301 Moved Permanently: The resource has been permanently moved to a new URL.
#     # 404 Not Found: The requested page could not be found on the server.
#     # 403 Forbidden: The server refuses to authorize the request.
#     # 500 Internal Server Error: The server encountered an unexpected error.
#     # 502 Bad Gateway: The server was acting as a gateway and received an invalid response.
#     # 503 Service Unavailable: The server is temporarily unavailable (e.g., due to maintenance).

# %%
# fetches and stores the page content (and other response data) from URL
page = requests.get(url)

# %%
# Parsing the HTML content of the fetched page using BeautifulSoup
# 'html.parser' is a built-in parser in Python that helps parse and navigate HTML content
soup = BeautifulSoup(page.text, 'html.parser')

# %%
# Printing the parsed HTML content of the webpage
# This prints raw HTML (not very readable)
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html data-a11y-animated-images="system" data-a11y-link-underlines="true" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/light-74231a1f3bbb.css" media="all" rel="stylesheet"><link crossorigin="anonymous" href="https://github.githubassets.com/assets/dark-8a995f0bacd4.css" media="all" rel="stylesheet"><link crossorigin="anonymous" data-color-theme="dark_dimmed" data-href="https://github.githubassets.com/assets/dark_dimmed-f37fb7684b1f.css" media="all" rel="stylesheet"><link crossorigin="anonymous" data-color-theme="dark_high_contrast" data-href="https://github.githubassets.com/assets/dark_high_contrast-9ac301c3ebe5.css" media="all" rel="stylesheet"><link crossorigin="anonymous" data-color-theme="dark_colorblind" data-href="https://github.githubassets.com/assets/dark_colorblind-cd826e8636dc.css" media="all" rel="stylesheet"><link crossorigin="anonymous" data-color-theme="light_colorblind" data-href="https://github.githubassets.com/assets/light_colorblind-f91b0f603451.css" media="all" rel="stylesheet"><link crossorigin="anonymous" data-color-theme="light_high_contrast" data-href="https://github.githubassets.com/assets/light_high_contrast-83beb16e0ecf.css" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_tritanopia" data-href="https://github.githubassets.com/assets/light_tritanopia-6e122dab64fc.css" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_tritanopia" data-href="https://github.githubassets.com/assets/dark_tritanopia-18119e682df0.css" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/primer-primitives-225433424a87.css" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/primer-aaa714e5674d.css" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/global-0a3c53b9d1c2.css" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/github-ea73c9cb5377.css" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/site-3e72ff5534e0.css" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/explore-742a7653565b.css" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/dashboard-0de2bd46c6d8.css" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/discussions-dae9ae1a46a6.css" media="all" rel="stylesheet"/>
# <script id="client-env" type="application/json">{"locale":"en","featureFlags":["a11y_quote_reply_fix","copilot_immersive_issue_preview","copilot_new_references_ui","copilot_chat_repo_custom_instructions_preview","copilot_no_floating_button","copilot_topics_as_references","copilot_read_shared_conversation","copilot_duplicate_thread","copilot_buffered_streaming","dotcom_chat_client_side_skills","experimentation_azure_variant_endpoint","failbot_handle_non_errors","geojson_azure_maps","ghost_pilot_confidence_truncation_25","ghost_pilot_confidence_truncation_40","github_models_gateway_parse_params","github_models_o3_mini_streaming","insert_before_patch","issues_react_remove_placeholders","issues_react_blur_item_picker_on_close","marketing_pages_search_explore_provider","primer_react_css_modules_ga","react_data_router_pull_requests","remove_child_patch","sample_network_conn_type","swp_enterprise_contact_form","site_proxima_australia_update","viewscreen_sandbox","issues_react_create_milestone","issues_react_cache_fix_workaround","lifecycle_label_name_updates","copilot_task_oriented_assistive_prompts","issue_types_prevent_private_type_creation","refresh_image_video_src","react_router_dispose_on_disconnect","codespaces_prebuild_region_target_update","turbo_app_id_restore","copilot_code_review_sign_up_closed"]}</script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/wp-runtime-900d20148682.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_oddbird_popover-polyfill_dist_popover_js-9da652f58479.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_arianotify-polyfill_ariaNotify-polyfill_js-node_modules_github_mi-3abb8f-46b9f4874d95.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/ui_packages_failbot_failbot_ts-75968cfb5298.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/environment-f04cb2a9fc8c.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_primer_behaviors_dist_esm_index_mjs-0dbb79f97f8f.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_selector-observer_dist_index_esm_js-f690fd9ae3d5.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_relative-time-element_dist_index_js-62d275b7ddd9.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_text-expander-element_dist_index_js-78748950cb0c.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_auto-complete-element_dist_index_js-node_modules_github_catalyst_-8e9f78-a90ac05d2469.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_filter-input-element_dist_index_js-node_modules_github_remote-inp-b5f1d7-a1760ffda83d.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_markdown-toolbar-element_dist_index_js-ceef33f593fa.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_file-attachment-element_dist_index_js-node_modules_primer_view-co-c44a69-efa32db3a345.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/github-elements-394f8eb34f19.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/element-registry-25113a65b77f.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_braintree_browser-detection_dist_browser-detection_js-node_modules_githu-2906d7-2a07a295af40.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_lit-html_lit-html_js-be8cb88f481b.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_mini-throttle_dist_index_js-node_modules_morphdom_dist_morphdom-e-7c534c-a4a1922eb55f.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_turbo_dist_turbo_es2017-esm_js-a03ee12d659a.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_delegated-events_dist_inde-893f9f-b6294cf703b7.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_color-convert_index_js-e3180fe3bcb3.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_quote-selection_dist_index_js-node_modules_github_session-resume_-947061-e7a6c4a19f98.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/ui_packages_updatable-content_updatable-content_ts-eb3147a21e96.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_task-list_ts-app_assets_modules_github_sso_ts-ui_packages-900dde-768abe60b1f8.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/app_assets_modules_github_sticky-scroll-into-view_ts-3e000c5d31a9.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_ajax-error_ts-app_assets_modules_github_behaviors_include-87a4ae-4c160a67a3f8.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_commenting_edit_ts-app_assets_modules_github_behaviors_ht-83c235-e429cff6ceb1.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/behaviors-1f167e0c2aee.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_github_catalyst_lib_index_js-f6223d90c7ba.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/notifications-global-01e85cd1be94.js" type="application/javascript"></script>
# <title>Topics on GitHub · GitHub</title>
# <meta content="/topics(.:format)" data-turbo-transient="" name="route-pattern"/>
# <meta content="topics" data-turbo-transient="" name="route-controller"/>
# <meta content="index" data-turbo-transient="" name="route-action"/>
# <meta content="82c569b93da5c18ed649ebd4c2c79437db4611a6a1373e805a3cb001c64130b7" name="current-catalog-service-hash"/>
# <meta content="E13A:99E34:153637:1B8FB8:67E96907" data-pjax-transient="true" name="request-id"><meta content="a5016707e7ea34d51780c28c782d17df7c1a209ca58eb2497674c1c5963fb396" data-pjax-transient="true" name="html-safe-nonce"><meta content="eyJyZWZlcnJlciI6IiIsInJlcXVlc3RfaWQiOiJFMTNBOjk5RTM0OjE1MzYzNzoxQjhGQjg6NjdFOTY5MDciLCJ2aXNpdG9yX2lkIjoiMjY1NjM0MDkzMzkwNzkzMzQ0NyIsInJlZ2lvbl9lZGdlIjoiaWFkIiwicmVnaW9uX3JlbmRlciI6ImlhZCJ9" data-pjax-transient="true" name="visitor-payload"><meta content="694c276884e03840269f51e950b7e412c20f24f1367e96d8f523b7f1f46dfb5c" data-pjax-transient="true" name="visitor-hmac">
# <meta content="copilot" data-turbo-transient="true" name="github-keyboard-shortcuts">
# <meta data-turbo-transient="" name="selected-link" value="/topics"/>
# <link href="https://github.githubassets.com/" rel="assets"/>
# <meta content="Apib7-x98H0j5cPqHWwSMm6dNU4GmODRoqxLiDzdx9I" name="google-site-verification"/>
# <meta content="https://collector.github.com/github/collect" name="octolytics-url">
# <meta content="" name="user-login"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="GitHub is where people build software. More than 150 million people use GitHub to discover, fork, and contribute to over 420 million projects." name="description"/>
# <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
# <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
# <meta content="1401488693436528" property="fb:app_id"/>
# <meta content="app-id=1477376905, app-argument=https://github.com/topics" name="apple-itunes-app">
# <meta content="https://github.com" property="og:url"/>
# <meta content="GitHub" property="og:site_name"/>
# <meta content="Build software better, together" property="og:title"/>
# <meta content="GitHub is where people build software. More than 150 million people use GitHub to discover, fork, and contribute to over 420 million projects." property="og:description"/>
# <meta content="https://github.githubassets.com/assets/github-logo-55c5b9a1fe52.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="1200" property="og:image:height"/>
# <meta content="https://github.githubassets.com/assets/github-mark-57519b92ca4e.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="https://github.githubassets.com/assets/github-octocat-13c86b8b336d.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="github" property="twitter:site"/>
# <meta content="13334762" property="twitter:site:id"/>
# <meta content="github" property="twitter:creator"/>
# <meta content="13334762" property="twitter:creator:id"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="GitHub" property="twitter:title"/>
# <meta content="GitHub is where people build software. More than 150 million people use GitHub to discover, fork, and contribute to over 420 million projects." property="twitter:description"/>
# <meta content="https://github.githubassets.com/assets/github-logo-55c5b9a1fe52.png" property="twitter:image"/>
# <meta content="1200" property="twitter:image:width"/>
# <meta content="1200" property="twitter:image:height"/>
# <meta content="github.com" name="hostname"/>
# <meta content="github.com" name="expected-hostname"/>
# <meta content="154e3ed6ec9e0d6fff5da6846be55e3cefb81f7aa557cdcfe2a45d929fc158d2" data-turbo-track="reload" http-equiv="x-pjax-version"/>
# <meta content="e26f9f0ba624ee85cc7ac057d8faa8618a4f25a85eab052c33d018ac0f6b1a46" data-turbo-track="reload" http-equiv="x-pjax-csp-version"/>
# <meta content="159e03504eed5183f9787c72780a7d8c1460af30746ab09d728b048c41719efa" data-turbo-track="reload" http-equiv="x-pjax-css-version"/>
# <meta content="3ef84064f1c111becc704df35223db168ecae977ac2d9ec422601ed98490e586" data-turbo-track="reload" http-equiv="x-pjax-js-version"/>
# <meta content="no-preview" data-turbo-transient="" name="turbo-cache-control"/>
# <link data-turbo-transient="" href="https://github.com/topics" rel="canonical"/>
# <meta content="logged-out env-production page-responsive" name="turbo-body-classes"/>
# <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
# <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
# <meta content="a809ed19c131f846b28e5314dd87328a15e02a37" name="release"/>
# <link color="#000000" href="https://github.githubassets.com/assets/pinned-octocat-093da3e6fa40.svg" rel="mask-icon"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.png" rel="alternate icon" type="image/png"/>
# <link class="js-site-favicon" data-base-href="https://github.githubassets.com/favicons/favicon" href="https://github.githubassets.com/favicons/favicon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="#1e2327" name="theme-color"/>
# <meta content="light dark" name="color-scheme">
# <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
# </meta></meta></meta></meta></meta></meta></meta></meta></link></link></link></link></link></link></head>
# <body class="logged-out env-production page-responsive" style="word-wrap: break-word;">
# <div class="logged-out env-production page-responsive" data-turbo-body="" style="word-wrap: break-word;">
# <div class="position-relative header-wrapper js-header-wrapper">
# <a class="px-2 py-4 color-bg-accent-emphasis color-fg-on-emphasis show-on-focus js-skip-to-content" data-skip-target-assigned="false" href="#start-of-content">Skip to content</a>
# <span class="progress-pjax-loader Progress position-fixed width-full" data-view-component="true">
# <span class="Progress-item progress-pjax-loader-bar left-0 top-0 color-bg-accent-emphasis" data-view-component="true" style="width: 0%;"></span>
# </span>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/primer-react-602097a4b0db.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/react-core-0bc17999cb79.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/react-lib-f1bca44e0926.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/octicons-react-cf2f2ab8dab4.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_emotion_is-prop-valid_dist_emotion-is-prop-valid_esm_js-node_modules_emo-62da9f-2df2f32ec596.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_mini-throttle_dist_index_js-node_modules_stacktrace-parser_dist_s-e7dcdd-9a233856b02c.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_oddbird_popover-polyfill_dist_popover-fn_js-55fea94174bf.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/ui_packages_ui-commands_ui-commands_ts-2ea4e93613c0.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/keyboard-shortcuts-dialog-79d6a754ebf9.js" type="application/javascript"></script>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/primer-react.8157a56b30ae88a1b356.module.css" media="all" rel="stylesheet">
# <react-partial data-attempted-ssr="false" data-ssr="false" partial-name="keyboard-shortcuts-dialog">
# <script data-target="react-partial.embeddedData" type="application/json">{"props":{"docsUrl":"https://docs.github.com/get-started/accessibility/keyboard-shortcuts"}}</script>
# <div data-target="react-partial.reactRoot"></div>
# </react-partial>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_delegated-events_dist_inde-94fd67-4898d1bf4b51.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/sessions-730dca81d0a2.js" type="application/javascript"></script>
# <header class="HeaderMktg header-logged-out js-details-container js-header Details f4 py-3" data-color-mode="light" data-dark-theme="dark" data-is-top="true" data-light-theme="light" role="banner">
# <h2 class="sr-only">Navigation Menu</h2>
# <button aria-label="Toggle navigation" class="HeaderMktg-backdrop d-lg-none border-0 position-fixed top-0 left-0 width-full height-full js-details-target" type="button">
# <span class="d-none">Toggle navigation</span>
# </button>
# <div class="d-flex flex-column flex-lg-row flex-items-center px-3 px-md-4 px-lg-5 height-full position-relative z-1">
# <div class="d-flex flex-justify-between flex-items-center width-full width-lg-auto">
# <div class="flex-1">
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target js-nav-padding-recalculate js-header-menu-toggle Button--link Button--medium Button d-lg-none color-fg-inherit p-1" data-view-component="true" type="button"> <span class="Button-content">
# <span class="Button-label"><div class="HeaderMenu-toggle-bar rounded my-1"></div>
# <div class="HeaderMenu-toggle-bar rounded my-1"></div>
# <div class="HeaderMenu-toggle-bar rounded my-1"></div></span>
# </span>
# </button>
# </div>
# <a aria-label="Homepage" class="mr-lg-3 color-fg-inherit flex-order-2 js-prevent-focus-on-mobile-nav" data-analytics-event='{"category":"Marketing nav","action":"click to go to homepage","label":"ref_page:Marketing;ref_cta:Logomark;ref_loc:Header"}' href="/">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="32" version="1.1" viewbox="0 0 24 24" width="32">
# <path d="M12 1C5.9225 1 1 5.9225 1 12C1 16.8675 4.14875 20.9787 8.52125 22.4362C9.07125 22.5325 9.2775 22.2025 9.2775 21.9137C9.2775 21.6525 9.26375 20.7862 9.26375 19.865C6.5 20.3737 5.785 19.1912 5.565 18.5725C5.44125 18.2562 4.905 17.28 4.4375 17.0187C4.0525 16.8125 3.5025 16.3037 4.42375 16.29C5.29 16.2762 5.90875 17.0875 6.115 17.4175C7.105 19.0812 8.68625 18.6137 9.31875 18.325C9.415 17.61 9.70375 17.1287 10.02 16.8537C7.5725 16.5787 5.015 15.63 5.015 11.4225C5.015 10.2262 5.44125 9.23625 6.1425 8.46625C6.0325 8.19125 5.6475 7.06375 6.2525 5.55125C6.2525 5.55125 7.17375 5.2625 9.2775 6.67875C10.1575 6.43125 11.0925 6.3075 12.0275 6.3075C12.9625 6.3075 13.8975 6.43125 14.7775 6.67875C16.8813 5.24875 17.8025 5.55125 17.8025 5.55125C18.4075 7.06375 18.0225 8.19125 17.9125 8.46625C18.6138 9.23625 19.04 10.2125 19.04 11.4225C19.04 15.6437 16.4688 16.5787 14.0213 16.8537C14.42 17.1975 14.7638 17.8575 14.7638 18.8887C14.7638 20.36 14.75 21.5425 14.75 21.9137C14.75 22.2025 14.9563 22.5462 15.5063 22.4362C19.8513 20.9787 23 16.8537 23 12C23 5.9225 18.0775 1 12 1Z"></path>
# </svg>
# </a>
# <div class="flex-1 flex-order-2 text-right">
# <a class="HeaderMenu-link HeaderMenu-button d-inline-flex d-lg-none flex-order-1 f5 no-underline border color-border-default rounded-2 px-2 py-1 color-fg-inherit js-prevent-focus-on-mobile-nav" data-analytics-event='{"category":"Marketing nav","action":"click to Sign in","label":"ref_page:Marketing;ref_cta:Sign in;ref_loc:Header"}' data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header menu","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/topics","user_id":null}}' data-hydro-click-hmac="be24ac4990e8cac9a74ee7032b910f8f38a1cea9154e0dbbe2347ce0b38a6adc" href="/login?return_to=https%3A%2F%2Fgithub.com%2Ftopics">
#             Sign in
#           </a>
# </div>
# </div>
# <div class="HeaderMenu js-header-menu height-fit position-lg-relative d-lg-flex flex-column flex-auto top-0">
# <div class="HeaderMenu-wrapper d-flex flex-column flex-self-start flex-lg-row flex-auto rounded rounded-lg-0">
# <nav aria-label="Global" class="HeaderMenu-nav">
# <ul class="d-lg-flex list-style-none">
# <li class="HeaderMenu-item position-relative flex-wrap flex-justify-between flex-items-center d-block d-lg-flex flex-lg-nowrap flex-lg-items-center js-details-container js-header-menu-item">
# <button aria-expanded="false" class="HeaderMenu-link border-0 width-full width-lg-auto px-0 px-lg-2 py-lg-2 no-wrap d-flex flex-items-center flex-justify-between js-details-target" type="button">
#         Product
#         <svg aria-hidden="true" class="octicon octicon-chevron-down HeaderMenu-icon ml-1" data-view-component="true" height="16" opacity="0.5" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M12.78 5.22a.749.749 0 0 1 0 1.06l-4.25 4.25a.749.749 0 0 1-1.06 0L3.22 6.28a.749.749 0 1 1 1.06-1.06L8 8.939l3.72-3.719a.749.749 0 0 1 1.06 0Z"></path>
# </svg>
# </button>
# <div class="HeaderMenu-dropdown dropdown-menu rounded m-0 p-0 pt-2 pt-lg-4 position-relative position-lg-absolute left-0 left-lg-n3 pb-2 pb-lg-4 d-lg-flex flex-wrap dropdown-menu-wide">
# <div class="HeaderMenu-column px-lg-4 border-lg-right mb-4 mb-lg-0 pr-lg-7">
# <div class="border-bottom pb-3 pb-lg-0 border-lg-bottom-0">
# <ul class="list-style-none f5">
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"github_copilot","context":"product","tag":"link","label":"github_copilot_link_product_navbar"}' href="https://github.com/features/copilot">
# <svg aria-hidden="true" class="octicon octicon-copilot color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M23.922 16.992c-.861 1.495-5.859 5.023-11.922 5.023-6.063 0-11.061-3.528-11.922-5.023A.641.641 0 0 1 0 16.736v-2.869a.841.841 0 0 1 .053-.22c.372-.935 1.347-2.292 2.605-2.656.167-.429.414-1.055.644-1.517a10.195 10.195 0 0 1-.052-1.086c0-1.331.282-2.499 1.132-3.368.397-.406.89-.717 1.474-.952 1.399-1.136 3.392-2.093 6.122-2.093 2.731 0 4.767.957 6.166 2.093.584.235 1.077.546 1.474.952.85.869 1.132 2.037 1.132 3.368 0 .368-.014.733-.052 1.086.23.462.477 1.088.644 1.517 1.258.364 2.233 1.721 2.605 2.656a.832.832 0 0 1 .053.22v2.869a.641.641 0 0 1-.078.256ZM12.172 11h-.344a4.323 4.323 0 0 1-.355.508C10.703 12.455 9.555 13 7.965 13c-1.725 0-2.989-.359-3.782-1.259a2.005 2.005 0 0 1-.085-.104L4 11.741v6.585c1.435.779 4.514 2.179 8 2.179 3.486 0 6.565-1.4 8-2.179v-6.585l-.098-.104s-.033.045-.085.104c-.793.9-2.057 1.259-3.782 1.259-1.59 0-2.738-.545-3.508-1.492a4.323 4.323 0 0 1-.355-.508h-.016.016Zm.641-2.935c.136 1.057.403 1.913.878 2.497.442.544 1.134.938 2.344.938 1.573 0 2.292-.337 2.657-.751.384-.435.558-1.15.558-2.361 0-1.14-.243-1.847-.705-2.319-.477-.488-1.319-.862-2.824-1.025-1.487-.161-2.192.138-2.533.529-.269.307-.437.808-.438 1.578v.021c0 .265.021.562.063.893Zm-1.626 0c.042-.331.063-.628.063-.894v-.02c-.001-.77-.169-1.271-.438-1.578-.341-.391-1.046-.69-2.533-.529-1.505.163-2.347.537-2.824 1.025-.462.472-.705 1.179-.705 2.319 0 1.211.175 1.926.558 2.361.365.414 1.084.751 2.657.751 1.21 0 1.902-.394 2.344-.938.475-.584.742-1.44.878-2.497Z"></path><path d="M14.5 14.25a1 1 0 0 1 1 1v2a1 1 0 0 1-2 0v-2a1 1 0 0 1 1-1Zm-5 0a1 1 0 0 1 1 1v2a1 1 0 0 1-2 0v-2a1 1 0 0 1 1-1Z"></path>
# </svg>
# <div>
# <div class="color-fg-default h4">GitHub Copilot</div>
#         Write better code with AI
#       </div>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"security","context":"product","tag":"link","label":"security_link_product_navbar"}' href="https://github.com/features/security">
# <svg aria-hidden="true" class="octicon octicon-shield-check color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M16.53 9.78a.75.75 0 0 0-1.06-1.06L11 13.19l-1.97-1.97a.75.75 0 0 0-1.06 1.06l2.5 2.5a.75.75 0 0 0 1.06 0l5-5Z"></path><path d="m12.54.637 8.25 2.675A1.75 1.75 0 0 1 22 4.976V10c0 6.19-3.771 10.704-9.401 12.83a1.704 1.704 0 0 1-1.198 0C5.77 20.705 2 16.19 2 10V4.976c0-.758.489-1.43 1.21-1.664L11.46.637a1.748 1.748 0 0 1 1.08 0Zm-.617 1.426-8.25 2.676a.249.249 0 0 0-.173.237V10c0 5.46 3.28 9.483 8.43 11.426a.199.199 0 0 0 .14 0C17.22 19.483 20.5 15.461 20.5 10V4.976a.25.25 0 0 0-.173-.237l-8.25-2.676a.253.253 0 0 0-.154 0Z"></path>
# </svg>
# <div>
# <div class="color-fg-default h4">Security</div>
#         Find and fix vulnerabilities
#       </div>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"actions","context":"product","tag":"link","label":"actions_link_product_navbar"}' href="https://github.com/features/actions">
# <svg aria-hidden="true" class="octicon octicon-workflow color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M1 3a2 2 0 0 1 2-2h6.5a2 2 0 0 1 2 2v6.5a2 2 0 0 1-2 2H7v4.063C7 16.355 7.644 17 8.438 17H12.5v-2.5a2 2 0 0 1 2-2H21a2 2 0 0 1 2 2V21a2 2 0 0 1-2 2h-6.5a2 2 0 0 1-2-2v-2.5H8.437A2.939 2.939 0 0 1 5.5 15.562V11.5H3a2 2 0 0 1-2-2Zm2-.5a.5.5 0 0 0-.5.5v6.5a.5.5 0 0 0 .5.5h6.5a.5.5 0 0 0 .5-.5V3a.5.5 0 0 0-.5-.5ZM14.5 14a.5.5 0 0 0-.5.5V21a.5.5 0 0 0 .5.5H21a.5.5 0 0 0 .5-.5v-6.5a.5.5 0 0 0-.5-.5Z"></path>
# </svg>
# <div>
# <div class="color-fg-default h4">Actions</div>
#         Automate any workflow
#       </div>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"codespaces","context":"product","tag":"link","label":"codespaces_link_product_navbar"}' href="https://github.com/features/codespaces">
# <svg aria-hidden="true" class="octicon octicon-codespaces color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M3.5 3.75C3.5 2.784 4.284 2 5.25 2h13.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0 1 18.75 13H5.25a1.75 1.75 0 0 1-1.75-1.75Zm-2 12c0-.966.784-1.75 1.75-1.75h17.5c.966 0 1.75.784 1.75 1.75v4a1.75 1.75 0 0 1-1.75 1.75H3.25a1.75 1.75 0 0 1-1.75-1.75ZM5.25 3.5a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h13.5a.25.25 0 0 0 .25-.25v-7.5a.25.25 0 0 0-.25-.25Zm-2 12a.25.25 0 0 0-.25.25v4c0 .138.112.25.25.25h17.5a.25.25 0 0 0 .25-.25v-4a.25.25 0 0 0-.25-.25Z"></path><path d="M10 17.75a.75.75 0 0 1 .75-.75h6.5a.75.75 0 0 1 0 1.5h-6.5a.75.75 0 0 1-.75-.75Zm-4 0a.75.75 0 0 1 .75-.75h.5a.75.75 0 0 1 0 1.5h-.5a.75.75 0 0 1-.75-.75Z"></path>
# </svg>
# <div>
# <div class="color-fg-default h4">Codespaces</div>
#         Instant dev environments
#       </div>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"issues","context":"product","tag":"link","label":"issues_link_product_navbar"}' href="https://github.com/features/issues">
# <svg aria-hidden="true" class="octicon octicon-issue-opened color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M12 1c6.075 0 11 4.925 11 11s-4.925 11-11 11S1 18.075 1 12 5.925 1 12 1ZM2.5 12a9.5 9.5 0 0 0 9.5 9.5 9.5 9.5 0 0 0 9.5-9.5A9.5 9.5 0 0 0 12 2.5 9.5 9.5 0 0 0 2.5 12Zm9.5 2a2 2 0 1 1-.001-3.999A2 2 0 0 1 12 14Z"></path>
# </svg>
# <div>
# <div class="color-fg-default h4">Issues</div>
#         Plan and track work
#       </div>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"code_review","context":"product","tag":"link","label":"code_review_link_product_navbar"}' href="https://github.com/features/code-review">
# <svg aria-hidden="true" class="octicon octicon-code-review color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M10.3 6.74a.75.75 0 0 1-.04 1.06l-2.908 2.7 2.908 2.7a.75.75 0 1 1-1.02 1.1l-3.5-3.25a.75.75 0 0 1 0-1.1l3.5-3.25a.75.75 0 0 1 1.06.04Zm3.44 1.06a.75.75 0 1 1 1.02-1.1l3.5 3.25a.75.75 0 0 1 0 1.1l-3.5 3.25a.75.75 0 1 1-1.02-1.1l2.908-2.7-2.908-2.7Z"></path><path d="M1.5 4.25c0-.966.784-1.75 1.75-1.75h17.5c.966 0 1.75.784 1.75 1.75v12.5a1.75 1.75 0 0 1-1.75 1.75h-9.69l-3.573 3.573A1.458 1.458 0 0 1 5 21.043V18.5H3.25a1.75 1.75 0 0 1-1.75-1.75ZM3.25 4a.25.25 0 0 0-.25.25v12.5c0 .138.112.25.25.25h2.5a.75.75 0 0 1 .75.75v3.19l3.72-3.72a.749.749 0 0 1 .53-.22h10a.25.25 0 0 0 .25-.25V4.25a.25.25 0 0 0-.25-.25Z"></path>
# </svg>
# <div>
# <div class="color-fg-default h4">Code Review</div>
#         Manage code changes
#       </div>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"discussions","context":"product","tag":"link","label":"discussions_link_product_navbar"}' href="https://github.com/features/discussions">
# <svg aria-hidden="true" class="octicon octicon-comment-discussion color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M1.75 1h12.5c.966 0 1.75.784 1.75 1.75v9.5A1.75 1.75 0 0 1 14.25 14H8.061l-2.574 2.573A1.458 1.458 0 0 1 3 15.543V14H1.75A1.75 1.75 0 0 1 0 12.25v-9.5C0 1.784.784 1 1.75 1ZM1.5 2.75v9.5c0 .138.112.25.25.25h2a.75.75 0 0 1 .75.75v2.19l2.72-2.72a.749.749 0 0 1 .53-.22h6.5a.25.25 0 0 0 .25-.25v-9.5a.25.25 0 0 0-.25-.25H1.75a.25.25 0 0 0-.25.25Z"></path><path d="M22.5 8.75a.25.25 0 0 0-.25-.25h-3.5a.75.75 0 0 1 0-1.5h3.5c.966 0 1.75.784 1.75 1.75v9.5A1.75 1.75 0 0 1 22.25 20H21v1.543a1.457 1.457 0 0 1-2.487 1.03L15.939 20H10.75A1.75 1.75 0 0 1 9 18.25v-1.465a.75.75 0 0 1 1.5 0v1.465c0 .138.112.25.25.25h5.5a.75.75 0 0 1 .53.22l2.72 2.72v-2.19a.75.75 0 0 1 .75-.75h2a.25.25 0 0 0 .25-.25v-9.5Z"></path>
# </svg>
# <div>
# <div class="color-fg-default h4">Discussions</div>
#         Collaborate outside of code
#       </div>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description" data-analytics-event='{"location":"navbar","action":"code_search","context":"product","tag":"link","label":"code_search_link_product_navbar"}' href="https://github.com/features/code-search">
# <svg aria-hidden="true" class="octicon octicon-code-square color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M10.3 8.24a.75.75 0 0 1-.04 1.06L7.352 12l2.908 2.7a.75.75 0 1 1-1.02 1.1l-3.5-3.25a.75.75 0 0 1 0-1.1l3.5-3.25a.75.75 0 0 1 1.06.04Zm3.44 1.06a.75.75 0 1 1 1.02-1.1l3.5 3.25a.75.75 0 0 1 0 1.1l-3.5 3.25a.75.75 0 1 1-1.02-1.1l2.908-2.7-2.908-2.7Z"></path><path d="M2 3.75C2 2.784 2.784 2 3.75 2h16.5c.966 0 1.75.784 1.75 1.75v16.5A1.75 1.75 0 0 1 20.25 22H3.75A1.75 1.75 0 0 1 2 20.25Zm1.75-.25a.25.25 0 0 0-.25.25v16.5c0 .138.112.25.25.25h16.5a.25.25 0 0 0 .25-.25V3.75a.25.25 0 0 0-.25-.25Z"></path>
# </svg>
# <div>
# <div class="color-fg-default h4">Code Search</div>
#         Find more, search less
#       </div>
# </a></li>
# </ul>
# </div>
# </div>
# <div class="HeaderMenu-column px-lg-4">
# <div class="border-bottom pb-3 pb-lg-0 border-lg-bottom-0 border-bottom-0">
# <span class="d-block h4 color-fg-default my-1" id="product-explore-heading">Explore</span>
# <ul aria-labelledby="product-explore-heading" class="list-style-none f5">
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"all_features","context":"product","tag":"link","label":"all_features_link_product_navbar"}' href="https://github.com/features">
#       All features
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary Link--external" data-analytics-event='{"location":"navbar","action":"documentation","context":"product","tag":"link","label":"documentation_link_product_navbar"}' href="https://docs.github.com" target="_blank">
#       Documentation
#
#     <svg aria-hidden="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>
# </svg>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary Link--external" data-analytics-event='{"location":"navbar","action":"github_skills","context":"product","tag":"link","label":"github_skills_link_product_navbar"}' href="https://skills.github.com" target="_blank">
#       GitHub Skills
#
#     <svg aria-hidden="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>
# </svg>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary Link--external" data-analytics-event='{"location":"navbar","action":"blog","context":"product","tag":"link","label":"blog_link_product_navbar"}' href="https://github.blog" target="_blank">
#       Blog
#
#     <svg aria-hidden="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>
# </svg>
# </a></li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li class="HeaderMenu-item position-relative flex-wrap flex-justify-between flex-items-center d-block d-lg-flex flex-lg-nowrap flex-lg-items-center js-details-container js-header-menu-item">
# <button aria-expanded="false" class="HeaderMenu-link border-0 width-full width-lg-auto px-0 px-lg-2 py-lg-2 no-wrap d-flex flex-items-center flex-justify-between js-details-target" type="button">
#         Solutions
#         <svg aria-hidden="true" class="octicon octicon-chevron-down HeaderMenu-icon ml-1" data-view-component="true" height="16" opacity="0.5" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M12.78 5.22a.749.749 0 0 1 0 1.06l-4.25 4.25a.749.749 0 0 1-1.06 0L3.22 6.28a.749.749 0 1 1 1.06-1.06L8 8.939l3.72-3.719a.749.749 0 0 1 1.06 0Z"></path>
# </svg>
# </button>
# <div class="HeaderMenu-dropdown dropdown-menu rounded m-0 p-0 pt-2 pt-lg-4 position-relative position-lg-absolute left-0 left-lg-n3 d-lg-flex flex-wrap dropdown-menu-wide">
# <div class="HeaderMenu-column px-lg-4 border-lg-right mb-4 mb-lg-0 pr-lg-7">
# <div class="border-bottom pb-3 pb-lg-0 border-lg-bottom-0 pb-lg-3 mb-3 mb-lg-0">
# <span class="d-block h4 color-fg-default my-1" id="solutions-by-company-size-heading">By company size</span>
# <ul aria-labelledby="solutions-by-company-size-heading" class="list-style-none f5">
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"enterprises","context":"solutions","tag":"link","label":"enterprises_link_solutions_navbar"}' href="https://github.com/enterprise">
#       Enterprises
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"small_and_medium_teams","context":"solutions","tag":"link","label":"small_and_medium_teams_link_solutions_navbar"}' href="https://github.com/team">
#       Small and medium teams
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"startups","context":"solutions","tag":"link","label":"startups_link_solutions_navbar"}' href="https://github.com/enterprise/startups">
#       Startups
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"nonprofits","context":"solutions","tag":"link","label":"nonprofits_link_solutions_navbar"}' href="/solutions/industry/nonprofits">
#       Nonprofits
#
#
# </a></li>
# </ul>
# </div>
# <div class="border-bottom pb-3 pb-lg-0 border-lg-bottom-0">
# <span class="d-block h4 color-fg-default my-1" id="solutions-by-use-case-heading">By use case</span>
# <ul aria-labelledby="solutions-by-use-case-heading" class="list-style-none f5">
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"devsecops","context":"solutions","tag":"link","label":"devsecops_link_solutions_navbar"}' href="/solutions/use-case/devsecops">
#       DevSecOps
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"devops","context":"solutions","tag":"link","label":"devops_link_solutions_navbar"}' href="/solutions/use-case/devops">
#       DevOps
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"ci_cd","context":"solutions","tag":"link","label":"ci_cd_link_solutions_navbar"}' href="/solutions/use-case/ci-cd">
#       CI/CD
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"view_all_use_cases","context":"solutions","tag":"link","label":"view_all_use_cases_link_solutions_navbar"}' href="/solutions/use-case">
#       View all use cases
#
#
# </a></li>
# </ul>
# </div>
# </div>
# <div class="HeaderMenu-column px-lg-4">
# <div class="border-bottom pb-3 pb-lg-0 border-lg-bottom-0">
# <span class="d-block h4 color-fg-default my-1" id="solutions-by-industry-heading">By industry</span>
# <ul aria-labelledby="solutions-by-industry-heading" class="list-style-none f5">
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"healthcare","context":"solutions","tag":"link","label":"healthcare_link_solutions_navbar"}' href="/solutions/industry/healthcare">
#       Healthcare
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"financial_services","context":"solutions","tag":"link","label":"financial_services_link_solutions_navbar"}' href="/solutions/industry/financial-services">
#       Financial services
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"manufacturing","context":"solutions","tag":"link","label":"manufacturing_link_solutions_navbar"}' href="/solutions/industry/manufacturing">
#       Manufacturing
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"government","context":"solutions","tag":"link","label":"government_link_solutions_navbar"}' href="/solutions/industry/government">
#       Government
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"view_all_industries","context":"solutions","tag":"link","label":"view_all_industries_link_solutions_navbar"}' href="/solutions/industry">
#       View all industries
#
#
# </a></li>
# </ul>
# </div>
# </div>
# <div class="HeaderMenu-trailing-link rounded-bottom-2 flex-shrink-0 mt-lg-4 px-lg-4 py-4 py-lg-3 f5 text-semibold">
# <a href="/solutions">
#               View all solutions
#               <svg aria-hidden="true" class="octicon octicon-chevron-right HeaderMenu-trailing-link-icon" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M6.22 3.22a.75.75 0 0 1 1.06 0l4.25 4.25a.75.75 0 0 1 0 1.06l-4.25 4.25a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042L9.94 8 6.22 4.28a.75.75 0 0 1 0-1.06Z"></path>
# </svg>
# </a> </div>
# </div>
# </li>
# <li class="HeaderMenu-item position-relative flex-wrap flex-justify-between flex-items-center d-block d-lg-flex flex-lg-nowrap flex-lg-items-center js-details-container js-header-menu-item">
# <button aria-expanded="false" class="HeaderMenu-link border-0 width-full width-lg-auto px-0 px-lg-2 py-lg-2 no-wrap d-flex flex-items-center flex-justify-between js-details-target" type="button">
#         Resources
#         <svg aria-hidden="true" class="octicon octicon-chevron-down HeaderMenu-icon ml-1" data-view-component="true" height="16" opacity="0.5" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M12.78 5.22a.749.749 0 0 1 0 1.06l-4.25 4.25a.749.749 0 0 1-1.06 0L3.22 6.28a.749.749 0 1 1 1.06-1.06L8 8.939l3.72-3.719a.749.749 0 0 1 1.06 0Z"></path>
# </svg>
# </button>
# <div class="HeaderMenu-dropdown dropdown-menu rounded m-0 p-0 pt-2 pt-lg-4 position-relative position-lg-absolute left-0 left-lg-n3 pb-2 pb-lg-4 d-lg-flex flex-wrap dropdown-menu-wide">
# <div class="HeaderMenu-column px-lg-4 border-lg-right mb-4 mb-lg-0 pr-lg-7">
# <div class="border-bottom pb-3 pb-lg-0 border-lg-bottom-0">
# <span class="d-block h4 color-fg-default my-1" id="resources-topics-heading">Topics</span>
# <ul aria-labelledby="resources-topics-heading" class="list-style-none f5">
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"ai","context":"resources","tag":"link","label":"ai_link_resources_navbar"}' href="/resources/articles/ai">
#       AI
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"devops","context":"resources","tag":"link","label":"devops_link_resources_navbar"}' href="/resources/articles/devops">
#       DevOps
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"security","context":"resources","tag":"link","label":"security_link_resources_navbar"}' href="/resources/articles/security">
#       Security
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"software_development","context":"resources","tag":"link","label":"software_development_link_resources_navbar"}' href="/resources/articles/software-development">
#       Software Development
#
#
# </a></li>
# <li>
# ...
# <p class="f5 color-fg-muted mb-0 mt-1">
#           A cryptocurrency is a digital currency that uses cryptography.
#         </p>
# </a>
# <div class="flex-grow-0">
# <div class="d-block" data-view-component="true">
# <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-sw btn-sm btn" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":null,"auth_type":"LOG_IN","originating_url":"https://github.com/topics","user_id":null}}' data-hydro-click-hmac="7575b5082e2c3915281be9460d747ad48fe377ebd620d4e12e2387269c69459c" data-view-component="true" href="/login?return_to=%2Ftopic.cryptocurrency" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 .25a.75.75 0 0 1 .673.418l1.882 3.815 4.21.612a.75.75 0 0 1 .416 1.279l-3.046 2.97.719 4.192a.751.751 0 0 1-1.088.791L8 12.347l-3.766 1.98a.75.75 0 0 1-1.088-.79l.72-4.194L.818 6.374a.75.75 0 0 1 .416-1.28l4.21-.611L7.327.668A.75.75 0 0 1 8 .25Zm0 2.445L6.615 5.5a.75.75 0 0 1-.564.41l-3.097.45 2.24 2.184a.75.75 0 0 1 .216.664l-.528 3.084 2.769-1.456a.75.75 0 0 1 .698 0l2.77 1.456-.53-3.084a.75.75 0 0 1 .216-.664l2.24-2.183-3.096-.45a.75.75 0 0 1-.564-.41L8 2.694Z"></path>
# </svg><span class="d-inline" data-view-component="true">
#           Star
# </span>
# </a></div>
# </div>
# </div>
# <div class="py-4 border-bottom d-flex flex-justify-between">
# <a class="no-underline flex-grow-0" href="/topics/crystal">
# <img alt="crystal" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/80688e429a7d4ef2fca1e82350fe8e3517d3494d/topics/crystal/crystal.png" width="64"/>
# </a>
# <a class="no-underline flex-1 d-flex flex-column" href="/topics/crystal">
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Crystal</p>
# <p class="f5 color-fg-muted mb-0 mt-1">
#           Crystal is a self-hosted, general purpose programming language.
#         </p>
# </a>
# <div class="flex-grow-0">
# <div class="d-block" data-view-component="true">
# <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-sw btn-sm btn" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":null,"auth_type":"LOG_IN","originating_url":"https://github.com/topics","user_id":null}}' data-hydro-click-hmac="7575b5082e2c3915281be9460d747ad48fe377ebd620d4e12e2387269c69459c" data-view-component="true" href="/login?return_to=%2Ftopic.crystal" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 .25a.75.75 0 0 1 .673.418l1.882 3.815 4.21.612a.75.75 0 0 1 .416 1.279l-3.046 2.97.719 4.192a.751.751 0 0 1-1.088.791L8 12.347l-3.766 1.98a.75.75 0 0 1-1.088-.79l.72-4.194L.818 6.374a.75.75 0 0 1 .416-1.28l4.21-.611L7.327.668A.75.75 0 0 1 8 .25Zm0 2.445L6.615 5.5a.75.75 0 0 1-.564.41l-3.097.45 2.24 2.184a.75.75 0 0 1 .216.664l-.528 3.084 2.769-1.456a.75.75 0 0 1 .698 0l2.77 1.456-.53-3.084a.75.75 0 0 1 .216-.664l2.24-2.183-3.096-.45a.75.75 0 0 1-.564-.41L8 2.694Z"></path>
# </svg><span class="d-inline" data-view-component="true">
#           Star
# </span>
# </a></div>
# </div>
# </div>
# </div>
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="/topics" class="ajax-pagination-form js-ajax-pagination" data-turbo="false" method="get">
# <input name="page" type="hidden" value="2"/>
# <button class="ajax-pagination-btn btn mt-4 py-2 color-border-default f6 width-full" data-disable-with="Loading more..." type="submit">
#       Load more…
#     </button>
# </form>
# </div>
# <div class="col-lg-3">
# <h2 class="h4 mb-2">Popular topics</h2>
# <ul class="col-sm-6 col-md-4 col-lg-12 list-style-none flex-wrap">
# <li class="d-inline-block">
# <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to javascript, location:popular topics" data-view-component="true" href="/topics/javascript" title="Topic: javascript">
#   javascript
# </a>
# </li>
# <li class="d-inline-block">
# <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to game, location:popular topics" data-view-component="true" href="/topics/game" title="Topic: game">
#   game
# </a>
# </li>
# <li class="d-inline-block">
# <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to config, location:popular topics" data-view-component="true" href="/topics/config" title="Topic: config">
#   config
# </a>
# </li>
# <li class="d-inline-block">
# <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to python, location:popular topics" data-view-component="true" href="/topics/python" title="Topic: python">
#   python
# </a>
# </li>
# <li class="d-inline-block">
# <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to java, location:popular topics" data-view-component="true" href="/topics/java" title="Topic: java">
#   java
# </a>
# </li>
# <li class="d-inline-block">
# <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to docker, location:popular topics" data-view-component="true" href="/topics/docker" title="Topic: docker">
#   docker
# </a>
# </li>
# <li class="d-inline-block">
# <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to machine-learning, location:popular topics" data-view-component="true" href="/topics/machine-learning" title="Topic: machine-learning">
#   machine-learning
# </a>
# </li>
# <li class="d-inline-block">
# <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to typescript, location:popular topics" data-view-component="true" href="/topics/typescript" title="Topic: typescript">
#   typescript
# </a>
# </li>
# <li class="d-inline-block">
# <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to computer-vision, location:popular topics" data-view-component="true" href="/topics/computer-vision" title="Topic: computer-vision">
#   computer-vision
# </a>
# </li>
# <li class="d-inline-block">
# <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to github-config, location:popular topics" data-view-component="true" href="/topics/github-config" title="Topic: github-config">
#   github-config
# </a>
# </li>
# </ul>
# </div>
# </div>
# </main>
# </div>
# <footer class="footer pt-8 pb-6 f6 color-fg-muted p-responsive" role="contentinfo">
# <h2 class="sr-only">Footer</h2>
# <div class="d-flex flex-justify-center flex-items-center flex-column-reverse flex-lg-row flex-wrap flex-lg-nowrap">
# <div class="d-flex flex-items-center flex-shrink-0 mx-2">
# <a aria-label="Homepage" class="footer-octicon mr-2" href="https://github.com" title="GitHub">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M12 1C5.9225 1 1 5.9225 1 12C1 16.8675 4.14875 20.9787 8.52125 22.4362C9.07125 22.5325 9.2775 22.2025 9.2775 21.9137C9.2775 21.6525 9.26375 20.7862 9.26375 19.865C6.5 20.3737 5.785 19.1912 5.565 18.5725C5.44125 18.2562 4.905 17.28 4.4375 17.0187C4.0525 16.8125 3.5025 16.3037 4.42375 16.29C5.29 16.2762 5.90875 17.0875 6.115 17.4175C7.105 19.0812 8.68625 18.6137 9.31875 18.325C9.415 17.61 9.70375 17.1287 10.02 16.8537C7.5725 16.5787 5.015 15.63 5.015 11.4225C5.015 10.2262 5.44125 9.23625 6.1425 8.46625C6.0325 8.19125 5.6475 7.06375 6.2525 5.55125C6.2525 5.55125 7.17375 5.2625 9.2775 6.67875C10.1575 6.43125 11.0925 6.3075 12.0275 6.3075C12.9625 6.3075 13.8975 6.43125 14.7775 6.67875C16.8813 5.24875 17.8025 5.55125 17.8025 5.55125C18.4075 7.06375 18.0225 8.19125 17.9125 8.46625C18.6138 9.23625 19.04 10.2125 19.04 11.4225C19.04 15.6437 16.4688 16.5787 14.0213 16.8537C14.42 17.1975 14.7638 17.8575 14.7638 18.8887C14.7638 20.36 14.75 21.5425 14.75 21.9137C14.75 22.2025 14.9563 22.5462 15.5063 22.4362C19.8513 20.9787 23 16.8537 23 12C23 5.9225 18.0775 1 12 1Z"></path>
# </svg>
# </a>
# <span>
#         © 2025 GitHub, Inc.
#       </span>
# </div>
# <nav aria-label="Footer">
# <h3 class="sr-only" id="sr-footer-heading">Footer navigation</h3>
# <ul aria-labelledby="sr-footer-heading" class="list-style-none d-flex flex-justify-center flex-wrap mb-2 mb-lg-0">
# <li class="mx-2">
# <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to Terms","label":"text:terms"}' data-view-component="true" href="https://docs.github.com/site-policy/github-terms/github-terms-of-service">Terms</a>
# </li>
# <li class="mx-2">
# <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to privacy","label":"text:privacy"}' data-view-component="true" href="https://docs.github.com/site-policy/privacy-policies/github-privacy-statement">Privacy</a>
# </li>
# <li class="mx-2">
# <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to security","label":"text:security"}' data-view-component="true" href="https://github.com/security">Security</a>
# </li>
# <li class="mx-2">
# <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to status","label":"text:status"}' data-view-component="true" href="https://www.githubstatus.com/">Status</a>
# </li>
# <li class="mx-2">
# <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to docs","label":"text:docs"}' data-view-component="true" href="https://docs.github.com/">Docs</a>
# </li>
# <li class="mx-2">
# <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to contact","label":"text:contact"}' data-view-component="true" href="https://support.github.com?tags=dotcom-footer">Contact</a>
# </li>
# <li class="mx-2">
# <cookie-consent-link>
# <button class="Link--secondary underline-on-hover border-0 p-0 color-bg-transparent" data-action="click:cookie-consent-link#showConsentManagement" data-analytics-event='{"location":"footer","action":"cookies","context":"subfooter","tag":"link","label":"cookies_link_subfooter_footer"}' type="button">
#       Manage cookies
#     </button>
# </cookie-consent-link>
# </li>
# <li class="mx-2">
# <cookie-consent-link>
# <button class="Link--secondary underline-on-hover border-0 p-0 color-bg-transparent" data-action="click:cookie-consent-link#showConsentManagement" data-analytics-event='{"location":"footer","action":"dont_share_info","context":"subfooter","tag":"link","label":"dont_share_info_link_subfooter_footer"}' type="button">
#       Do not share my personal information
#     </button>
# </cookie-consent-link>
# </li>
# </ul>
# </nav>
# </div>
# </footer>
# <ghcc-consent class="position-fixed bottom-0 left-0" data-cookie-consent-required="false" data-initial-cookie-consent-allowed="" id="ghcc" style="z-index: 999999"></ghcc-consent>
# <div class="ajax-error-message flash flash-error" hidden="" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M6.457 1.047c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0 1 14.082 15H1.918a1.75 1.75 0 0 1-1.543-2.575Zm1.763.707a.25.25 0 0 0-.44 0L1.698 13.132a.25.25 0 0 0 .22.368h12.164a.25.25 0 0 0 .22-.368Zm.53 3.996v2.5a.75.75 0 0 1-1.5 0v-2.5a.75.75 0 0 1 1.5 0ZM9 11a1 1 0 1 1-2 0 1 1 0 0 1 2 0Z"></path>
# </svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 0 1 1.06 0L8 6.94l3.22-3.22a.749.749 0 0 1 1.275.326.749.749 0 0 1-.215.734L9.06 8l3.22 3.22a.749.749 0 0 1-.326 1.275.749.749 0 0 1-.734-.215L8 9.06l-3.22 3.22a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042L6.94 8 3.72 4.78a.75.75 0 0 1 0-1.06Z"></path>
# </svg>
# </button>
#     You can’t perform that action at this time.
#   </div>
# <template id="site-details-dialog">
# <details class="details-reset details-overlay details-overlay-dark lh-default color-fg-default hx_rsm" open="">
# <summary aria-label="Close dialog" role="button"></summary>
# <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
# <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 0 1 1.06 0L8 6.94l3.22-3.22a.749.749 0 0 1 1.275.326.749.749 0 0 1-.215.734L9.06 8l3.22 3.22a.749.749 0 0 1-.326 1.275.749.749 0 0 1-.734-.215L8 9.06l-3.22 3.22a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042L6.94 8 3.72 4.78a.75.75 0 0 1 0-1.06Z"></path>
# </svg>
# </button>
# <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
# </details-dialog>
# </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
# </div>
# </div>
# <template id="snippet-clipboard-copy-button">
# <div class="zeroclipboard-container position-absolute right-0 top-0">
# <clipboard-copy aria-label="Copy" class="ClipboardButton btn js-clipboard-copy m-2 p-0" data-copy-feedback="Copied!" data-tooltip-direction="w">
# <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 0 1 0 1.5h-1.5a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-1.5a.75.75 0 0 1 1.5 0v1.5A1.75 1.75 0 0 1 9.25 16h-7.5A1.75 1.75 0 0 1 0 14.25Z"></path><path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0 1 14.25 11h-7.5A1.75 1.75 0 0 1 5 9.25Zm1.75-.25a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-7.5a.25.25 0 0 0-.25-.25Z"></path>
# </svg>
# <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M13.78 4.22a.75.75 0 0 1 0 1.06l-7.25 7.25a.75.75 0 0 1-1.06 0L2.22 9.28a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L6 10.94l6.72-6.72a.75.75 0 0 1 1.06 0Z"></path>
# </svg>
# </clipboard-copy>
# </div>
# </template>
# <template id="snippet-clipboard-copy-button-unpositioned">
# <div class="zeroclipboard-container">
# <clipboard-copy aria-label="Copy" class="ClipboardButton btn btn-invisible js-clipboard-copy m-2 p-0 d-flex flex-justify-center flex-items-center" data-copy-feedback="Copied!" data-tooltip-direction="w">
# <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 0 1 0 1.5h-1.5a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-1.5a.75.75 0 0 1 1.5 0v1.5A1.75 1.75 0 0 1 9.25 16h-7.5A1.75 1.75 0 0 1 0 14.25Z"></path><path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0 1 14.25 11h-7.5A1.75 1.75 0 0 1 5 9.25Zm1.75-.25a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-7.5a.25.25 0 0 0-.25-.25Z"></path>
# </svg>
# <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M13.78 4.22a.75.75 0 0 1 0 1.06l-7.25 7.25a.75.75 0 0 1-1.06 0L2.22 9.28a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L6 10.94l6.72-6.72a.75.75 0 0 1 1.06 0Z"></path>
# </svg>
# </clipboard-copy>
# </div>
# </template>
# </div>
# <div aria-atomic="true" aria-live="polite" class="sr-only mt-n1" id="js-global-screen-reader-notice"></div>
# <div aria-atomic="true" aria-live="assertive" class="sr-only mt-n1" id="js-global-screen-reader-notice-assertive"></div>
# </body>
# </html>

# %%
# Formats and prints the parsed HTML in a structured, indented format for better readability
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-a11y-animated-images="system" data-a11y-link-underlines="true" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://github.githubassets.com" rel="dns-prefetch"/>
#   <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
#   <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
#   <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
#   <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/light-74231a1f3bbb.css" media="all" rel="stylesheet">
#    <link crossorigin="anonymous" href="https://github.githubassets.com/assets/dark-8a995f0bacd4.css" media="all" rel="stylesheet">
#     <link crossorigin="anonymous" data-color-theme="dark_dimmed" data-href="https://github.githubassets.com/assets/dark_dimmed-f37fb7684b1f.css" media="all" rel="stylesheet">
#      <link crossorigin="anonymous" data-color-theme="dark_high_contrast" data-href="https://github.githubassets.com/assets/dark_high_contrast-9ac301c3ebe5.css" media="all" rel="stylesheet">
#       <link crossorigin="anonymous" data-color-theme="dark_colorblind" data-href="https://github.githubassets.com/assets/dark_colorblind-cd826e8636dc.css" media="all" rel="stylesheet">
#        <link crossorigin="anonymous" data-color-theme="light_colorblind" data-href="https://github.githubassets.com/assets/light_colorblind-f91b0f603451.css" media="all" rel="stylesheet">
#         <link crossorigin="anonymous" data-color-theme="light_high_contrast" data-href="https://github.githubassets.com/assets/light_high_contrast-83beb16e0ecf.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" data-color-theme="light_tritanopia" data-href="https://github.githubassets.com/assets/light_tritanopia-6e122dab64fc.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" data-color-theme="dark_tritanopia" data-href="https://github.githubassets.com/assets/dark_tritanopia-18119e682df0.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://github.githubassets.com/assets/primer-primitives-225433424a87.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://github.githubassets.com/assets/primer-aaa714e5674d.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://github.githubassets.com/assets/global-0a3c53b9d1c2.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://github.githubassets.com/assets/github-ea73c9cb5377.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://github.githubassets.com/assets/site-3e72ff5534e0.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://github.githubassets.com/assets/explore-742a7653565b.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://github.githubassets.com/assets/dashboard-0de2bd46c6d8.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://github.githubassets.com/assets/discussions-dae9ae1a46a6.css" media="all" rel="stylesheet"/>
#         <script id="client-env" type="application/json">
#          {"locale":"en","featureFlags":["a11y_quote_reply_fix","copilot_immersive_issue_preview","copilot_new_references_ui","copilot_chat_repo_custom_instructions_preview","copilot_no_floating_button","copilot_topics_as_references","copilot_read_shared_conversation","copilot_duplicate_thread","copilot_buffered_streaming","dotcom_chat_client_side_skills","experimentation_azure_variant_endpoint","failbot_handle_non_errors","geojson_azure_maps","ghost_pilot_confidence_truncation_25","ghost_pilot_confidence_truncation_40","github_models_gateway_parse_params","github_models_o3_mini_streaming","insert_before_patch","issues_react_remove_placeholders","issues_react_blur_item_picker_on_close","marketing_pages_search_explore_provider","primer_react_css_modules_ga","react_data_router_pull_requests","remove_child_patch","sample_network_conn_type","swp_enterprise_contact_form","site_proxima_australia_update","viewscreen_sandbox","issues_react_create_milestone","issues_react_cache_fix_workaround","lifecycle_label_name_updates","copilot_task_oriented_assistive_prompts","issue_types_prevent_private_type_creation","refresh_image_video_src","react_router_dispose_on_disconnect","codespaces_prebuild_region_target_update","turbo_app_id_restore","copilot_code_review_sign_up_closed"]}
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/wp-runtime-900d20148682.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_oddbird_popover-polyfill_dist_popover_js-9da652f58479.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_arianotify-polyfill_ariaNotify-polyfill_js-node_modules_github_mi-3abb8f-46b9f4874d95.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/ui_packages_failbot_failbot_ts-75968cfb5298.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/environment-f04cb2a9fc8c.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_primer_behaviors_dist_esm_index_mjs-0dbb79f97f8f.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_selector-observer_dist_index_esm_js-f690fd9ae3d5.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_relative-time-element_dist_index_js-62d275b7ddd9.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_text-expander-element_dist_index_js-78748950cb0c.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_auto-complete-element_dist_index_js-node_modules_github_catalyst_-8e9f78-a90ac05d2469.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_filter-input-element_dist_index_js-node_modules_github_remote-inp-b5f1d7-a1760ffda83d.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_markdown-toolbar-element_dist_index_js-ceef33f593fa.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_file-attachment-element_dist_index_js-node_modules_primer_view-co-c44a69-efa32db3a345.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/github-elements-394f8eb34f19.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/element-registry-25113a65b77f.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_braintree_browser-detection_dist_browser-detection_js-node_modules_githu-2906d7-2a07a295af40.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_lit-html_lit-html_js-be8cb88f481b.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_mini-throttle_dist_index_js-node_modules_morphdom_dist_morphdom-e-7c534c-a4a1922eb55f.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_turbo_dist_turbo_es2017-esm_js-a03ee12d659a.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_delegated-events_dist_inde-893f9f-b6294cf703b7.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_color-convert_index_js-e3180fe3bcb3.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_quote-selection_dist_index_js-node_modules_github_session-resume_-947061-e7a6c4a19f98.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/ui_packages_updatable-content_updatable-content_ts-eb3147a21e96.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_task-list_ts-app_assets_modules_github_sso_ts-ui_packages-900dde-768abe60b1f8.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/app_assets_modules_github_sticky-scroll-into-view_ts-3e000c5d31a9.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_ajax-error_ts-app_assets_modules_github_behaviors_include-87a4ae-4c160a67a3f8.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_commenting_edit_ts-app_assets_modules_github_behaviors_ht-83c235-e429cff6ceb1.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/behaviors-1f167e0c2aee.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_github_catalyst_lib_index_js-f6223d90c7ba.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/notifications-global-01e85cd1be94.js" type="application/javascript">
#         </script>
#         <title>
#          Topics on GitHub · GitHub
#         </title>
#         <meta content="/topics(.:format)" data-turbo-transient="" name="route-pattern"/>
#         <meta content="topics" data-turbo-transient="" name="route-controller"/>
#         <meta content="index" data-turbo-transient="" name="route-action"/>
#         <meta content="82c569b93da5c18ed649ebd4c2c79437db4611a6a1373e805a3cb001c64130b7" name="current-catalog-service-hash"/>
#         <meta content="E13A:99E34:153637:1B8FB8:67E96907" data-pjax-transient="true" name="request-id">
#          <meta content="a5016707e7ea34d51780c28c782d17df7c1a209ca58eb2497674c1c5963fb396" data-pjax-transient="true" name="html-safe-nonce">
#           <meta content="eyJyZWZlcnJlciI6IiIsInJlcXVlc3RfaWQiOiJFMTNBOjk5RTM0OjE1MzYzNzoxQjhGQjg6NjdFOTY5MDciLCJ2aXNpdG9yX2lkIjoiMjY1NjM0MDkzMzkwNzkzMzQ0NyIsInJlZ2lvbl9lZGdlIjoiaWFkIiwicmVnaW9uX3JlbmRlciI6ImlhZCJ9" data-pjax-transient="true" name="visitor-payload">
#            <meta content="694c276884e03840269f51e950b7e412c20f24f1367e96d8f523b7f1f46dfb5c" data-pjax-transient="true" name="visitor-hmac">
#             <meta content="copilot" data-turbo-transient="true" name="github-keyboard-shortcuts">
#              <meta data-turbo-transient="" name="selected-link" value="/topics"/>
#              <link href="https://github.githubassets.com/" rel="assets"/>
#              <meta content="Apib7-x98H0j5cPqHWwSMm6dNU4GmODRoqxLiDzdx9I" name="google-site-verification"/>
#              <meta content="https://collector.github.com/github/collect" name="octolytics-url">
#               <meta content="" name="user-login"/>
#               <meta content="width=device-width" name="viewport"/>
#               <meta content="GitHub is where people build software. More than 150 million people use GitHub to discover, fork, and contribute to over 420 million projects." name="description"/>
#               <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
#               <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
#               <meta content="1401488693436528" property="fb:app_id"/>
#               <meta content="app-id=1477376905, app-argument=https://github.com/topics" name="apple-itunes-app">
#                <meta content="https://github.com" property="og:url"/>
#                <meta content="GitHub" property="og:site_name"/>
#                <meta content="Build software better, together" property="og:title"/>
#                <meta content="GitHub is where people build software. More than 150 million people use GitHub to discover, fork, and contribute to over 420 million projects." property="og:description"/>
#                <meta content="https://github.githubassets.com/assets/github-logo-55c5b9a1fe52.png" property="og:image"/>
#                <meta content="image/png" property="og:image:type"/>
#                <meta content="1200" property="og:image:width"/>
#                <meta content="1200" property="og:image:height"/>
#                <meta content="https://github.githubassets.com/assets/github-mark-57519b92ca4e.png" property="og:image"/>
#                <meta content="image/png" property="og:image:type"/>
#                <meta content="1200" property="og:image:width"/>
#                <meta content="620" property="og:image:height"/>
#                <meta content="https://github.githubassets.com/assets/github-octocat-13c86b8b336d.png" property="og:image"/>
#                <meta content="image/png" property="og:image:type"/>
#                <meta content="1200" property="og:image:width"/>
#                <meta content="620" property="og:image:height"/>
#                <meta content="github" property="twitter:site"/>
#                <meta content="13334762" property="twitter:site:id"/>
#                <meta content="github" property="twitter:creator"/>
#                <meta content="13334762" property="twitter:creator:id"/>
#                <meta content="summary_large_image" property="twitter:card"/>
#                <meta content="GitHub" property="twitter:title"/>
#                <meta content="GitHub is where people build software. More than 150 million people use GitHub to discover, fork, and contribute to over 420 million projects." property="twitter:description"/>
#                <meta content="https://github.githubassets.com/assets/github-logo-55c5b9a1fe52.png" property="twitter:image"/>
#                <meta content="1200" property="twitter:image:width"/>
#                <meta content="1200" property="twitter:image:height"/>
#                <meta content="github.com" name="hostname"/>
#                <meta content="github.com" name="expected-hostname"/>
#                <meta content="154e3ed6ec9e0d6fff5da6846be55e3cefb81f7aa557cdcfe2a45d929fc158d2" data-turbo-track="reload" http-equiv="x-pjax-version"/>
#                <meta content="e26f9f0ba624ee85cc7ac057d8faa8618a4f25a85eab052c33d018ac0f6b1a46" data-turbo-track="reload" http-equiv="x-pjax-csp-version"/>
#                <meta content="159e03504eed5183f9787c72780a7d8c1460af30746ab09d728b048c41719efa" data-turbo-track="reload" http-equiv="x-pjax-css-version"/>
#                <meta content="3ef84064f1c111becc704df35223db168ecae977ac2d9ec422601ed98490e586" data-turbo-track="reload" http-equiv="x-pjax-js-version"/>
#                <meta content="no-preview" data-turbo-transient="" name="turbo-cache-control"/>
#                <link data-turbo-transient="" href="https://github.com/topics" rel="canonical"/>
#                <meta content="logged-out env-production page-responsive" name="turbo-body-classes"/>
#                <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
#                <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
#                <meta content="a809ed19c131f846b28e5314dd87328a15e02a37" name="release"/>
#                <link color="#000000" href="https://github.githubassets.com/assets/pinned-octocat-093da3e6fa40.svg" rel="mask-icon"/>
#                <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.png" rel="alternate icon" type="image/png"/>
#                <link class="js-site-favicon" data-base-href="https://github.githubassets.com/favicons/favicon" href="https://github.githubassets.com/favicons/favicon.svg" rel="icon" type="image/svg+xml"/>
#                <meta content="#1e2327" name="theme-color"/>
#                <meta content="light dark" name="color-scheme">
#                 <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
#                </meta>
#               </meta>
#              </meta>
#             </meta>
#            </meta>
#           </meta>
#          </meta>
#         </meta>
#        </link>
#       </link>
#      </link>
#     </link>
#    </link>
#   </link>
#  </head>
#  <body class="logged-out env-production page-responsive" style="word-wrap: break-word;">
#   <div class="logged-out env-production page-responsive" data-turbo-body="" style="word-wrap: break-word;">
#    <div class="position-relative header-wrapper js-header-wrapper">
#     <a class="px-2 py-4 color-bg-accent-emphasis color-fg-on-emphasis show-on-focus js-skip-to-content" data-skip-target-assigned="false" href="#start-of-content">
#      Skip to content
#     </a>
#     <span class="progress-pjax-loader Progress position-fixed width-full" data-view-component="true">
#      <span class="Progress-item progress-pjax-loader-bar left-0 top-0 color-bg-accent-emphasis" data-view-component="true" style="width: 0%;">
#      </span>
#     </span>
#     <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/primer-react-602097a4b0db.js" type="application/javascript">
#     </script>
#     <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/react-core-0bc17999cb79.js" type="application/javascript">
#     </script>
#     <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/react-lib-f1bca44e0926.js" type="application/javascript">
#     </script>
#     <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/octicons-react-cf2f2ab8dab4.js" type="application/javascript">
#     </script>
#     <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_emotion_is-prop-valid_dist_emotion-is-prop-valid_esm_js-node_modules_emo-62da9f-2df2f32ec596.js" type="application/javascript">
#     </script>
#     <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_mini-throttle_dist_index_js-node_modules_stacktrace-parser_dist_s-e7dcdd-9a233856b02c.js" type="application/javascript">
#     </script>
#     <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_oddbird_popover-polyfill_dist_popover-fn_js-55fea94174bf.js" type="application/javascript">
#     </script>
#     <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/ui_packages_ui-commands_ui-commands_ts-2ea4e93613c0.js" type="application/javascript">
#     </script>
#     <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/keyboard-shortcuts-dialog-79d6a754ebf9.js" type="application/javascript">
#     </script>
#     <link crossorigin="anonymous" href="https://github.githubassets.com/assets/primer-react.8157a56b30ae88a1b356.module.css" media="all" rel="stylesheet">
#      <react-partial data-attempted-ssr="false" data-ssr="false" partial-name="keyboard-shortcuts-dialog">
#       <script data-target="react-partial.embeddedData" type="application/json">
#        {"props":{"docsUrl":"https://docs.github.com/get-started/accessibility/keyboard-shortcuts"}}
#       </script>
#       <div data-target="react-partial.reactRoot">
#       </div>
#      </react-partial>
#      <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_delegated-events_dist_inde-94fd67-4898d1bf4b51.js" type="application/javascript">
#      </script>
#      <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/sessions-730dca81d0a2.js" type="application/javascript">
#      </script>
#      <header class="HeaderMktg header-logged-out js-details-container js-header Details f4 py-3" data-color-mode="light" data-dark-theme="dark" data-is-top="true" data-light-theme="light" role="banner">
#       <h2 class="sr-only">
#        Navigation Menu
#       </h2>
#       <button aria-label="Toggle navigation" class="HeaderMktg-backdrop d-lg-none border-0 position-fixed top-0 left-0 width-full height-full js-details-target" type="button">
#        <span class="d-none">
#         Toggle navigation
#        </span>
#       </button>
#       <div class="d-flex flex-column flex-lg-row flex-items-center px-3 px-md-4 px-lg-5 height-full position-relative z-1">
#        <div class="d-flex flex-justify-between flex-items-center width-full width-lg-auto">
#         <div class="flex-1">
#          <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target js-nav-padding-recalculate js-header-menu-toggle Button--link Button--medium Button d-lg-none color-fg-inherit p-1" data-view-component="true" type="button">
#           <span class="Button-content">
#            <span class="Button-label">
#             <div class="HeaderMenu-toggle-bar rounded my-1">
#             </div>
#             <div class="HeaderMenu-toggle-bar rounded my-1">
#             </div>
#             <div class="HeaderMenu-toggle-bar rounded my-1">
#             </div>
#            </span>
#           </span>
#          </button>
#         </div>
#         <a aria-label="Homepage" class="mr-lg-3 color-fg-inherit flex-order-2 js-prevent-focus-on-mobile-nav" data-analytics-event='{"category":"Marketing nav","action":"click to go to homepage","label":"ref_page:Marketing;ref_cta:Logomark;ref_loc:Header"}' href="/">
#          <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="32" version="1.1" viewbox="0 0 24 24" width="32">
#           <path d="M12 1C5.9225 1 1 5.9225 1 12C1 16.8675 4.14875 20.9787 8.52125 22.4362C9.07125 22.5325 9.2775 22.2025 9.2775 21.9137C9.2775 21.6525 9.26375 20.7862 9.26375 19.865C6.5 20.3737 5.785 19.1912 5.565 18.5725C5.44125 18.2562 4.905 17.28 4.4375 17.0187C4.0525 16.8125 3.5025 16.3037 4.42375 16.29C5.29 16.2762 5.90875 17.0875 6.115 17.4175C7.105 19.0812 8.68625 18.6137 9.31875 18.325C9.415 17.61 9.70375 17.1287 10.02 16.8537C7.5725 16.5787 5.015 15.63 5.015 11.4225C5.015 10.2262 5.44125 9.23625 6.1425 8.46625C6.0325 8.19125 5.6475 7.06375 6.2525 5.55125C6.2525 5.55125 7.17375 5.2625 9.2775 6.67875C10.1575 6.43125 11.0925 6.3075 12.0275 6.3075C12.9625 6.3075 13.8975 6.43125 14.7775 6.67875C16.8813 5.24875 17.8025 5.55125 17.8025 5.55125C18.4075 7.06375 18.0225 8.19125 17.9125 8.46625C18.6138 9.23625 19.04 10.2125 19.04 11.4225C19.04 15.6437 16.4688 16.5787 14.0213 16.8537C14.42 17.1975 14.7638 17.8575 14.7638 18.8887C14.7638 20.36 14.75 21.5425 14.75 21.9137C14.75 22.2025 14.9563 22.5462 15.5063 22.4362C19.8513 20.9787 23 16.8537 23 12C23 5.9225 18.0775 1 12 1Z">
#           </path>
#          </svg>
#         </a>
#         <div class="flex-1 flex-order-2 text-right">
#          <a class="HeaderMenu-link HeaderMenu-button d-inline-flex d-lg-none flex-order-1 f5 no-underline border color-border-default rounded-2 px-2 py-1 color-fg-inherit js-prevent-focus-on-mobile-nav" data-analytics-event='{"category":"Marketing nav","action":"click to Sign in","label":"ref_page:Marketing;ref_cta:Sign in;ref_loc:Header"}' data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header menu","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/topics","user_id":null}}' data-hydro-click-hmac="be24ac4990e8cac9a74ee7032b910f8f38a1cea9154e0dbbe2347ce0b38a6adc" href="/login?return_to=https%3A%2F%2Fgithub.com%2Ftopics">
#           Sign in
#          </a>
#         </div>
#        </div>
#        <div class="HeaderMenu js-header-menu height-fit position-lg-relative d-lg-flex flex-column flex-auto top-0">
#         <div class="HeaderMenu-wrapper d-flex flex-column flex-self-start flex-lg-row flex-auto rounded rounded-lg-0">
#          <nav aria-label="Global" class="HeaderMenu-nav">
#           <ul class="d-lg-flex list-style-none">
#            <li class="HeaderMenu-item position-relative flex-wrap flex-justify-between flex-items-center d-block d-lg-flex flex-lg-nowrap flex-lg-items-center js-details-container js-header-menu-item">
#             <button aria-expanded="false" class="HeaderMenu-link border-0 width-full width-lg-auto px-0 px-lg-2 py-lg-2 no-wrap d-flex flex-items-center flex-justify-between js-details-target" type="button">
#              Product
#              <svg aria-hidden="true" class="octicon octicon-chevron-down HeaderMenu-icon ml-1" data-view-component="true" height="16" opacity="0.5" version="1.1" viewbox="0 0 16 16" width="16">
#               <path d="M12.78 5.22a.749.749 0 0 1 0 1.06l-4.25 4.25a.749.749 0 0 1-1.06 0L3.22 6.28a.749.749 0 1 1 1.06-1.06L8 8.939l3.72-3.719a.749.749 0 0 1 1.06 0Z">
#               </path>
#              </svg>
#             </button>
#             <div class="HeaderMenu-dropdown dropdown-menu rounded m-0 p-0 pt-2 pt-lg-4 position-relative position-lg-absolute left-0 left-lg-n3 pb-2 pb-lg-4 d-lg-flex flex-wrap dropdown-menu-wide">
#              <div class="HeaderMenu-column px-lg-4 border-lg-right mb-4 mb-lg-0 pr-lg-7">
#               <div class="border-bottom pb-3 pb-lg-0 border-lg-bottom-0">
#                <ul class="list-style-none f5">
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"github_copilot","context":"product","tag":"link","label":"github_copilot_link_product_navbar"}' href="https://github.com/features/copilot">
#                   <svg aria-hidden="true" class="octicon octicon-copilot color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#                    <path d="M23.922 16.992c-.861 1.495-5.859 5.023-11.922 5.023-6.063 0-11.061-3.528-11.922-5.023A.641.641 0 0 1 0 16.736v-2.869a.841.841 0 0 1 .053-.22c.372-.935 1.347-2.292 2.605-2.656.167-.429.414-1.055.644-1.517a10.195 10.195 0 0 1-.052-1.086c0-1.331.282-2.499 1.132-3.368.397-.406.89-.717 1.474-.952 1.399-1.136 3.392-2.093 6.122-2.093 2.731 0 4.767.957 6.166 2.093.584.235 1.077.546 1.474.952.85.869 1.132 2.037 1.132 3.368 0 .368-.014.733-.052 1.086.23.462.477 1.088.644 1.517 1.258.364 2.233 1.721 2.605 2.656a.832.832 0 0 1 .053.22v2.869a.641.641 0 0 1-.078.256ZM12.172 11h-.344a4.323 4.323 0 0 1-.355.508C10.703 12.455 9.555 13 7.965 13c-1.725 0-2.989-.359-3.782-1.259a2.005 2.005 0 0 1-.085-.104L4 11.741v6.585c1.435.779 4.514 2.179 8 2.179 3.486 0 6.565-1.4 8-2.179v-6.585l-.098-.104s-.033.045-.085.104c-.793.9-2.057 1.259-3.782 1.259-1.59 0-2.738-.545-3.508-1.492a4.323 4.323 0 0 1-.355-.508h-.016.016Zm.641-2.935c.136 1.057.403 1.913.878 2.497.442.544 1.134.938 2.344.938 1.573 0 2.292-.337 2.657-.751.384-.435.558-1.15.558-2.361 0-1.14-.243-1.847-.705-2.319-.477-.488-1.319-.862-2.824-1.025-1.487-.161-2.192.138-2.533.529-.269.307-.437.808-.438 1.578v.021c0 .265.021.562.063.893Zm-1.626 0c.042-.331.063-.628.063-.894v-.02c-.001-.77-.169-1.271-.438-1.578-.341-.391-1.046-.69-2.533-.529-1.505.163-2.347.537-2.824 1.025-.462.472-.705 1.179-.705 2.319 0 1.211.175 1.926.558 2.361.365.414 1.084.751 2.657.751 1.21 0 1.902-.394 2.344-.938.475-.584.742-1.44.878-2.497Z">
#                    </path>
#                    <path d="M14.5 14.25a1 1 0 0 1 1 1v2a1 1 0 0 1-2 0v-2a1 1 0 0 1 1-1Zm-5 0a1 1 0 0 1 1 1v2a1 1 0 0 1-2 0v-2a1 1 0 0 1 1-1Z">
#                    </path>
#                   </svg>
#                   <div>
#                    <div class="color-fg-default h4">
#                     GitHub Copilot
#                    </div>
#                    Write better code with AI
#                   </div>
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"security","context":"product","tag":"link","label":"security_link_product_navbar"}' href="https://github.com/features/security">
#                   <svg aria-hidden="true" class="octicon octicon-shield-check color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#                    <path d="M16.53 9.78a.75.75 0 0 0-1.06-1.06L11 13.19l-1.97-1.97a.75.75 0 0 0-1.06 1.06l2.5 2.5a.75.75 0 0 0 1.06 0l5-5Z">
#                    </path>
#                    <path d="m12.54.637 8.25 2.675A1.75 1.75 0 0 1 22 4.976V10c0 6.19-3.771 10.704-9.401 12.83a1.704 1.704 0 0 1-1.198 0C5.77 20.705 2 16.19 2 10V4.976c0-.758.489-1.43 1.21-1.664L11.46.637a1.748 1.748 0 0 1 1.08 0Zm-.617 1.426-8.25 2.676a.249.249 0 0 0-.173.237V10c0 5.46 3.28 9.483 8.43 11.426a.199.199 0 0 0 .14 0C17.22 19.483 20.5 15.461 20.5 10V4.976a.25.25 0 0 0-.173-.237l-8.25-2.676a.253.253 0 0 0-.154 0Z">
#                    </path>
#                   </svg>
#                   <div>
#                    <div class="color-fg-default h4">
#                     Security
#                    </div>
#                    Find and fix vulnerabilities
#                   </div>
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"actions","context":"product","tag":"link","label":"actions_link_product_navbar"}' href="https://github.com/features/actions">
#                   <svg aria-hidden="true" class="octicon octicon-workflow color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#                    <path d="M1 3a2 2 0 0 1 2-2h6.5a2 2 0 0 1 2 2v6.5a2 2 0 0 1-2 2H7v4.063C7 16.355 7.644 17 8.438 17H12.5v-2.5a2 2 0 0 1 2-2H21a2 2 0 0 1 2 2V21a2 2 0 0 1-2 2h-6.5a2 2 0 0 1-2-2v-2.5H8.437A2.939 2.939 0 0 1 5.5 15.562V11.5H3a2 2 0 0 1-2-2Zm2-.5a.5.5 0 0 0-.5.5v6.5a.5.5 0 0 0 .5.5h6.5a.5.5 0 0 0 .5-.5V3a.5.5 0 0 0-.5-.5ZM14.5 14a.5.5 0 0 0-.5.5V21a.5.5 0 0 0 .5.5H21a.5.5 0 0 0 .5-.5v-6.5a.5.5 0 0 0-.5-.5Z">
#                    </path>
#                   </svg>
#                   <div>
#                    <div class="color-fg-default h4">
#                     Actions
#                    </div>
#                    Automate any workflow
#                   </div>
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"codespaces","context":"product","tag":"link","label":"codespaces_link_product_navbar"}' href="https://github.com/features/codespaces">
#                   <svg aria-hidden="true" class="octicon octicon-codespaces color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#                    <path d="M3.5 3.75C3.5 2.784 4.284 2 5.25 2h13.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0 1 18.75 13H5.25a1.75 1.75 0 0 1-1.75-1.75Zm-2 12c0-.966.784-1.75 1.75-1.75h17.5c.966 0 1.75.784 1.75 1.75v4a1.75 1.75 0 0 1-1.75 1.75H3.25a1.75 1.75 0 0 1-1.75-1.75ZM5.25 3.5a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h13.5a.25.25 0 0 0 .25-.25v-7.5a.25.25 0 0 0-.25-.25Zm-2 12a.25.25 0 0 0-.25.25v4c0 .138.112.25.25.25h17.5a.25.25 0 0 0 .25-.25v-4a.25.25 0 0 0-.25-.25Z">
#                    </path>
#                    <path d="M10 17.75a.75.75 0 0 1 .75-.75h6.5a.75.75 0 0 1 0 1.5h-6.5a.75.75 0 0 1-.75-.75Zm-4 0a.75.75 0 0 1 .75-.75h.5a.75.75 0 0 1 0 1.5h-.5a.75.75 0 0 1-.75-.75Z">
#                    </path>
#                   </svg>
#                   <div>
#                    <div class="color-fg-default h4">
#                     Codespaces
#                    </div>
#                    Instant dev environments
#                   </div>
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"issues","context":"product","tag":"link","label":"issues_link_product_navbar"}' href="https://github.com/features/issues">
#                   <svg aria-hidden="true" class="octicon octicon-issue-opened color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#                    <path d="M12 1c6.075 0 11 4.925 11 11s-4.925 11-11 11S1 18.075 1 12 5.925 1 12 1ZM2.5 12a9.5 9.5 0 0 0 9.5 9.5 9.5 9.5 0 0 0 9.5-9.5A9.5 9.5 0 0 0 12 2.5 9.5 9.5 0 0 0 2.5 12Zm9.5 2a2 2 0 1 1-.001-3.999A2 2 0 0 1 12 14Z">
#                    </path>
#                   </svg>
#                   <div>
#                    <div class="color-fg-default h4">
#                     Issues
#                    </div>
#                    Plan and track work
#                   </div>
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"code_review","context":"product","tag":"link","label":"code_review_link_product_navbar"}' href="https://github.com/features/code-review">
#                   <svg aria-hidden="true" class="octicon octicon-code-review color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#                    <path d="M10.3 6.74a.75.75 0 0 1-.04 1.06l-2.908 2.7 2.908 2.7a.75.75 0 1 1-1.02 1.1l-3.5-3.25a.75.75 0 0 1 0-1.1l3.5-3.25a.75.75 0 0 1 1.06.04Zm3.44 1.06a.75.75 0 1 1 1.02-1.1l3.5 3.25a.75.75 0 0 1 0 1.1l-3.5 3.25a.75.75 0 1 1-1.02-1.1l2.908-2.7-2.908-2.7Z">
#                    </path>
#                    <path d="M1.5 4.25c0-.966.784-1.75 1.75-1.75h17.5c.966 0 1.75.784 1.75 1.75v12.5a1.75 1.75 0 0 1-1.75 1.75h-9.69l-3.573 3.573A1.458 1.458 0 0 1 5 21.043V18.5H3.25a1.75 1.75 0 0 1-1.75-1.75ZM3.25 4a.25.25 0 0 0-.25.25v12.5c0 .138.112.25.25.25h2.5a.75.75 0 0 1 .75.75v3.19l3.72-3.72a.749.749 0 0 1 .53-.22h10a.25.25 0 0 0 .25-.25V4.25a.25.25 0 0 0-.25-.25Z">
#                    </path>
#                   </svg>
#                   <div>
#                    <div class="color-fg-default h4">
#                     Code Review
#                    </div>
#                    Manage code changes
#                   </div>
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"discussions","context":"product","tag":"link","label":"discussions_link_product_navbar"}' href="https://github.com/features/discussions">
#                   <svg aria-hidden="true" class="octicon octicon-comment-discussion color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#                    <path d="M1.75 1h12.5c.966 0 1.75.784 1.75 1.75v9.5A1.75 1.75 0 0 1 14.25 14H8.061l-2.574 2.573A1.458 1.458 0 0 1 3 15.543V14H1.75A1.75 1.75 0 0 1 0 12.25v-9.5C0 1.784.784 1 1.75 1ZM1.5 2.75v9.5c0 .138.112.25.25.25h2a.75.75 0 0 1 .75.75v2.19l2.72-2.72a.749.749 0 0 1 .53-.22h6.5a.25.25 0 0 0 .25-.25v-9.5a.25.25 0 0 0-.25-.25H1.75a.25.25 0 0 0-.25.25Z">
#                    </path>
#                    <path d="M22.5 8.75a.25.25 0 0 0-.25-.25h-3.5a.75.75 0 0 1 0-1.5h3.5c.966 0 1.75.784 1.75 1.75v9.5A1.75 1.75 0 0 1 22.25 20H21v1.543a1.457 1.457 0 0 1-2.487 1.03L15.939 20H10.75A1.75 1.75 0 0 1 9 18.25v-1.465a.75.75 0 0 1 1.5 0v1.465c0 .138.112.25.25.25h5.5a.75.75 0 0 1 .53.22l2.72 2.72v-2.19a.75.75 0 0 1 .75-.75h2a.25.25 0 0 0 .25-.25v-9.5Z">
#                    </path>
#                   </svg>
#                   <div>
#                    <div class="color-fg-default h4">
#                     Discussions
#                    </div>
#                    Collaborate outside of code
#                   </div>
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description" data-analytics-event='{"location":"navbar","action":"code_search","context":"product","tag":"link","label":"code_search_link_product_navbar"}' href="https://github.com/features/code-search">
#                   <svg aria-hidden="true" class="octicon octicon-code-square color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#                    <path d="M10.3 8.24a.75.75 0 0 1-.04 1.06L7.352 12l2.908 2.7a.75.75 0 1 1-1.02 1.1l-3.5-3.25a.75.75 0 0 1 0-1.1l3.5-3.25a.75.75 0 0 1 1.06.04Zm3.44 1.06a.75.75 0 1 1 1.02-1.1l3.5 3.25a.75.75 0 0 1 0 1.1l-3.5 3.25a.75.75 0 1 1-1.02-1.1l2.908-2.7-2.908-2.7Z">
#                    </path>
#                    <path d="M2 3.75C2 2.784 2.784 2 3.75 2h16.5c.966 0 1.75.784 1.75 1.75v16.5A1.75 1.75 0 0 1 20.25 22H3.75A1.75 1.75 0 0 1 2 20.25Zm1.75-.25a.25.25 0 0 0-.25.25v16.5c0 .138.112.25.25.25h16.5a.25.25 0 0 0 .25-.25V3.75a.25.25 0 0 0-.25-.25Z">
#                    </path>
#                   </svg>
#                   <div>
#                    <div class="color-fg-default h4">
#                     Code Search
#                    </div>
#                    Find more, search less
#                   </div>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#              <div class="HeaderMenu-column px-lg-4">
#               <div class="border-bottom pb-3 pb-lg-0 border-lg-bottom-0 border-bottom-0">
#                <span class="d-block h4 color-fg-default my-1" id="product-explore-heading">
#                 Explore
#                </span>
#                <ul aria-labelledby="product-explore-heading" class="list-style-none f5">
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"all_features","context":"product","tag":"link","label":"all_features_link_product_navbar"}' href="https://github.com/features">
#                   All features
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary Link--external" data-analytics-event='{"location":"navbar","action":"documentation","context":"product","tag":"link","label":"documentation_link_product_navbar"}' href="https://docs.github.com" target="_blank">
#                   Documentation
#                   <svg aria-hidden="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#                    <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z">
#                    </path>
#                   </svg>
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary Link--external" data-analytics-event='{"location":"navbar","action":"github_skills","context":"product","tag":"link","label":"github_skills_link_product_navbar"}' href="https://skills.github.com" target="_blank">
#                   GitHub Skills
#                   <svg aria-hidden="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#                    <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z">
#                    </path>
#                   </svg>
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary Link--external" data-analytics-event='{"location":"navbar","action":"blog","context":"product","tag":"link","label":"blog_link_product_navbar"}' href="https://github.blog" target="_blank">
#                   Blog
#                   <svg aria-hidden="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#                    <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z">
#                    </path>
#                   </svg>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </div>
#            </li>
#            <li class="HeaderMenu-item position-relative flex-wrap flex-justify-between flex-items-center d-block d-lg-flex flex-lg-nowrap flex-lg-items-center js-details-container js-header-menu-item">
#             <button aria-expanded="false" class="HeaderMenu-link border-0 width-full width-lg-auto px-0 px-lg-2 py-lg-2 no-wrap d-flex flex-items-center flex-justify-between js-details-target" type="button">
#              Solutions
#              <svg aria-hidden="true" class="octicon octicon-chevron-down HeaderMenu-icon ml-1" data-view-component="true" height="16" opacity="0.5" version="1.1" viewbox="0 0 16 16" width="16">
#               <path d="M12.78 5.22a.749.749 0 0 1 0 1.06l-4.25 4.25a.749.749 0 0 1-1.06 0L3.22 6.28a.749.749 0 1 1 1.06-1.06L8 8.939l3.72-3.719a.749.749 0 0 1 1.06 0Z">
#               </path>
#              </svg>
#             </button>
#             <div class="HeaderMenu-dropdown dropdown-menu rounded m-0 p-0 pt-2 pt-lg-4 position-relative position-lg-absolute left-0 left-lg-n3 d-lg-flex flex-wrap dropdown-menu-wide">
#              <div class="HeaderMenu-column px-lg-4 border-lg-right mb-4 mb-lg-0 pr-lg-7">
#               <div class="border-bottom pb-3 pb-lg-0 border-lg-bottom-0 pb-lg-3 mb-3 mb-lg-0">
#                <span class="d-block h4 color-fg-default my-1" id="solutions-by-company-size-heading">
#                 By company size
#                </span>
#                <ul aria-labelledby="solutions-by-company-size-heading" class="list-style-none f5">
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"enterprises","context":"solutions","tag":"link","label":"enterprises_link_solutions_navbar"}' href="https://github.com/enterprise">
#                   Enterprises
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"small_and_medium_teams","context":"solutions","tag":"link","label":"small_and_medium_teams_link_solutions_navbar"}' href="https://github.com/team">
#                   Small and medium teams
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"startups","context":"solutions","tag":"link","label":"startups_link_solutions_navbar"}' href="https://github.com/enterprise/startups">
#                   Startups
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"nonprofits","context":"solutions","tag":"link","label":"nonprofits_link_solutions_navbar"}' href="/solutions/industry/nonprofits">
#                   Nonprofits
#                  </a>
#                 </li>
#                </ul>
#               </div>
#               <div class="border-bottom pb-3 pb-lg-0 border-lg-bottom-0">
#                <span class="d-block h4 color-fg-default my-1" id="solutions-by-use-case-heading">
#                 By use case
#                </span>
#                <ul aria-labelledby="solutions-by-use-case-heading" class="list-style-none f5">
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"devsecops","context":"solutions","tag":"link","label":"devsecops_link_solutions_navbar"}' href="/solutions/use-case/devsecops">
#                   DevSecOps
#                  </a>
#                 </li>
#                 <li>
# ...
#          </a>
#          <a class="no-underline flex-1 d-flex flex-column" href="/topics/crystal">
#           <p class="f3 lh-condensed mb-0 mt-1 Link--primary">
#            Crystal
#           </p>
#           <p class="f5 color-fg-muted mb-0 mt-1">
#            Crystal is a self-hosted, general purpose programming language.
#           </p>
#          </a>
#          <div class="flex-grow-0">
#           <div class="d-block" data-view-component="true">
#            <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-sw btn-sm btn" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":null,"auth_type":"LOG_IN","originating_url":"https://github.com/topics","user_id":null}}' data-hydro-click-hmac="7575b5082e2c3915281be9460d747ad48fe377ebd620d4e12e2387269c69459c" data-view-component="true" href="/login?return_to=%2Ftopic.crystal" rel="nofollow">
#             <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#              <path d="M8 .25a.75.75 0 0 1 .673.418l1.882 3.815 4.21.612a.75.75 0 0 1 .416 1.279l-3.046 2.97.719 4.192a.751.751 0 0 1-1.088.791L8 12.347l-3.766 1.98a.75.75 0 0 1-1.088-.79l.72-4.194L.818 6.374a.75.75 0 0 1 .416-1.28l4.21-.611L7.327.668A.75.75 0 0 1 8 .25Zm0 2.445L6.615 5.5a.75.75 0 0 1-.564.41l-3.097.45 2.24 2.184a.75.75 0 0 1 .216.664l-.528 3.084 2.769-1.456a.75.75 0 0 1 .698 0l2.77 1.456-.53-3.084a.75.75 0 0 1 .216-.664l2.24-2.183-3.096-.45a.75.75 0 0 1-.564-.41L8 2.694Z">
#              </path>
#             </svg>
#             <span class="d-inline" data-view-component="true">
#              Star
#             </span>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#        <!-- '"` -->
#        <!-- </textarea></xmp> -->
#        <form accept-charset="UTF-8" action="/topics" class="ajax-pagination-form js-ajax-pagination" data-turbo="false" method="get">
#         <input name="page" type="hidden" value="2"/>
#         <button class="ajax-pagination-btn btn mt-4 py-2 color-border-default f6 width-full" data-disable-with="Loading more..." type="submit">
#          Load more…
#         </button>
#        </form>
#       </div>
#       <div class="col-lg-3">
#        <h2 class="h4 mb-2">
#         Popular topics
#        </h2>
#        <ul class="col-sm-6 col-md-4 col-lg-12 list-style-none flex-wrap">
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to javascript, location:popular topics" data-view-component="true" href="/topics/javascript" title="Topic: javascript">
#           javascript
#          </a>
#         </li>
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to game, location:popular topics" data-view-component="true" href="/topics/game" title="Topic: game">
#           game
#          </a>
#         </li>
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to config, location:popular topics" data-view-component="true" href="/topics/config" title="Topic: config">
#           config
#          </a>
#         </li>
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to python, location:popular topics" data-view-component="true" href="/topics/python" title="Topic: python">
#           python
#          </a>
#         </li>
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to java, location:popular topics" data-view-component="true" href="/topics/java" title="Topic: java">
#           java
#          </a>
#         </li>
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to docker, location:popular topics" data-view-component="true" href="/topics/docker" title="Topic: docker">
#           docker
#          </a>
#         </li>
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to machine-learning, location:popular topics" data-view-component="true" href="/topics/machine-learning" title="Topic: machine-learning">
#           machine-learning
#          </a>
#         </li>
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to typescript, location:popular topics" data-view-component="true" href="/topics/typescript" title="Topic: typescript">
#           typescript
#          </a>
#         </li>
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to computer-vision, location:popular topics" data-view-component="true" href="/topics/computer-vision" title="Topic: computer-vision">
#           computer-vision
#          </a>
#         </li>
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to github-config, location:popular topics" data-view-component="true" href="/topics/github-config" title="Topic: github-config">
#           github-config
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </main>
#    </div>
#    <footer class="footer pt-8 pb-6 f6 color-fg-muted p-responsive" role="contentinfo">
#     <h2 class="sr-only">
#      Footer
#     </h2>
#     <div class="d-flex flex-justify-center flex-items-center flex-column-reverse flex-lg-row flex-wrap flex-lg-nowrap">
#      <div class="d-flex flex-items-center flex-shrink-0 mx-2">
#       <a aria-label="Homepage" class="footer-octicon mr-2" href="https://github.com" title="GitHub">
#        <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#         <path d="M12 1C5.9225 1 1 5.9225 1 12C1 16.8675 4.14875 20.9787 8.52125 22.4362C9.07125 22.5325 9.2775 22.2025 9.2775 21.9137C9.2775 21.6525 9.26375 20.7862 9.26375 19.865C6.5 20.3737 5.785 19.1912 5.565 18.5725C5.44125 18.2562 4.905 17.28 4.4375 17.0187C4.0525 16.8125 3.5025 16.3037 4.42375 16.29C5.29 16.2762 5.90875 17.0875 6.115 17.4175C7.105 19.0812 8.68625 18.6137 9.31875 18.325C9.415 17.61 9.70375 17.1287 10.02 16.8537C7.5725 16.5787 5.015 15.63 5.015 11.4225C5.015 10.2262 5.44125 9.23625 6.1425 8.46625C6.0325 8.19125 5.6475 7.06375 6.2525 5.55125C6.2525 5.55125 7.17375 5.2625 9.2775 6.67875C10.1575 6.43125 11.0925 6.3075 12.0275 6.3075C12.9625 6.3075 13.8975 6.43125 14.7775 6.67875C16.8813 5.24875 17.8025 5.55125 17.8025 5.55125C18.4075 7.06375 18.0225 8.19125 17.9125 8.46625C18.6138 9.23625 19.04 10.2125 19.04 11.4225C19.04 15.6437 16.4688 16.5787 14.0213 16.8537C14.42 17.1975 14.7638 17.8575 14.7638 18.8887C14.7638 20.36 14.75 21.5425 14.75 21.9137C14.75 22.2025 14.9563 22.5462 15.5063 22.4362C19.8513 20.9787 23 16.8537 23 12C23 5.9225 18.0775 1 12 1Z">
#         </path>
#        </svg>
#       </a>
#       <span>
#        © 2025 GitHub, Inc.
#       </span>
#      </div>
#      <nav aria-label="Footer">
#       <h3 class="sr-only" id="sr-footer-heading">
#        Footer navigation
#       </h3>
#       <ul aria-labelledby="sr-footer-heading" class="list-style-none d-flex flex-justify-center flex-wrap mb-2 mb-lg-0">
#        <li class="mx-2">
#         <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to Terms","label":"text:terms"}' data-view-component="true" href="https://docs.github.com/site-policy/github-terms/github-terms-of-service">
#          Terms
#         </a>
#        </li>
#        <li class="mx-2">
#         <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to privacy","label":"text:privacy"}' data-view-component="true" href="https://docs.github.com/site-policy/privacy-policies/github-privacy-statement">
#          Privacy
#         </a>
#        </li>
#        <li class="mx-2">
#         <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to security","label":"text:security"}' data-view-component="true" href="https://github.com/security">
#          Security
#         </a>
#        </li>
#        <li class="mx-2">
#         <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to status","label":"text:status"}' data-view-component="true" href="https://www.githubstatus.com/">
#          Status
#         </a>
#        </li>
#        <li class="mx-2">
#         <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to docs","label":"text:docs"}' data-view-component="true" href="https://docs.github.com/">
#          Docs
#         </a>
#        </li>
#        <li class="mx-2">
#         <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to contact","label":"text:contact"}' data-view-component="true" href="https://support.github.com?tags=dotcom-footer">
#          Contact
#         </a>
#        </li>
#        <li class="mx-2">
#         <cookie-consent-link>
#          <button class="Link--secondary underline-on-hover border-0 p-0 color-bg-transparent" data-action="click:cookie-consent-link#showConsentManagement" data-analytics-event='{"location":"footer","action":"cookies","context":"subfooter","tag":"link","label":"cookies_link_subfooter_footer"}' type="button">
#           Manage cookies
#          </button>
#         </cookie-consent-link>
#        </li>
#        <li class="mx-2">
#         <cookie-consent-link>
#          <button class="Link--secondary underline-on-hover border-0 p-0 color-bg-transparent" data-action="click:cookie-consent-link#showConsentManagement" data-analytics-event='{"location":"footer","action":"dont_share_info","context":"subfooter","tag":"link","label":"dont_share_info_link_subfooter_footer"}' type="button">
#           Do not share my personal information
#          </button>
#         </cookie-consent-link>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </footer>
#    <ghcc-consent class="position-fixed bottom-0 left-0" data-cookie-consent-required="false" data-initial-cookie-consent-allowed="" id="ghcc" style="z-index: 999999">
#    </ghcc-consent>
#    <div class="ajax-error-message flash flash-error" hidden="" id="ajax-error-message">
#     <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#      <path d="M6.457 1.047c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0 1 14.082 15H1.918a1.75 1.75 0 0 1-1.543-2.575Zm1.763.707a.25.25 0 0 0-.44 0L1.698 13.132a.25.25 0 0 0 .22.368h12.164a.25.25 0 0 0 .22-.368Zm.53 3.996v2.5a.75.75 0 0 1-1.5 0v-2.5a.75.75 0 0 1 1.5 0ZM9 11a1 1 0 1 1-2 0 1 1 0 0 1 2 0Z">
#      </path>
#     </svg>
#     <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
#      <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#       <path d="M3.72 3.72a.75.75 0 0 1 1.06 0L8 6.94l3.22-3.22a.749.749 0 0 1 1.275.326.749.749 0 0 1-.215.734L9.06 8l3.22 3.22a.749.749 0 0 1-.326 1.275.749.749 0 0 1-.734-.215L8 9.06l-3.22 3.22a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042L6.94 8 3.72 4.78a.75.75 0 0 1 0-1.06Z">
#       </path>
#      </svg>
#     </button>
#     You can’t perform that action at this time.
#    </div>
#    <template id="site-details-dialog">
#     <details class="details-reset details-overlay details-overlay-dark lh-default color-fg-default hx_rsm" open="">
#      <summary aria-label="Close dialog" role="button">
#      </summary>
#      <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
#       <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
#        <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#         <path d="M3.72 3.72a.75.75 0 0 1 1.06 0L8 6.94l3.22-3.22a.749.749 0 0 1 1.275.326.749.749 0 0 1-.215.734L9.06 8l3.22 3.22a.749.749 0 0 1-.326 1.275.749.749 0 0 1-.734-.215L8 9.06l-3.22 3.22a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042L6.94 8 3.72 4.78a.75.75 0 0 1 0-1.06Z">
#         </path>
#        </svg>
#       </button>
#       <div class="octocat-spinner my-6 js-details-dialog-spinner">
#       </div>
#      </details-dialog>
#     </details>
#    </template>
#    <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;">
#     <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
#     </div>
#    </div>
#    <template id="snippet-clipboard-copy-button">
#     <div class="zeroclipboard-container position-absolute right-0 top-0">
#      <clipboard-copy aria-label="Copy" class="ClipboardButton btn js-clipboard-copy m-2 p-0" data-copy-feedback="Copied!" data-tooltip-direction="w">
#       <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#        <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 0 1 0 1.5h-1.5a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-1.5a.75.75 0 0 1 1.5 0v1.5A1.75 1.75 0 0 1 9.25 16h-7.5A1.75 1.75 0 0 1 0 14.25Z">
#        </path>
#        <path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0 1 14.25 11h-7.5A1.75 1.75 0 0 1 5 9.25Zm1.75-.25a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-7.5a.25.25 0 0 0-.25-.25Z">
#        </path>
#       </svg>
#       <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#        <path d="M13.78 4.22a.75.75 0 0 1 0 1.06l-7.25 7.25a.75.75 0 0 1-1.06 0L2.22 9.28a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L6 10.94l6.72-6.72a.75.75 0 0 1 1.06 0Z">
#        </path>
#       </svg>
#      </clipboard-copy>
#     </div>
#    </template>
#    <template id="snippet-clipboard-copy-button-unpositioned">
#     <div class="zeroclipboard-container">
#      <clipboard-copy aria-label="Copy" class="ClipboardButton btn btn-invisible js-clipboard-copy m-2 p-0 d-flex flex-justify-center flex-items-center" data-copy-feedback="Copied!" data-tooltip-direction="w">
#       <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#        <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 0 1 0 1.5h-1.5a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-1.5a.75.75 0 0 1 1.5 0v1.5A1.75 1.75 0 0 1 9.25 16h-7.5A1.75 1.75 0 0 1 0 14.25Z">
#        </path>
#        <path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0 1 14.25 11h-7.5A1.75 1.75 0 0 1 5 9.25Zm1.75-.25a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-7.5a.25.25 0 0 0-.25-.25Z">
#        </path>
#       </svg>
#       <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#        <path d="M13.78 4.22a.75.75 0 0 1 0 1.06l-7.25 7.25a.75.75 0 0 1-1.06 0L2.22 9.28a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L6 10.94l6.72-6.72a.75.75 0 0 1 1.06 0Z">
#        </path>
#       </svg>
#      </clipboard-copy>
#     </div>
#    </template>
#   </div>
#   <div aria-atomic="true" aria-live="polite" class="sr-only mt-n1" id="js-global-screen-reader-notice">
#   </div>
#   <div aria-atomic="true" aria-live="assertive" class="sr-only mt-n1" id="js-global-screen-reader-notice-assertive">
#   </div>
#  </body>
# </html>

# %%
# Prints formatted HTML
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-a11y-animated-images="system" data-a11y-link-underlines="true" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://github.githubassets.com" rel="dns-prefetch"/>
#   <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
#   <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
#   <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
#   <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/light-74231a1f3bbb.css" media="all" rel="stylesheet">
#    <link crossorigin="anonymous" href="https://github.githubassets.com/assets/dark-8a995f0bacd4.css" media="all" rel="stylesheet">
#     <link crossorigin="anonymous" data-color-theme="dark_dimmed" data-href="https://github.githubassets.com/assets/dark_dimmed-f37fb7684b1f.css" media="all" rel="stylesheet">
#      <link crossorigin="anonymous" data-color-theme="dark_high_contrast" data-href="https://github.githubassets.com/assets/dark_high_contrast-9ac301c3ebe5.css" media="all" rel="stylesheet">
#       <link crossorigin="anonymous" data-color-theme="dark_colorblind" data-href="https://github.githubassets.com/assets/dark_colorblind-cd826e8636dc.css" media="all" rel="stylesheet">
#        <link crossorigin="anonymous" data-color-theme="light_colorblind" data-href="https://github.githubassets.com/assets/light_colorblind-f91b0f603451.css" media="all" rel="stylesheet">
#         <link crossorigin="anonymous" data-color-theme="light_high_contrast" data-href="https://github.githubassets.com/assets/light_high_contrast-83beb16e0ecf.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" data-color-theme="light_tritanopia" data-href="https://github.githubassets.com/assets/light_tritanopia-6e122dab64fc.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" data-color-theme="dark_tritanopia" data-href="https://github.githubassets.com/assets/dark_tritanopia-18119e682df0.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://github.githubassets.com/assets/primer-primitives-225433424a87.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://github.githubassets.com/assets/primer-aaa714e5674d.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://github.githubassets.com/assets/global-0a3c53b9d1c2.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://github.githubassets.com/assets/github-ea73c9cb5377.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://github.githubassets.com/assets/site-3e72ff5534e0.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://github.githubassets.com/assets/explore-742a7653565b.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://github.githubassets.com/assets/dashboard-0de2bd46c6d8.css" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://github.githubassets.com/assets/discussions-dae9ae1a46a6.css" media="all" rel="stylesheet"/>
#         <script id="client-env" type="application/json">
#          {"locale":"en","featureFlags":["a11y_quote_reply_fix","copilot_immersive_issue_preview","copilot_new_references_ui","copilot_chat_repo_custom_instructions_preview","copilot_no_floating_button","copilot_topics_as_references","copilot_read_shared_conversation","copilot_duplicate_thread","copilot_buffered_streaming","dotcom_chat_client_side_skills","experimentation_azure_variant_endpoint","failbot_handle_non_errors","geojson_azure_maps","ghost_pilot_confidence_truncation_25","ghost_pilot_confidence_truncation_40","github_models_gateway_parse_params","github_models_o3_mini_streaming","insert_before_patch","issues_react_remove_placeholders","issues_react_blur_item_picker_on_close","marketing_pages_search_explore_provider","primer_react_css_modules_ga","react_data_router_pull_requests","remove_child_patch","sample_network_conn_type","swp_enterprise_contact_form","site_proxima_australia_update","viewscreen_sandbox","issues_react_create_milestone","issues_react_cache_fix_workaround","lifecycle_label_name_updates","copilot_task_oriented_assistive_prompts","issue_types_prevent_private_type_creation","refresh_image_video_src","react_router_dispose_on_disconnect","codespaces_prebuild_region_target_update","turbo_app_id_restore","copilot_code_review_sign_up_closed"]}
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/wp-runtime-900d20148682.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_oddbird_popover-polyfill_dist_popover_js-9da652f58479.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_arianotify-polyfill_ariaNotify-polyfill_js-node_modules_github_mi-3abb8f-46b9f4874d95.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/ui_packages_failbot_failbot_ts-75968cfb5298.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/environment-f04cb2a9fc8c.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_primer_behaviors_dist_esm_index_mjs-0dbb79f97f8f.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_selector-observer_dist_index_esm_js-f690fd9ae3d5.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_relative-time-element_dist_index_js-62d275b7ddd9.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_text-expander-element_dist_index_js-78748950cb0c.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_auto-complete-element_dist_index_js-node_modules_github_catalyst_-8e9f78-a90ac05d2469.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_filter-input-element_dist_index_js-node_modules_github_remote-inp-b5f1d7-a1760ffda83d.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_markdown-toolbar-element_dist_index_js-ceef33f593fa.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_file-attachment-element_dist_index_js-node_modules_primer_view-co-c44a69-efa32db3a345.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/github-elements-394f8eb34f19.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/element-registry-25113a65b77f.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_braintree_browser-detection_dist_browser-detection_js-node_modules_githu-2906d7-2a07a295af40.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_lit-html_lit-html_js-be8cb88f481b.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_mini-throttle_dist_index_js-node_modules_morphdom_dist_morphdom-e-7c534c-a4a1922eb55f.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_turbo_dist_turbo_es2017-esm_js-a03ee12d659a.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_delegated-events_dist_inde-893f9f-b6294cf703b7.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_color-convert_index_js-e3180fe3bcb3.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_quote-selection_dist_index_js-node_modules_github_session-resume_-947061-e7a6c4a19f98.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/ui_packages_updatable-content_updatable-content_ts-eb3147a21e96.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_task-list_ts-app_assets_modules_github_sso_ts-ui_packages-900dde-768abe60b1f8.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/app_assets_modules_github_sticky-scroll-into-view_ts-3e000c5d31a9.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_ajax-error_ts-app_assets_modules_github_behaviors_include-87a4ae-4c160a67a3f8.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_commenting_edit_ts-app_assets_modules_github_behaviors_ht-83c235-e429cff6ceb1.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/behaviors-1f167e0c2aee.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_github_catalyst_lib_index_js-f6223d90c7ba.js" type="application/javascript">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/notifications-global-01e85cd1be94.js" type="application/javascript">
#         </script>
#         <title>
#          Topics on GitHub · GitHub
#         </title>
#         <meta content="/topics(.:format)" data-turbo-transient="" name="route-pattern"/>
#         <meta content="topics" data-turbo-transient="" name="route-controller"/>
#         <meta content="index" data-turbo-transient="" name="route-action"/>
#         <meta content="82c569b93da5c18ed649ebd4c2c79437db4611a6a1373e805a3cb001c64130b7" name="current-catalog-service-hash"/>
#         <meta content="E13A:99E34:153637:1B8FB8:67E96907" data-pjax-transient="true" name="request-id">
#          <meta content="a5016707e7ea34d51780c28c782d17df7c1a209ca58eb2497674c1c5963fb396" data-pjax-transient="true" name="html-safe-nonce">
#           <meta content="eyJyZWZlcnJlciI6IiIsInJlcXVlc3RfaWQiOiJFMTNBOjk5RTM0OjE1MzYzNzoxQjhGQjg6NjdFOTY5MDciLCJ2aXNpdG9yX2lkIjoiMjY1NjM0MDkzMzkwNzkzMzQ0NyIsInJlZ2lvbl9lZGdlIjoiaWFkIiwicmVnaW9uX3JlbmRlciI6ImlhZCJ9" data-pjax-transient="true" name="visitor-payload">
#            <meta content="694c276884e03840269f51e950b7e412c20f24f1367e96d8f523b7f1f46dfb5c" data-pjax-transient="true" name="visitor-hmac">
#             <meta content="copilot" data-turbo-transient="true" name="github-keyboard-shortcuts">
#              <meta data-turbo-transient="" name="selected-link" value="/topics"/>
#              <link href="https://github.githubassets.com/" rel="assets"/>
#              <meta content="Apib7-x98H0j5cPqHWwSMm6dNU4GmODRoqxLiDzdx9I" name="google-site-verification"/>
#              <meta content="https://collector.github.com/github/collect" name="octolytics-url">
#               <meta content="" name="user-login"/>
#               <meta content="width=device-width" name="viewport"/>
#               <meta content="GitHub is where people build software. More than 150 million people use GitHub to discover, fork, and contribute to over 420 million projects." name="description"/>
#               <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
#               <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
#               <meta content="1401488693436528" property="fb:app_id"/>
#               <meta content="app-id=1477376905, app-argument=https://github.com/topics" name="apple-itunes-app">
#                <meta content="https://github.com" property="og:url"/>
#                <meta content="GitHub" property="og:site_name"/>
#                <meta content="Build software better, together" property="og:title"/>
#                <meta content="GitHub is where people build software. More than 150 million people use GitHub to discover, fork, and contribute to over 420 million projects." property="og:description"/>
#                <meta content="https://github.githubassets.com/assets/github-logo-55c5b9a1fe52.png" property="og:image"/>
#                <meta content="image/png" property="og:image:type"/>
#                <meta content="1200" property="og:image:width"/>
#                <meta content="1200" property="og:image:height"/>
#                <meta content="https://github.githubassets.com/assets/github-mark-57519b92ca4e.png" property="og:image"/>
#                <meta content="image/png" property="og:image:type"/>
#                <meta content="1200" property="og:image:width"/>
#                <meta content="620" property="og:image:height"/>
#                <meta content="https://github.githubassets.com/assets/github-octocat-13c86b8b336d.png" property="og:image"/>
#                <meta content="image/png" property="og:image:type"/>
#                <meta content="1200" property="og:image:width"/>
#                <meta content="620" property="og:image:height"/>
#                <meta content="github" property="twitter:site"/>
#                <meta content="13334762" property="twitter:site:id"/>
#                <meta content="github" property="twitter:creator"/>
#                <meta content="13334762" property="twitter:creator:id"/>
#                <meta content="summary_large_image" property="twitter:card"/>
#                <meta content="GitHub" property="twitter:title"/>
#                <meta content="GitHub is where people build software. More than 150 million people use GitHub to discover, fork, and contribute to over 420 million projects." property="twitter:description"/>
#                <meta content="https://github.githubassets.com/assets/github-logo-55c5b9a1fe52.png" property="twitter:image"/>
#                <meta content="1200" property="twitter:image:width"/>
#                <meta content="1200" property="twitter:image:height"/>
#                <meta content="github.com" name="hostname"/>
#                <meta content="github.com" name="expected-hostname"/>
#                <meta content="154e3ed6ec9e0d6fff5da6846be55e3cefb81f7aa557cdcfe2a45d929fc158d2" data-turbo-track="reload" http-equiv="x-pjax-version"/>
#                <meta content="e26f9f0ba624ee85cc7ac057d8faa8618a4f25a85eab052c33d018ac0f6b1a46" data-turbo-track="reload" http-equiv="x-pjax-csp-version"/>
#                <meta content="159e03504eed5183f9787c72780a7d8c1460af30746ab09d728b048c41719efa" data-turbo-track="reload" http-equiv="x-pjax-css-version"/>
#                <meta content="3ef84064f1c111becc704df35223db168ecae977ac2d9ec422601ed98490e586" data-turbo-track="reload" http-equiv="x-pjax-js-version"/>
#                <meta content="no-preview" data-turbo-transient="" name="turbo-cache-control"/>
#                <link data-turbo-transient="" href="https://github.com/topics" rel="canonical"/>
#                <meta content="logged-out env-production page-responsive" name="turbo-body-classes"/>
#                <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
#                <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
#                <meta content="a809ed19c131f846b28e5314dd87328a15e02a37" name="release"/>
#                <link color="#000000" href="https://github.githubassets.com/assets/pinned-octocat-093da3e6fa40.svg" rel="mask-icon"/>
#                <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.png" rel="alternate icon" type="image/png"/>
#                <link class="js-site-favicon" data-base-href="https://github.githubassets.com/favicons/favicon" href="https://github.githubassets.com/favicons/favicon.svg" rel="icon" type="image/svg+xml"/>
#                <meta content="#1e2327" name="theme-color"/>
#                <meta content="light dark" name="color-scheme">
#                 <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
#                </meta>
#               </meta>
#              </meta>
#             </meta>
#            </meta>
#           </meta>
#          </meta>
#         </meta>
#        </link>
#       </link>
#      </link>
#     </link>
#    </link>
#   </link>
#  </head>
#  <body class="logged-out env-production page-responsive" style="word-wrap: break-word;">
#   <div class="logged-out env-production page-responsive" data-turbo-body="" style="word-wrap: break-word;">
#    <div class="position-relative header-wrapper js-header-wrapper">
#     <a class="px-2 py-4 color-bg-accent-emphasis color-fg-on-emphasis show-on-focus js-skip-to-content" data-skip-target-assigned="false" href="#start-of-content">
#      Skip to content
#     </a>
#     <span class="progress-pjax-loader Progress position-fixed width-full" data-view-component="true">
#      <span class="Progress-item progress-pjax-loader-bar left-0 top-0 color-bg-accent-emphasis" data-view-component="true" style="width: 0%;">
#      </span>
#     </span>
#     <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/primer-react-602097a4b0db.js" type="application/javascript">
#     </script>
#     <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/react-core-0bc17999cb79.js" type="application/javascript">
#     </script>
#     <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/react-lib-f1bca44e0926.js" type="application/javascript">
#     </script>
#     <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/octicons-react-cf2f2ab8dab4.js" type="application/javascript">
#     </script>
#     <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_emotion_is-prop-valid_dist_emotion-is-prop-valid_esm_js-node_modules_emo-62da9f-2df2f32ec596.js" type="application/javascript">
#     </script>
#     <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_mini-throttle_dist_index_js-node_modules_stacktrace-parser_dist_s-e7dcdd-9a233856b02c.js" type="application/javascript">
#     </script>
#     <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_oddbird_popover-polyfill_dist_popover-fn_js-55fea94174bf.js" type="application/javascript">
#     </script>
#     <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/ui_packages_ui-commands_ui-commands_ts-2ea4e93613c0.js" type="application/javascript">
#     </script>
#     <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/keyboard-shortcuts-dialog-79d6a754ebf9.js" type="application/javascript">
#     </script>
#     <link crossorigin="anonymous" href="https://github.githubassets.com/assets/primer-react.8157a56b30ae88a1b356.module.css" media="all" rel="stylesheet">
#      <react-partial data-attempted-ssr="false" data-ssr="false" partial-name="keyboard-shortcuts-dialog">
#       <script data-target="react-partial.embeddedData" type="application/json">
#        {"props":{"docsUrl":"https://docs.github.com/get-started/accessibility/keyboard-shortcuts"}}
#       </script>
#       <div data-target="react-partial.reactRoot">
#       </div>
#      </react-partial>
#      <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_delegated-events_dist_inde-94fd67-4898d1bf4b51.js" type="application/javascript">
#      </script>
#      <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/sessions-730dca81d0a2.js" type="application/javascript">
#      </script>
#      <header class="HeaderMktg header-logged-out js-details-container js-header Details f4 py-3" data-color-mode="light" data-dark-theme="dark" data-is-top="true" data-light-theme="light" role="banner">
#       <h2 class="sr-only">
#        Navigation Menu
#       </h2>
#       <button aria-label="Toggle navigation" class="HeaderMktg-backdrop d-lg-none border-0 position-fixed top-0 left-0 width-full height-full js-details-target" type="button">
#        <span class="d-none">
#         Toggle navigation
#        </span>
#       </button>
#       <div class="d-flex flex-column flex-lg-row flex-items-center px-3 px-md-4 px-lg-5 height-full position-relative z-1">
#        <div class="d-flex flex-justify-between flex-items-center width-full width-lg-auto">
#         <div class="flex-1">
#          <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target js-nav-padding-recalculate js-header-menu-toggle Button--link Button--medium Button d-lg-none color-fg-inherit p-1" data-view-component="true" type="button">
#           <span class="Button-content">
#            <span class="Button-label">
#             <div class="HeaderMenu-toggle-bar rounded my-1">
#             </div>
#             <div class="HeaderMenu-toggle-bar rounded my-1">
#             </div>
#             <div class="HeaderMenu-toggle-bar rounded my-1">
#             </div>
#            </span>
#           </span>
#          </button>
#         </div>
#         <a aria-label="Homepage" class="mr-lg-3 color-fg-inherit flex-order-2 js-prevent-focus-on-mobile-nav" data-analytics-event='{"category":"Marketing nav","action":"click to go to homepage","label":"ref_page:Marketing;ref_cta:Logomark;ref_loc:Header"}' href="/">
#          <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="32" version="1.1" viewbox="0 0 24 24" width="32">
#           <path d="M12 1C5.9225 1 1 5.9225 1 12C1 16.8675 4.14875 20.9787 8.52125 22.4362C9.07125 22.5325 9.2775 22.2025 9.2775 21.9137C9.2775 21.6525 9.26375 20.7862 9.26375 19.865C6.5 20.3737 5.785 19.1912 5.565 18.5725C5.44125 18.2562 4.905 17.28 4.4375 17.0187C4.0525 16.8125 3.5025 16.3037 4.42375 16.29C5.29 16.2762 5.90875 17.0875 6.115 17.4175C7.105 19.0812 8.68625 18.6137 9.31875 18.325C9.415 17.61 9.70375 17.1287 10.02 16.8537C7.5725 16.5787 5.015 15.63 5.015 11.4225C5.015 10.2262 5.44125 9.23625 6.1425 8.46625C6.0325 8.19125 5.6475 7.06375 6.2525 5.55125C6.2525 5.55125 7.17375 5.2625 9.2775 6.67875C10.1575 6.43125 11.0925 6.3075 12.0275 6.3075C12.9625 6.3075 13.8975 6.43125 14.7775 6.67875C16.8813 5.24875 17.8025 5.55125 17.8025 5.55125C18.4075 7.06375 18.0225 8.19125 17.9125 8.46625C18.6138 9.23625 19.04 10.2125 19.04 11.4225C19.04 15.6437 16.4688 16.5787 14.0213 16.8537C14.42 17.1975 14.7638 17.8575 14.7638 18.8887C14.7638 20.36 14.75 21.5425 14.75 21.9137C14.75 22.2025 14.9563 22.5462 15.5063 22.4362C19.8513 20.9787 23 16.8537 23 12C23 5.9225 18.0775 1 12 1Z">
#           </path>
#          </svg>
#         </a>
#         <div class="flex-1 flex-order-2 text-right">
#          <a class="HeaderMenu-link HeaderMenu-button d-inline-flex d-lg-none flex-order-1 f5 no-underline border color-border-default rounded-2 px-2 py-1 color-fg-inherit js-prevent-focus-on-mobile-nav" data-analytics-event='{"category":"Marketing nav","action":"click to Sign in","label":"ref_page:Marketing;ref_cta:Sign in;ref_loc:Header"}' data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header menu","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/topics","user_id":null}}' data-hydro-click-hmac="be24ac4990e8cac9a74ee7032b910f8f38a1cea9154e0dbbe2347ce0b38a6adc" href="/login?return_to=https%3A%2F%2Fgithub.com%2Ftopics">
#           Sign in
#          </a>
#         </div>
#        </div>
#        <div class="HeaderMenu js-header-menu height-fit position-lg-relative d-lg-flex flex-column flex-auto top-0">
#         <div class="HeaderMenu-wrapper d-flex flex-column flex-self-start flex-lg-row flex-auto rounded rounded-lg-0">
#          <nav aria-label="Global" class="HeaderMenu-nav">
#           <ul class="d-lg-flex list-style-none">
#            <li class="HeaderMenu-item position-relative flex-wrap flex-justify-between flex-items-center d-block d-lg-flex flex-lg-nowrap flex-lg-items-center js-details-container js-header-menu-item">
#             <button aria-expanded="false" class="HeaderMenu-link border-0 width-full width-lg-auto px-0 px-lg-2 py-lg-2 no-wrap d-flex flex-items-center flex-justify-between js-details-target" type="button">
#              Product
#              <svg aria-hidden="true" class="octicon octicon-chevron-down HeaderMenu-icon ml-1" data-view-component="true" height="16" opacity="0.5" version="1.1" viewbox="0 0 16 16" width="16">
#               <path d="M12.78 5.22a.749.749 0 0 1 0 1.06l-4.25 4.25a.749.749 0 0 1-1.06 0L3.22 6.28a.749.749 0 1 1 1.06-1.06L8 8.939l3.72-3.719a.749.749 0 0 1 1.06 0Z">
#               </path>
#              </svg>
#             </button>
#             <div class="HeaderMenu-dropdown dropdown-menu rounded m-0 p-0 pt-2 pt-lg-4 position-relative position-lg-absolute left-0 left-lg-n3 pb-2 pb-lg-4 d-lg-flex flex-wrap dropdown-menu-wide">
#              <div class="HeaderMenu-column px-lg-4 border-lg-right mb-4 mb-lg-0 pr-lg-7">
#               <div class="border-bottom pb-3 pb-lg-0 border-lg-bottom-0">
#                <ul class="list-style-none f5">
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"github_copilot","context":"product","tag":"link","label":"github_copilot_link_product_navbar"}' href="https://github.com/features/copilot">
#                   <svg aria-hidden="true" class="octicon octicon-copilot color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#                    <path d="M23.922 16.992c-.861 1.495-5.859 5.023-11.922 5.023-6.063 0-11.061-3.528-11.922-5.023A.641.641 0 0 1 0 16.736v-2.869a.841.841 0 0 1 .053-.22c.372-.935 1.347-2.292 2.605-2.656.167-.429.414-1.055.644-1.517a10.195 10.195 0 0 1-.052-1.086c0-1.331.282-2.499 1.132-3.368.397-.406.89-.717 1.474-.952 1.399-1.136 3.392-2.093 6.122-2.093 2.731 0 4.767.957 6.166 2.093.584.235 1.077.546 1.474.952.85.869 1.132 2.037 1.132 3.368 0 .368-.014.733-.052 1.086.23.462.477 1.088.644 1.517 1.258.364 2.233 1.721 2.605 2.656a.832.832 0 0 1 .053.22v2.869a.641.641 0 0 1-.078.256ZM12.172 11h-.344a4.323 4.323 0 0 1-.355.508C10.703 12.455 9.555 13 7.965 13c-1.725 0-2.989-.359-3.782-1.259a2.005 2.005 0 0 1-.085-.104L4 11.741v6.585c1.435.779 4.514 2.179 8 2.179 3.486 0 6.565-1.4 8-2.179v-6.585l-.098-.104s-.033.045-.085.104c-.793.9-2.057 1.259-3.782 1.259-1.59 0-2.738-.545-3.508-1.492a4.323 4.323 0 0 1-.355-.508h-.016.016Zm.641-2.935c.136 1.057.403 1.913.878 2.497.442.544 1.134.938 2.344.938 1.573 0 2.292-.337 2.657-.751.384-.435.558-1.15.558-2.361 0-1.14-.243-1.847-.705-2.319-.477-.488-1.319-.862-2.824-1.025-1.487-.161-2.192.138-2.533.529-.269.307-.437.808-.438 1.578v.021c0 .265.021.562.063.893Zm-1.626 0c.042-.331.063-.628.063-.894v-.02c-.001-.77-.169-1.271-.438-1.578-.341-.391-1.046-.69-2.533-.529-1.505.163-2.347.537-2.824 1.025-.462.472-.705 1.179-.705 2.319 0 1.211.175 1.926.558 2.361.365.414 1.084.751 2.657.751 1.21 0 1.902-.394 2.344-.938.475-.584.742-1.44.878-2.497Z">
#                    </path>
#                    <path d="M14.5 14.25a1 1 0 0 1 1 1v2a1 1 0 0 1-2 0v-2a1 1 0 0 1 1-1Zm-5 0a1 1 0 0 1 1 1v2a1 1 0 0 1-2 0v-2a1 1 0 0 1 1-1Z">
#                    </path>
#                   </svg>
#                   <div>
#                    <div class="color-fg-default h4">
#                     GitHub Copilot
#                    </div>
#                    Write better code with AI
#                   </div>
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"security","context":"product","tag":"link","label":"security_link_product_navbar"}' href="https://github.com/features/security">
#                   <svg aria-hidden="true" class="octicon octicon-shield-check color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#                    <path d="M16.53 9.78a.75.75 0 0 0-1.06-1.06L11 13.19l-1.97-1.97a.75.75 0 0 0-1.06 1.06l2.5 2.5a.75.75 0 0 0 1.06 0l5-5Z">
#                    </path>
#                    <path d="m12.54.637 8.25 2.675A1.75 1.75 0 0 1 22 4.976V10c0 6.19-3.771 10.704-9.401 12.83a1.704 1.704 0 0 1-1.198 0C5.77 20.705 2 16.19 2 10V4.976c0-.758.489-1.43 1.21-1.664L11.46.637a1.748 1.748 0 0 1 1.08 0Zm-.617 1.426-8.25 2.676a.249.249 0 0 0-.173.237V10c0 5.46 3.28 9.483 8.43 11.426a.199.199 0 0 0 .14 0C17.22 19.483 20.5 15.461 20.5 10V4.976a.25.25 0 0 0-.173-.237l-8.25-2.676a.253.253 0 0 0-.154 0Z">
#                    </path>
#                   </svg>
#                   <div>
#                    <div class="color-fg-default h4">
#                     Security
#                    </div>
#                    Find and fix vulnerabilities
#                   </div>
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"actions","context":"product","tag":"link","label":"actions_link_product_navbar"}' href="https://github.com/features/actions">
#                   <svg aria-hidden="true" class="octicon octicon-workflow color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#                    <path d="M1 3a2 2 0 0 1 2-2h6.5a2 2 0 0 1 2 2v6.5a2 2 0 0 1-2 2H7v4.063C7 16.355 7.644 17 8.438 17H12.5v-2.5a2 2 0 0 1 2-2H21a2 2 0 0 1 2 2V21a2 2 0 0 1-2 2h-6.5a2 2 0 0 1-2-2v-2.5H8.437A2.939 2.939 0 0 1 5.5 15.562V11.5H3a2 2 0 0 1-2-2Zm2-.5a.5.5 0 0 0-.5.5v6.5a.5.5 0 0 0 .5.5h6.5a.5.5 0 0 0 .5-.5V3a.5.5 0 0 0-.5-.5ZM14.5 14a.5.5 0 0 0-.5.5V21a.5.5 0 0 0 .5.5H21a.5.5 0 0 0 .5-.5v-6.5a.5.5 0 0 0-.5-.5Z">
#                    </path>
#                   </svg>
#                   <div>
#                    <div class="color-fg-default h4">
#                     Actions
#                    </div>
#                    Automate any workflow
#                   </div>
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"codespaces","context":"product","tag":"link","label":"codespaces_link_product_navbar"}' href="https://github.com/features/codespaces">
#                   <svg aria-hidden="true" class="octicon octicon-codespaces color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#                    <path d="M3.5 3.75C3.5 2.784 4.284 2 5.25 2h13.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0 1 18.75 13H5.25a1.75 1.75 0 0 1-1.75-1.75Zm-2 12c0-.966.784-1.75 1.75-1.75h17.5c.966 0 1.75.784 1.75 1.75v4a1.75 1.75 0 0 1-1.75 1.75H3.25a1.75 1.75 0 0 1-1.75-1.75ZM5.25 3.5a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h13.5a.25.25 0 0 0 .25-.25v-7.5a.25.25 0 0 0-.25-.25Zm-2 12a.25.25 0 0 0-.25.25v4c0 .138.112.25.25.25h17.5a.25.25 0 0 0 .25-.25v-4a.25.25 0 0 0-.25-.25Z">
#                    </path>
#                    <path d="M10 17.75a.75.75 0 0 1 .75-.75h6.5a.75.75 0 0 1 0 1.5h-6.5a.75.75 0 0 1-.75-.75Zm-4 0a.75.75 0 0 1 .75-.75h.5a.75.75 0 0 1 0 1.5h-.5a.75.75 0 0 1-.75-.75Z">
#                    </path>
#                   </svg>
#                   <div>
#                    <div class="color-fg-default h4">
#                     Codespaces
#                    </div>
#                    Instant dev environments
#                   </div>
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"issues","context":"product","tag":"link","label":"issues_link_product_navbar"}' href="https://github.com/features/issues">
#                   <svg aria-hidden="true" class="octicon octicon-issue-opened color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#                    <path d="M12 1c6.075 0 11 4.925 11 11s-4.925 11-11 11S1 18.075 1 12 5.925 1 12 1ZM2.5 12a9.5 9.5 0 0 0 9.5 9.5 9.5 9.5 0 0 0 9.5-9.5A9.5 9.5 0 0 0 12 2.5 9.5 9.5 0 0 0 2.5 12Zm9.5 2a2 2 0 1 1-.001-3.999A2 2 0 0 1 12 14Z">
#                    </path>
#                   </svg>
#                   <div>
#                    <div class="color-fg-default h4">
#                     Issues
#                    </div>
#                    Plan and track work
#                   </div>
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"code_review","context":"product","tag":"link","label":"code_review_link_product_navbar"}' href="https://github.com/features/code-review">
#                   <svg aria-hidden="true" class="octicon octicon-code-review color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#                    <path d="M10.3 6.74a.75.75 0 0 1-.04 1.06l-2.908 2.7 2.908 2.7a.75.75 0 1 1-1.02 1.1l-3.5-3.25a.75.75 0 0 1 0-1.1l3.5-3.25a.75.75 0 0 1 1.06.04Zm3.44 1.06a.75.75 0 1 1 1.02-1.1l3.5 3.25a.75.75 0 0 1 0 1.1l-3.5 3.25a.75.75 0 1 1-1.02-1.1l2.908-2.7-2.908-2.7Z">
#                    </path>
#                    <path d="M1.5 4.25c0-.966.784-1.75 1.75-1.75h17.5c.966 0 1.75.784 1.75 1.75v12.5a1.75 1.75 0 0 1-1.75 1.75h-9.69l-3.573 3.573A1.458 1.458 0 0 1 5 21.043V18.5H3.25a1.75 1.75 0 0 1-1.75-1.75ZM3.25 4a.25.25 0 0 0-.25.25v12.5c0 .138.112.25.25.25h2.5a.75.75 0 0 1 .75.75v3.19l3.72-3.72a.749.749 0 0 1 .53-.22h10a.25.25 0 0 0 .25-.25V4.25a.25.25 0 0 0-.25-.25Z">
#                    </path>
#                   </svg>
#                   <div>
#                    <div class="color-fg-default h4">
#                     Code Review
#                    </div>
#                    Manage code changes
#                   </div>
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event='{"location":"navbar","action":"discussions","context":"product","tag":"link","label":"discussions_link_product_navbar"}' href="https://github.com/features/discussions">
#                   <svg aria-hidden="true" class="octicon octicon-comment-discussion color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#                    <path d="M1.75 1h12.5c.966 0 1.75.784 1.75 1.75v9.5A1.75 1.75 0 0 1 14.25 14H8.061l-2.574 2.573A1.458 1.458 0 0 1 3 15.543V14H1.75A1.75 1.75 0 0 1 0 12.25v-9.5C0 1.784.784 1 1.75 1ZM1.5 2.75v9.5c0 .138.112.25.25.25h2a.75.75 0 0 1 .75.75v2.19l2.72-2.72a.749.749 0 0 1 .53-.22h6.5a.25.25 0 0 0 .25-.25v-9.5a.25.25 0 0 0-.25-.25H1.75a.25.25 0 0 0-.25.25Z">
#                    </path>
#                    <path d="M22.5 8.75a.25.25 0 0 0-.25-.25h-3.5a.75.75 0 0 1 0-1.5h3.5c.966 0 1.75.784 1.75 1.75v9.5A1.75 1.75 0 0 1 22.25 20H21v1.543a1.457 1.457 0 0 1-2.487 1.03L15.939 20H10.75A1.75 1.75 0 0 1 9 18.25v-1.465a.75.75 0 0 1 1.5 0v1.465c0 .138.112.25.25.25h5.5a.75.75 0 0 1 .53.22l2.72 2.72v-2.19a.75.75 0 0 1 .75-.75h2a.25.25 0 0 0 .25-.25v-9.5Z">
#                    </path>
#                   </svg>
#                   <div>
#                    <div class="color-fg-default h4">
#                     Discussions
#                    </div>
#                    Collaborate outside of code
#                   </div>
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description" data-analytics-event='{"location":"navbar","action":"code_search","context":"product","tag":"link","label":"code_search_link_product_navbar"}' href="https://github.com/features/code-search">
#                   <svg aria-hidden="true" class="octicon octicon-code-square color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#                    <path d="M10.3 8.24a.75.75 0 0 1-.04 1.06L7.352 12l2.908 2.7a.75.75 0 1 1-1.02 1.1l-3.5-3.25a.75.75 0 0 1 0-1.1l3.5-3.25a.75.75 0 0 1 1.06.04Zm3.44 1.06a.75.75 0 1 1 1.02-1.1l3.5 3.25a.75.75 0 0 1 0 1.1l-3.5 3.25a.75.75 0 1 1-1.02-1.1l2.908-2.7-2.908-2.7Z">
#                    </path>
#                    <path d="M2 3.75C2 2.784 2.784 2 3.75 2h16.5c.966 0 1.75.784 1.75 1.75v16.5A1.75 1.75 0 0 1 20.25 22H3.75A1.75 1.75 0 0 1 2 20.25Zm1.75-.25a.25.25 0 0 0-.25.25v16.5c0 .138.112.25.25.25h16.5a.25.25 0 0 0 .25-.25V3.75a.25.25 0 0 0-.25-.25Z">
#                    </path>
#                   </svg>
#                   <div>
#                    <div class="color-fg-default h4">
#                     Code Search
#                    </div>
#                    Find more, search less
#                   </div>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#              <div class="HeaderMenu-column px-lg-4">
#               <div class="border-bottom pb-3 pb-lg-0 border-lg-bottom-0 border-bottom-0">
#                <span class="d-block h4 color-fg-default my-1" id="product-explore-heading">
#                 Explore
#                </span>
#                <ul aria-labelledby="product-explore-heading" class="list-style-none f5">
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"all_features","context":"product","tag":"link","label":"all_features_link_product_navbar"}' href="https://github.com/features">
#                   All features
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary Link--external" data-analytics-event='{"location":"navbar","action":"documentation","context":"product","tag":"link","label":"documentation_link_product_navbar"}' href="https://docs.github.com" target="_blank">
#                   Documentation
#                   <svg aria-hidden="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#                    <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z">
#                    </path>
#                   </svg>
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary Link--external" data-analytics-event='{"location":"navbar","action":"github_skills","context":"product","tag":"link","label":"github_skills_link_product_navbar"}' href="https://skills.github.com" target="_blank">
#                   GitHub Skills
#                   <svg aria-hidden="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#                    <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z">
#                    </path>
#                   </svg>
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary Link--external" data-analytics-event='{"location":"navbar","action":"blog","context":"product","tag":"link","label":"blog_link_product_navbar"}' href="https://github.blog" target="_blank">
#                   Blog
#                   <svg aria-hidden="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#                    <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z">
#                    </path>
#                   </svg>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </div>
#            </li>
#            <li class="HeaderMenu-item position-relative flex-wrap flex-justify-between flex-items-center d-block d-lg-flex flex-lg-nowrap flex-lg-items-center js-details-container js-header-menu-item">
#             <button aria-expanded="false" class="HeaderMenu-link border-0 width-full width-lg-auto px-0 px-lg-2 py-lg-2 no-wrap d-flex flex-items-center flex-justify-between js-details-target" type="button">
#              Solutions
#              <svg aria-hidden="true" class="octicon octicon-chevron-down HeaderMenu-icon ml-1" data-view-component="true" height="16" opacity="0.5" version="1.1" viewbox="0 0 16 16" width="16">
#               <path d="M12.78 5.22a.749.749 0 0 1 0 1.06l-4.25 4.25a.749.749 0 0 1-1.06 0L3.22 6.28a.749.749 0 1 1 1.06-1.06L8 8.939l3.72-3.719a.749.749 0 0 1 1.06 0Z">
#               </path>
#              </svg>
#             </button>
#             <div class="HeaderMenu-dropdown dropdown-menu rounded m-0 p-0 pt-2 pt-lg-4 position-relative position-lg-absolute left-0 left-lg-n3 d-lg-flex flex-wrap dropdown-menu-wide">
#              <div class="HeaderMenu-column px-lg-4 border-lg-right mb-4 mb-lg-0 pr-lg-7">
#               <div class="border-bottom pb-3 pb-lg-0 border-lg-bottom-0 pb-lg-3 mb-3 mb-lg-0">
#                <span class="d-block h4 color-fg-default my-1" id="solutions-by-company-size-heading">
#                 By company size
#                </span>
#                <ul aria-labelledby="solutions-by-company-size-heading" class="list-style-none f5">
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"enterprises","context":"solutions","tag":"link","label":"enterprises_link_solutions_navbar"}' href="https://github.com/enterprise">
#                   Enterprises
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"small_and_medium_teams","context":"solutions","tag":"link","label":"small_and_medium_teams_link_solutions_navbar"}' href="https://github.com/team">
#                   Small and medium teams
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"startups","context":"solutions","tag":"link","label":"startups_link_solutions_navbar"}' href="https://github.com/enterprise/startups">
#                   Startups
#                  </a>
#                 </li>
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"nonprofits","context":"solutions","tag":"link","label":"nonprofits_link_solutions_navbar"}' href="/solutions/industry/nonprofits">
#                   Nonprofits
#                  </a>
#                 </li>
#                </ul>
#               </div>
#               <div class="border-bottom pb-3 pb-lg-0 border-lg-bottom-0">
#                <span class="d-block h4 color-fg-default my-1" id="solutions-by-use-case-heading">
#                 By use case
#                </span>
#                <ul aria-labelledby="solutions-by-use-case-heading" class="list-style-none f5">
#                 <li>
#                  <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"location":"navbar","action":"devsecops","context":"solutions","tag":"link","label":"devsecops_link_solutions_navbar"}' href="/solutions/use-case/devsecops">
#                   DevSecOps
#                  </a>
#                 </li>
#                 <li>
# ...
#          </a>
#          <a class="no-underline flex-1 d-flex flex-column" href="/topics/crystal">
#           <p class="f3 lh-condensed mb-0 mt-1 Link--primary">
#            Crystal
#           </p>
#           <p class="f5 color-fg-muted mb-0 mt-1">
#            Crystal is a self-hosted, general purpose programming language.
#           </p>
#          </a>
#          <div class="flex-grow-0">
#           <div class="d-block" data-view-component="true">
#            <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-sw btn-sm btn" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":null,"auth_type":"LOG_IN","originating_url":"https://github.com/topics","user_id":null}}' data-hydro-click-hmac="7575b5082e2c3915281be9460d747ad48fe377ebd620d4e12e2387269c69459c" data-view-component="true" href="/login?return_to=%2Ftopic.crystal" rel="nofollow">
#             <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#              <path d="M8 .25a.75.75 0 0 1 .673.418l1.882 3.815 4.21.612a.75.75 0 0 1 .416 1.279l-3.046 2.97.719 4.192a.751.751 0 0 1-1.088.791L8 12.347l-3.766 1.98a.75.75 0 0 1-1.088-.79l.72-4.194L.818 6.374a.75.75 0 0 1 .416-1.28l4.21-.611L7.327.668A.75.75 0 0 1 8 .25Zm0 2.445L6.615 5.5a.75.75 0 0 1-.564.41l-3.097.45 2.24 2.184a.75.75 0 0 1 .216.664l-.528 3.084 2.769-1.456a.75.75 0 0 1 .698 0l2.77 1.456-.53-3.084a.75.75 0 0 1 .216-.664l2.24-2.183-3.096-.45a.75.75 0 0 1-.564-.41L8 2.694Z">
#              </path>
#             </svg>
#             <span class="d-inline" data-view-component="true">
#              Star
#             </span>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#        <!-- '"` -->
#        <!-- </textarea></xmp> -->
#        <form accept-charset="UTF-8" action="/topics" class="ajax-pagination-form js-ajax-pagination" data-turbo="false" method="get">
#         <input name="page" type="hidden" value="2"/>
#         <button class="ajax-pagination-btn btn mt-4 py-2 color-border-default f6 width-full" data-disable-with="Loading more..." type="submit">
#          Load more…
#         </button>
#        </form>
#       </div>
#       <div class="col-lg-3">
#        <h2 class="h4 mb-2">
#         Popular topics
#        </h2>
#        <ul class="col-sm-6 col-md-4 col-lg-12 list-style-none flex-wrap">
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to javascript, location:popular topics" data-view-component="true" href="/topics/javascript" title="Topic: javascript">
#           javascript
#          </a>
#         </li>
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to game, location:popular topics" data-view-component="true" href="/topics/game" title="Topic: game">
#           game
#          </a>
#         </li>
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to config, location:popular topics" data-view-component="true" href="/topics/config" title="Topic: config">
#           config
#          </a>
#         </li>
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to python, location:popular topics" data-view-component="true" href="/topics/python" title="Topic: python">
#           python
#          </a>
#         </li>
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to java, location:popular topics" data-view-component="true" href="/topics/java" title="Topic: java">
#           java
#          </a>
#         </li>
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to docker, location:popular topics" data-view-component="true" href="/topics/docker" title="Topic: docker">
#           docker
#          </a>
#         </li>
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to machine-learning, location:popular topics" data-view-component="true" href="/topics/machine-learning" title="Topic: machine-learning">
#           machine-learning
#          </a>
#         </li>
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to typescript, location:popular topics" data-view-component="true" href="/topics/typescript" title="Topic: typescript">
#           typescript
#          </a>
#         </li>
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to computer-vision, location:popular topics" data-view-component="true" href="/topics/computer-vision" title="Topic: computer-vision">
#           computer-vision
#          </a>
#         </li>
#         <li class="d-inline-block">
#          <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Topics, go to github-config, location:popular topics" data-view-component="true" href="/topics/github-config" title="Topic: github-config">
#           github-config
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </main>
#    </div>
#    <footer class="footer pt-8 pb-6 f6 color-fg-muted p-responsive" role="contentinfo">
#     <h2 class="sr-only">
#      Footer
#     </h2>
#     <div class="d-flex flex-justify-center flex-items-center flex-column-reverse flex-lg-row flex-wrap flex-lg-nowrap">
#      <div class="d-flex flex-items-center flex-shrink-0 mx-2">
#       <a aria-label="Homepage" class="footer-octicon mr-2" href="https://github.com" title="GitHub">
#        <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#         <path d="M12 1C5.9225 1 1 5.9225 1 12C1 16.8675 4.14875 20.9787 8.52125 22.4362C9.07125 22.5325 9.2775 22.2025 9.2775 21.9137C9.2775 21.6525 9.26375 20.7862 9.26375 19.865C6.5 20.3737 5.785 19.1912 5.565 18.5725C5.44125 18.2562 4.905 17.28 4.4375 17.0187C4.0525 16.8125 3.5025 16.3037 4.42375 16.29C5.29 16.2762 5.90875 17.0875 6.115 17.4175C7.105 19.0812 8.68625 18.6137 9.31875 18.325C9.415 17.61 9.70375 17.1287 10.02 16.8537C7.5725 16.5787 5.015 15.63 5.015 11.4225C5.015 10.2262 5.44125 9.23625 6.1425 8.46625C6.0325 8.19125 5.6475 7.06375 6.2525 5.55125C6.2525 5.55125 7.17375 5.2625 9.2775 6.67875C10.1575 6.43125 11.0925 6.3075 12.0275 6.3075C12.9625 6.3075 13.8975 6.43125 14.7775 6.67875C16.8813 5.24875 17.8025 5.55125 17.8025 5.55125C18.4075 7.06375 18.0225 8.19125 17.9125 8.46625C18.6138 9.23625 19.04 10.2125 19.04 11.4225C19.04 15.6437 16.4688 16.5787 14.0213 16.8537C14.42 17.1975 14.7638 17.8575 14.7638 18.8887C14.7638 20.36 14.75 21.5425 14.75 21.9137C14.75 22.2025 14.9563 22.5462 15.5063 22.4362C19.8513 20.9787 23 16.8537 23 12C23 5.9225 18.0775 1 12 1Z">
#         </path>
#        </svg>
#       </a>
#       <span>
#        © 2025 GitHub, Inc.
#       </span>
#      </div>
#      <nav aria-label="Footer">
#       <h3 class="sr-only" id="sr-footer-heading">
#        Footer navigation
#       </h3>
#       <ul aria-labelledby="sr-footer-heading" class="list-style-none d-flex flex-justify-center flex-wrap mb-2 mb-lg-0">
#        <li class="mx-2">
#         <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to Terms","label":"text:terms"}' data-view-component="true" href="https://docs.github.com/site-policy/github-terms/github-terms-of-service">
#          Terms
#         </a>
#        </li>
#        <li class="mx-2">
#         <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to privacy","label":"text:privacy"}' data-view-component="true" href="https://docs.github.com/site-policy/privacy-policies/github-privacy-statement">
#          Privacy
#         </a>
#        </li>
#        <li class="mx-2">
#         <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to security","label":"text:security"}' data-view-component="true" href="https://github.com/security">
#          Security
#         </a>
#        </li>
#        <li class="mx-2">
#         <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to status","label":"text:status"}' data-view-component="true" href="https://www.githubstatus.com/">
#          Status
#         </a>
#        </li>
#        <li class="mx-2">
#         <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to docs","label":"text:docs"}' data-view-component="true" href="https://docs.github.com/">
#          Docs
#         </a>
#        </li>
#        <li class="mx-2">
#         <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to contact","label":"text:contact"}' data-view-component="true" href="https://support.github.com?tags=dotcom-footer">
#          Contact
#         </a>
#        </li>
#        <li class="mx-2">
#         <cookie-consent-link>
#          <button class="Link--secondary underline-on-hover border-0 p-0 color-bg-transparent" data-action="click:cookie-consent-link#showConsentManagement" data-analytics-event='{"location":"footer","action":"cookies","context":"subfooter","tag":"link","label":"cookies_link_subfooter_footer"}' type="button">
#           Manage cookies
#          </button>
#         </cookie-consent-link>
#        </li>
#        <li class="mx-2">
#         <cookie-consent-link>
#          <button class="Link--secondary underline-on-hover border-0 p-0 color-bg-transparent" data-action="click:cookie-consent-link#showConsentManagement" data-analytics-event='{"location":"footer","action":"dont_share_info","context":"subfooter","tag":"link","label":"dont_share_info_link_subfooter_footer"}' type="button">
#           Do not share my personal information
#          </button>
#         </cookie-consent-link>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </footer>
#    <ghcc-consent class="position-fixed bottom-0 left-0" data-cookie-consent-required="false" data-initial-cookie-consent-allowed="" id="ghcc" style="z-index: 999999">
#    </ghcc-consent>
#    <div class="ajax-error-message flash flash-error" hidden="" id="ajax-error-message">
#     <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#      <path d="M6.457 1.047c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0 1 14.082 15H1.918a1.75 1.75 0 0 1-1.543-2.575Zm1.763.707a.25.25 0 0 0-.44 0L1.698 13.132a.25.25 0 0 0 .22.368h12.164a.25.25 0 0 0 .22-.368Zm.53 3.996v2.5a.75.75 0 0 1-1.5 0v-2.5a.75.75 0 0 1 1.5 0ZM9 11a1 1 0 1 1-2 0 1 1 0 0 1 2 0Z">
#      </path>
#     </svg>
#     <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
#      <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#       <path d="M3.72 3.72a.75.75 0 0 1 1.06 0L8 6.94l3.22-3.22a.749.749 0 0 1 1.275.326.749.749 0 0 1-.215.734L9.06 8l3.22 3.22a.749.749 0 0 1-.326 1.275.749.749 0 0 1-.734-.215L8 9.06l-3.22 3.22a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042L6.94 8 3.72 4.78a.75.75 0 0 1 0-1.06Z">
#       </path>
#      </svg>
#     </button>
#     You can’t perform that action at this time.
#    </div>
#    <template id="site-details-dialog">
#     <details class="details-reset details-overlay details-overlay-dark lh-default color-fg-default hx_rsm" open="">
#      <summary aria-label="Close dialog" role="button">
#      </summary>
#      <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
#       <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
#        <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#         <path d="M3.72 3.72a.75.75 0 0 1 1.06 0L8 6.94l3.22-3.22a.749.749 0 0 1 1.275.326.749.749 0 0 1-.215.734L9.06 8l3.22 3.22a.749.749 0 0 1-.326 1.275.749.749 0 0 1-.734-.215L8 9.06l-3.22 3.22a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042L6.94 8 3.72 4.78a.75.75 0 0 1 0-1.06Z">
#         </path>
#        </svg>
#       </button>
#       <div class="octocat-spinner my-6 js-details-dialog-spinner">
#       </div>
#      </details-dialog>
#     </details>
#    </template>
#    <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;">
#     <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
#     </div>
#    </div>
#    <template id="snippet-clipboard-copy-button">
#     <div class="zeroclipboard-container position-absolute right-0 top-0">
#      <clipboard-copy aria-label="Copy" class="ClipboardButton btn js-clipboard-copy m-2 p-0" data-copy-feedback="Copied!" data-tooltip-direction="w">
#       <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#        <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 0 1 0 1.5h-1.5a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-1.5a.75.75 0 0 1 1.5 0v1.5A1.75 1.75 0 0 1 9.25 16h-7.5A1.75 1.75 0 0 1 0 14.25Z">
#        </path>
#        <path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0 1 14.25 11h-7.5A1.75 1.75 0 0 1 5 9.25Zm1.75-.25a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-7.5a.25.25 0 0 0-.25-.25Z">
#        </path>
#       </svg>
#       <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#        <path d="M13.78 4.22a.75.75 0 0 1 0 1.06l-7.25 7.25a.75.75 0 0 1-1.06 0L2.22 9.28a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L6 10.94l6.72-6.72a.75.75 0 0 1 1.06 0Z">
#        </path>
#       </svg>
#      </clipboard-copy>
#     </div>
#    </template>
#    <template id="snippet-clipboard-copy-button-unpositioned">
#     <div class="zeroclipboard-container">
#      <clipboard-copy aria-label="Copy" class="ClipboardButton btn btn-invisible js-clipboard-copy m-2 p-0 d-flex flex-justify-center flex-items-center" data-copy-feedback="Copied!" data-tooltip-direction="w">
#       <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#        <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 0 1 0 1.5h-1.5a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-1.5a.75.75 0 0 1 1.5 0v1.5A1.75 1.75 0 0 1 9.25 16h-7.5A1.75 1.75 0 0 1 0 14.25Z">
#        </path>
#        <path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0 1 14.25 11h-7.5A1.75 1.75 0 0 1 5 9.25Zm1.75-.25a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-7.5a.25.25 0 0 0-.25-.25Z">
#        </path>
#       </svg>
#       <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#        <path d="M13.78 4.22a.75.75 0 0 1 0 1.06l-7.25 7.25a.75.75 0 0 1-1.06 0L2.22 9.28a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L6 10.94l6.72-6.72a.75.75 0 0 1 1.06 0Z">
#        </path>
#       </svg>
#      </clipboard-copy>
#     </div>
#    </template>
#   </div>
#   <div aria-atomic="true" aria-live="polite" class="sr-only mt-n1" id="js-global-screen-reader-notice">
#   </div>
#   <div aria-atomic="true" aria-live="assertive" class="sr-only mt-n1" id="js-global-screen-reader-notice-assertive">
#   </div>
#  </body>
# </html>

# %% [markdown]
# ## 3.1 Extracting the topics being discussed
#   - **Key Note:**
#      - The class name should be correctly defined (f3 lh-condensed mb-0 mt-1 Link--primary)
#      - To find the class name you need to inspect (F12) any topic in the website (https://github.com/topics)

# %%
# Ensure the class name is correctly defined
selection_class = 'f3 lh-condensed mb-0 mt-1 Link--primary'

# Extract all <p> elements with the specified class
topics = soup.find_all('p', {'class': selection_class})

# Retrieve only the text content of the topics
topic_titles = [topic.get_text(strip=True) for topic in topics]

# Print or use the extracted topics
print(topic_titles)
# Out:
# ['3D', 'Ajax', 'Algorithm', 'Amp', 'Android', 'Angular', 'Ansible', 'API', 'Arduino', 'ASP.NET', 'Awesome Lists', 'Amazon Web Services', 'Azure', 'Babel', 'Bash', 'Bitcoin', 'Bootstrap', 'Bot', 'C', 'Chrome', 'Chrome extension', 'Command-line interface', 'Clojure', 'Code quality', 'Code review', 'Compiler', 'Continuous integration', 'C++', 'Cryptocurrency', 'Crystal']

# %%
# list of topics being discussed
topic_titles
# Out:
# ['3D',
#  'Ajax',
#  'Algorithm',
#  'Amp',
#  'Android',
#  'Angular',
#  'Ansible',
#  'API',
#  'Arduino',
#  'ASP.NET',
#  'Awesome Lists',
#  'Amazon Web Services',
#  'Azure',
#  'Babel',
#  'Bash',
#  'Bitcoin',
#  'Bootstrap',
#  'Bot',
#  'C',
#  'Chrome',
#  'Chrome extension',
#  'Command-line interface',
#  'Clojure',
#  'Code quality',
#  'Code review',
#  'Compiler',
#  'Continuous integration',
#  'C++',
#  'Cryptocurrency',
#  'Crystal']

# %%
len(topic_titles)
# Out:
# 30

# %%
# Get the parent of the first topic description (if available)
topics[0].parent
# Out:
# <a class="no-underline flex-1 d-flex flex-column" href="/topics/3d">
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">3D</p>
# <p class="f5 color-fg-muted mb-0 mt-1">
#           3D refers to the use of three-dimensional graphics, modeling, and animation in various industries.
#         </p>
# </a>

# %%
# total number of topics
len(topics)
# Out:
# 30

# %% [markdown]
# ## 3.2 Extracting the topics descriptions
#   - class: (f5 color-fg-muted mb-0 mt-1)

# %%
# Define the correct class for topic descriptions
description_class = 'f5 color-fg-muted mb-0 mt-1'

# Find all <p> elements that match the topic description class
topic_descriptions = soup.find_all('p', {'class': description_class})

# Extract and clean the text content
descriptions = [desc.get_text(strip=True) for desc in topic_descriptions]

# Print or use the extracted topic descriptions
print(descriptions)
# Out:
# ['3D refers to the use of three-dimensional graphics, modeling, and animation in various industries.', 'Ajax is a technique for creating interactive web applications.', 'Algorithms are self-contained sequences that carry out a variety of tasks.', 'Amp is a non-blocking concurrency library for PHP.', 'Android is an operating system built by Google designed for mobile devices.', 'Angular is an open source web application platform.', 'Ansible is a simple and powerful automation engine.', 'An API (Application Programming Interface) is a collection of protocols and subroutines for building software.', 'Arduino is an open source platform for building electronic devices.', 'ASP.NET is a web framework for building modern web apps and services.', 'An awesome list is a list of awesome things curated by the community.', 'Amazon Web Services provides on-demand cloud computing platforms on a subscription basis.', 'Azure is a cloud computing service created by Microsoft.', 'Babel is a compiler for writing next generation JavaScript, today.', 'Bash is a shell and command language interpreter for the GNU operating system.', 'Bitcoin is a cryptocurrency developed by Satoshi Nakamoto.', 'Bootstrap is an HTML, CSS, and JavaScript framework.', 'A bot is an application that runs automated tasks over the Internet.', 'C is a general purpose programming language that first appeared in 1972.', 'Chrome is a web browser from the tech company Google.', 'Chrome extensions enable users to customize the Chrome browsing experience.', 'A CLI, or command-line interface, is a console that helps users issue commands to a program.', 'Clojure is a dynamic, general-purpose programming language.', 'Automate your code review with style, quality, security, and test‑coverage checks when you need them.', 'Ensure your code meets quality standards and ship with confidence.', 'Compilers are software that translate higher-level programming languages to lower-level languages (e.g. machine code).', 'Automatically build and test your code as you push it upstream, preventing bugs from being deployed to production.', 'C++ is a general purpose and object-oriented programming language.', 'A cryptocurrency is a digital currency that uses cryptography.', 'Crystal is a self-hosted, general purpose programming language.']

# %%
descriptions
# Out:
# ['3D refers to the use of three-dimensional graphics, modeling, and animation in various industries.',
#  'Ajax is a technique for creating interactive web applications.',
#  'Algorithms are self-contained sequences that carry out a variety of tasks.',
#  'Amp is a non-blocking concurrency library for PHP.',
#  'Android is an operating system built by Google designed for mobile devices.',
#  'Angular is an open source web application platform.',
#  'Ansible is a simple and powerful automation engine.',
#  'An API (Application Programming Interface) is a collection of protocols and subroutines for building software.',
#  'Arduino is an open source platform for building electronic devices.',
#  'ASP.NET is a web framework for building modern web apps and services.',
#  'An awesome list is a list of awesome things curated by the community.',
#  'Amazon Web Services provides on-demand cloud computing platforms on a subscription basis.',
#  'Azure is a cloud computing service created by Microsoft.',
#  'Babel is a compiler for writing next generation JavaScript, today.',
#  'Bash is a shell and command language interpreter for the GNU operating system.',
#  'Bitcoin is a cryptocurrency developed by Satoshi Nakamoto.',
#  'Bootstrap is an HTML, CSS, and JavaScript framework.',
#  'A bot is an application that runs automated tasks over the Internet.',
#  'C is a general purpose programming language that first appeared in 1972.',
#  'Chrome is a web browser from the tech company Google.',
#  'Chrome extensions enable users to customize the Chrome browsing experience.',
#  'A CLI, or command-line interface, is a console that helps users issue commands to a program.',
#  'Clojure is a dynamic, general-purpose programming language.',
#  'Automate your code review with style, quality, security, and test‑coverage checks when you need them.',
#  'Ensure your code meets quality standards and ship with confidence.',
#  'Compilers are software that translate higher-level programming languages to lower-level languages (e.g. machine code).',
#  'Automatically build and test your code as you push it upstream, preventing bugs from being deployed to production.',
#  'C++ is a general purpose and object-oriented programming language.',
#  'A cryptocurrency is a digital currency that uses cryptography.',
#  'Crystal is a self-hosted, general purpose programming language.']

# %%
# total number of descriptions
len(descriptions)
# Out:
# 30

# %%
# Define the correct class for topic titles
topic_class = 'f3 lh-condensed mb-0 mt-1 Link--primary'

# Find all <p> elements that match the topic title class
topics = soup.find_all('p', {'class': topic_class})

# Extract topic text and associated URLs (if available)
topic_data = []
for topic in topics:
    link_tag = topic.find('a')  # Find an <a> tag inside the <p>
    if link_tag and 'href' in link_tag.attrs:
        url = link_tag['href']  # Extract the href (URL)
        title = topic.get_text(strip=True)  # Extract the topic text
        topic_data.append((title, url))

# Print extracted topics with their URLs
for title, url in topic_data:
    print(f"Topic: {title}, URL: {url}")

# %% [markdown]
# ## 3.3 Extracting the topic links
#   - class: (no-underline flex-1 d-flex flex-column)

# %%
# Define the class for the topic link
topic_link_class = 'no-underline flex-1 d-flex flex-column'

# Find all <a> elements with the specified class
topic_links = soup.find_all('a', class_=topic_link_class)

# Extract URLs into a list
urls = [link['href'] for link in topic_links if 'href' in link.attrs]

# Print the list of URLs
print(urls)
# Out:
# ['/topics/3d', '/topics/ajax', '/topics/algorithm', '/topics/amphp', '/topics/android', '/topics/angular', '/topics/ansible', '/topics/api', '/topics/arduino', '/topics/aspnet', '/topics/awesome', '/topics/aws', '/topics/azure', '/topics/babel', '/topics/bash', '/topics/bitcoin', '/topics/bootstrap', '/topics/bot', '/topics/c', '/topics/chrome', '/topics/chrome-extension', '/topics/cli', '/topics/clojure', '/topics/code-quality', '/topics/code-review', '/topics/compiler', '/topics/continuous-integration', '/topics/cpp', '/topics/cryptocurrency', '/topics/crystal']

# %%
# list of extracted urls without base url('https://github.com')
urls
# Out:
# ['/topics/3d',
#  '/topics/ajax',
#  '/topics/algorithm',
#  '/topics/amphp',
#  '/topics/android',
#  '/topics/angular',
#  '/topics/ansible',
#  '/topics/api',
#  '/topics/arduino',
#  '/topics/aspnet',
#  '/topics/awesome',
#  '/topics/aws',
#  '/topics/azure',
#  '/topics/babel',
#  '/topics/bash',
#  '/topics/bitcoin',
#  '/topics/bootstrap',
#  '/topics/bot',
#  '/topics/c',
#  '/topics/chrome',
#  '/topics/chrome-extension',
#  '/topics/cli',
#  '/topics/clojure',
#  '/topics/code-quality',
#  '/topics/code-review',
#  '/topics/compiler',
#  '/topics/continuous-integration',
#  '/topics/cpp',
#  '/topics/cryptocurrency',
#  '/topics/crystal']

# %%
# Construct the full URL for the first topic by appending the relative path to GitHub's base URL
topics0_url = "https://github.com" + topic_links[0]['href']
# Print the complete URL of the first topic
print(topics0_url)
# Out:
# https://github.com/topics/3d

# %%
# Define the base URL
base_url = 'https://github.com'

# Define the class for the topic link
topic_link_class = 'no-underline flex-1 d-flex flex-column'

# Find all <a> elements with the specified class
topic_links = soup.find_all('a', class_=topic_link_class)

# Extract URLs and prepend base_url if necessary
urls = [base_url + link['href'] if link['href'].startswith('/') else link['href']
        for link in topic_links if 'href' in link.attrs]

# Print the list of full URLs
print(urls)
# Out:
# ['https://github.com/topics/3d', 'https://github.com/topics/ajax', 'https://github.com/topics/algorithm', 'https://github.com/topics/amphp', 'https://github.com/topics/android', 'https://github.com/topics/angular', 'https://github.com/topics/ansible', 'https://github.com/topics/api', 'https://github.com/topics/arduino', 'https://github.com/topics/aspnet', 'https://github.com/topics/awesome', 'https://github.com/topics/aws', 'https://github.com/topics/azure', 'https://github.com/topics/babel', 'https://github.com/topics/bash', 'https://github.com/topics/bitcoin', 'https://github.com/topics/bootstrap', 'https://github.com/topics/bot', 'https://github.com/topics/c', 'https://github.com/topics/chrome', 'https://github.com/topics/chrome-extension', 'https://github.com/topics/cli', 'https://github.com/topics/clojure', 'https://github.com/topics/code-quality', 'https://github.com/topics/code-review', 'https://github.com/topics/compiler', 'https://github.com/topics/continuous-integration', 'https://github.com/topics/cpp', 'https://github.com/topics/cryptocurrency', 'https://github.com/topics/crystal']

# %%
# list of extracted urls with base url('https://github.com')
urls
# Out:
# ['https://github.com/topics/3d',
#  'https://github.com/topics/ajax',
#  'https://github.com/topics/algorithm',
#  'https://github.com/topics/amphp',
#  'https://github.com/topics/android',
#  'https://github.com/topics/angular',
#  'https://github.com/topics/ansible',
#  'https://github.com/topics/api',
#  'https://github.com/topics/arduino',
#  'https://github.com/topics/aspnet',
#  'https://github.com/topics/awesome',
#  'https://github.com/topics/aws',
#  'https://github.com/topics/azure',
#  'https://github.com/topics/babel',
#  'https://github.com/topics/bash',
#  'https://github.com/topics/bitcoin',
#  'https://github.com/topics/bootstrap',
#  'https://github.com/topics/bot',
#  'https://github.com/topics/c',
#  'https://github.com/topics/chrome',
#  'https://github.com/topics/chrome-extension',
#  'https://github.com/topics/cli',
#  'https://github.com/topics/clojure',
#  'https://github.com/topics/code-quality',
#  'https://github.com/topics/code-review',
#  'https://github.com/topics/compiler',
#  'https://github.com/topics/continuous-integration',
#  'https://github.com/topics/cpp',
#  'https://github.com/topics/cryptocurrency',
#  'https://github.com/topics/crystal']

# %%
print("Number of topic titles:", len(topic_titles))
print("Number of descriptions:", len(descriptions))
print("Number of URLs:", len(urls))
# Out:
# Number of topic titles: 30
# Number of descriptions: 30
# Number of URLs: 30

# %% [markdown]
# **Key Note**
#   - to be able to create a Pandas datframe all variables should be of the same length

# %% [markdown]
# # 4 Creating a Pandas DataFrame

# %%
import pandas as pd

# %%
# Create a dictionary to organize topic data
topics_dict = {
    # The key 'Topic Title' maps to the list of topic titles
    "Topic Title": topic_titles,

    # The key 'Description' maps to the list of descriptions corresponding to each topic
    "Description": descriptions,

    # The key 'URL' maps to the list of URLs for each topic
    "URL": urls
}

# %%
# Create a DataFrame from the topics_dict dictionary
topics_df = pd.DataFrame(topics_dict)

# %%
topics_df
# Out:
#                Topic Title                                        Description  \
# 0                       3D  3D refers to the use of three-dimensional grap...
# 1                     Ajax  Ajax is a technique for creating interactive w...
# 2                Algorithm  Algorithms are self-contained sequences that c...
# 3                      Amp  Amp is a non-blocking concurrency library for ...
# 4                  Android  Android is an operating system built by Google...
# 5                  Angular  Angular is an open source web application plat...
# 6                  Ansible  Ansible is a simple and powerful automation en...
# 7                      API  An API (Application Programming Interface) is ...
# 8                  Arduino  Arduino is an open source platform for buildin...
# 9                  ASP.NET  ASP.NET is a web framework for building modern...
# 10           Awesome Lists  An awesome list is a list of awesome things cu...
# 11     Amazon Web Services  Amazon Web Services provides on-demand cloud c...
# 12                   Azure  Azure is a cloud computing service created by ...
# 13                   Babel  Babel is a compiler for writing next generatio...
# 14                    Bash  Bash is a shell and command language interpret...
# 15                 Bitcoin  Bitcoin is a cryptocurrency developed by Satos...
# 16               Bootstrap  Bootstrap is an HTML, CSS, and JavaScript fram...
# 17                     Bot  A bot is an application that runs automated ta...
# 18                       C  C is a general purpose programming language th...
# 19                  Chrome  Chrome is a web browser from the tech company ...
# 20        Chrome extension  Chrome extensions enable users to customize th...
# 21  Command-line interface  A CLI, or command-line interface, is a console...
# 22                 Clojure  Clojure is a dynamic, general-purpose programm...
# 23            Code quality  Automate your code review with style, quality,...
# 24             Code review  Ensure your code meets quality standards and s...
# 25                Compiler  Compilers are software that translate higher-l...
# 26  Continuous integration  Automatically build and test your code as you ...
# 27                     C++  C++ is a general purpose and object-oriented p...
# 28          Cryptocurrency  A cryptocurrency is a digital currency that us...
# 29                 Crystal  Crystal is a self-hosted, general purpose prog...
#
#                                                  URL
# 0                       https://github.com/topics/3d
# 1                     https://github.com/topics/ajax
# 2                https://github.com/topics/algorithm
# 3                    https://github.com/topics/amphp
# 4                  https://github.com/topics/android
# 5                  https://github.com/topics/angular
# 6                  https://github.com/topics/ansible
# 7                      https://github.com/topics/api
# 8                  https://github.com/topics/arduino
# 9                   https://github.com/topics/aspnet
# 10                 https://github.com/topics/awesome
# 11                     https://github.com/topics/aws
# 12                   https://github.com/topics/azure
# 13                   https://github.com/topics/babel
# 14                    https://github.com/topics/bash
# 15                 https://github.com/topics/bitcoin
# 16               https://github.com/topics/bootstrap
# 17                     https://github.com/topics/bot
# 18                       https://github.com/topics/c
# 19                  https://github.com/topics/chrome
# 20        https://github.com/topics/chrome-extension
# 21                     https://github.com/topics/cli
# 22                 https://github.com/topics/clojure
# 23            https://github.com/topics/code-quality
# 24             https://github.com/topics/code-review
# 25                https://github.com/topics/compiler
# 26  https://github.com/topics/continuous-integration
# 27                     https://github.com/topics/cpp
# 28          https://github.com/topics/cryptocurrency
# 29                 https://github.com/topics/crystal

# %%
# Create a CSV file from the topics_df DataFrame
topics_df.to_csv('topics.csv', index=False)

# %% [markdown]
# # 5 Getting Information Out of a Single Page
# - The total number of topics is 30,
# - Our aim is to deal with first topic page and scrap its contents
# - **The first topic is '3D'**

# %%
# Retrieve the URL of the first topic from the 'urls' list
topics_page_url = urls[0]

# Display the URL of the first topic
topics_page_url
# Out:
# 'https://github.com/topics/3d'

# %% [markdown]
# Open: https://github.com/topics/3d
# - Key Important Issues we're interested in
#        - username
#        - repository
#        - repository link
#        - stars

# %%
# Send an HTTP GET request to the URL stored in 'topics_page_url'
response = requests.get(topics_page_url)

# Display the HTTP status code of the response to check if the request was successful
response.status_code
# Out:
# 200

# %%
# Get the length of the response text (HTML content) from the GET request
len(response.text)
# Out:
# 515357

# %%
# Parse the HTML content of the page using BeautifulSoup
topic_doc = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# **Key Comment**
# - **topic_doc** now holds the structured version of the webpage, allowing you to navigate and extract specific elements using BeautifulSoup methods (like .find(), .find_all(), .select(), etc.).

# %% [markdown]
# ## 5.1 Extracting the Repo tags
#    - Repo tags = Repository name + Username
#    - Use **topic_doc (which contains the parsed HTML)** to extract **repo_tags** by selecting the correct class name.

# %%
# Define the class for the repository tag
repo_tag_class = 'f3 color-fg-muted text-normal lh-condensed'

# Find all <h3> elements with the specified class
repo_titles = topic_doc.find_all('h3', class_=repo_tag_class)

# Extract the text from the repository tags into a list
repo_tags = [repo_tag.get_text(strip=True) for repo_tag in repo_titles]

# Print the list of repository titles
print(repo_tags)
# Out:
# ['mrdoob/three.js', 'pmndrs/react-three-fiber', 'libgdx/libgdx', 'BabylonJS/Babylon.js', 'FreeCAD/FreeCAD', 'ssloy/tinyrenderer', 'lettier/3d-game-shaders-for-beginners', 'aframevr/aframe', 'blender/blender', 'CesiumGS/cesium', '4ian/GDevelop', 'isl-org/Open3D', 'MonoGame/MonoGame', 'mapbox/mapbox-gl-js', 'metafizzy/zdog', 'nerfstudio-project/nerfstudio', 'timzhang642/3D-Machine-Learning', 'DavidHDev/react-bits', 'microsoft/TRELLIS', 'cocos/cocos-engine']

# %%
# Print the number of extracted repository tags
print(len(repo_tags))
# Out:
# 20

# %%
# the first repo tag
repo_tags[0]
# Out:
# 'mrdoob/three.js'

# %% [markdown]
# ## 5.2 Extracting usernames from repo tags
#   - repo tags (username + repository name)

# %%
# Define the class for the repository tag
repo_tag_class = 'f3 color-fg-muted text-normal lh-condensed'

# Find all <h3> elements with the specified class
repo_tags = topic_doc.find_all('h3', class_=repo_tag_class)

# Extract the username from the repository tags into a list
usernames = [repo_tag.get_text(strip=True).split('/')[0] for repo_tag in repo_tags if '/' in repo_tag.get_text(strip=True)]

# Print the list of usernames
print(usernames)
# Out:
# ['mrdoob', 'pmndrs', 'libgdx', 'BabylonJS', 'FreeCAD', 'ssloy', 'lettier', 'aframevr', 'blender', 'CesiumGS', '4ian', 'isl-org', 'MonoGame', 'mapbox', 'metafizzy', 'nerfstudio-project', 'timzhang642', 'DavidHDev', 'microsoft', 'cocos']

# %%
# the first username
usernames[0]
# Out:
# 'mrdoob'

# %% [markdown]
# ## 5.3 Extracting repository names from repo tags
#   - repo tags (username + repository name)

# %%
# Define the class for the repository tag
repo_tag_class = 'f3 color-fg-muted text-normal lh-condensed'

# Find all <h3> elements with the specified class
repo_tags = topic_doc.find_all('h3', class_=repo_tag_class)

# Extract the repository name from the repository tags into a list
repo_names = [repo_tag.get_text(strip=True).split('/')[1] for repo_tag in repo_tags if '/' in repo_tag.get_text(strip=True)]

# Print the list of repository names
print(repo_names)
# Out:
# ['three.js', 'react-three-fiber', 'libgdx', 'Babylon.js', 'FreeCAD', 'tinyrenderer', '3d-game-shaders-for-beginners', 'aframe', 'blender', 'cesium', 'GDevelop', 'Open3D', 'MonoGame', 'mapbox-gl-js', 'zdog', 'nerfstudio', '3D-Machine-Learning', 'react-bits', 'TRELLIS', 'cocos-engine']

# %%
# the first repository name
repo_names[0]
# Out:
# 'three.js'

# %% [markdown]
# ## 5.4 Extracting a repo url by concatenating base url, username, and repository name

# %%
base_url = 'https://github.com'

# %%
# Define the base URL
base_url = 'https://github.com'

# Extract the usernames and repository names into separate lists
username = [repo_tag.get_text(strip=True).split('/')[0] for repo_tag in repo_tags if '/' in repo_tag.get_text(strip=True)]
repo_name = [repo_tag.get_text(strip=True).split('/')[1] for repo_tag in repo_tags if '/' in repo_tag.get_text(strip=True)]

# Loop through both lists and concatenate the base URL, username, and repository name
full_urls = [f"{base_url}/{u}/{r}" for u, r in zip(username, repo_name)]

# Print the list of full URLs
for repo_url in full_urls:
    print(repo_url)
# Out:
# https://github.com/mrdoob/three.js
# https://github.com/pmndrs/react-three-fiber
# https://github.com/libgdx/libgdx
# https://github.com/BabylonJS/Babylon.js
# https://github.com/FreeCAD/FreeCAD
# https://github.com/ssloy/tinyrenderer
# https://github.com/lettier/3d-game-shaders-for-beginners
# https://github.com/aframevr/aframe
# https://github.com/blender/blender
# https://github.com/CesiumGS/cesium
# https://github.com/4ian/GDevelop
# https://github.com/isl-org/Open3D
# https://github.com/MonoGame/MonoGame
# https://github.com/mapbox/mapbox-gl-js
# https://github.com/metafizzy/zdog
# https://github.com/nerfstudio-project/nerfstudio
# https://github.com/timzhang642/3D-Machine-Learning
# https://github.com/DavidHDev/react-bits
# https://github.com/microsoft/TRELLIS
# https://github.com/cocos/cocos-engine

# %% [markdown]
# ## 5.5 Extracting the Star Counts

# %%
# Define the class for the star count
star_class = 'Counter js-social-count'

# Find all elements with the specified class
star_tags = topic_doc.find_all(class_=star_class)

# Extract the star count into a list
star_counts = [star.get_text(strip=True) for star in star_tags]

# Print the list of star counts
print(star_counts)
# Out:
# ['105k', '28.5k', '23.9k', '23.8k', '23.7k', '21.6k', '18.5k', '17k', '14.7k', '13.5k', '13.5k', '12.1k', '11.9k', '11.5k', '10.5k', '10k', '9.9k', '9.9k', '8.7k', '8.5k']

# %%
# Length of the star counts (number of repositories with star counts)
len(star_counts)
# Out:
# 20

# %%
# Print the first star count from the list
print(star_counts[0])
# Out:
# 105k

# %% [markdown]
# - Parse and clean the star count using a helper function below

# %%
# Parse and clean the star count using a helper function

def parse_star_count(value):
    # Dictionary to map suffixes to corresponding multipliers
    suffixes = {'k': 1000, 'm': 1000000, 'b': 1000000000}

    # Extract the suffix (last character) and the numeric part
    suffix = value[-1].lower()
    numeric_value = float(value[:-1])

    # Check if the suffix is in the dictionary, then multiply
    if suffix in suffixes:
        return int(numeric_value * suffixes[suffix])
    else:
        return int(value)  # If no suffix, return the integer value

# Example usage:
value = '105k'
numeric_value = parse_star_count(value)
print(numeric_value)
# Out:
# 105000

# %% [markdown]
# ## 5.6 Extracting repository information

# %%
# Function to extract repository information (username, repository name, star count, and repository URL)
def get_repo_info(h3_tag, star_tag):
    # Find all <a> tags within the <h3> tag
    a_tags = h3_tag.find_all('a')

    # Extract and clean the username (first <a> tag)
    username = a_tags[0].text.strip()

    # Extract and clean the repository name (second <a> tag)
    repo_name = a_tags[1].text.strip()

    # Construct the repository URL by concatenating the base URL and the href from the second <a> tag
    repo_url = base_url + a_tags[1]['href']

    # Parse and clean the star count using a helper function (assuming parse_star_count exists)
    stars = parse_star_count(star_tag.text.strip())

    # Return the extracted information as a tuple: (username, repo_name, stars, repo_url)
    return username, repo_name, stars, repo_url

# %%
# Call the function get_repo_info to extract repository details from the first repo tag and star tag
get_repo_info(repo_tags[0], star_tags[0])
# Out:
# ('mrdoob', 'three.js', 105000, 'https://github.com/mrdoob/three.js')

# %%
# Extracting information for all repositories
# List to store extracted repository information
repo_info_list = []

# Loop through each repo_tag and star_tag to extract information
for repo_tag, star_tag in zip(repo_tags, star_tags):
    # Extract username, repo name, stars, and repo URL for each repository
    repo_info = get_repo_info(repo_tag, star_tag)

    # Append the extracted information to the list
    repo_info_list.append(repo_info)

# %%
repo_info_list
# Out:
# [('mrdoob', 'three.js', 105000, 'https://github.com/mrdoob/three.js'),
#  ('pmndrs',
#   'react-three-fiber',
#   28500,
#   'https://github.com/pmndrs/react-three-fiber'),
#  ('libgdx', 'libgdx', 23900, 'https://github.com/libgdx/libgdx'),
#  ('BabylonJS', 'Babylon.js', 23800, 'https://github.com/BabylonJS/Babylon.js'),
#  ('FreeCAD', 'FreeCAD', 23700, 'https://github.com/FreeCAD/FreeCAD'),
#  ('ssloy', 'tinyrenderer', 21600, 'https://github.com/ssloy/tinyrenderer'),
#  ('lettier',
#   '3d-game-shaders-for-beginners',
#   18500,
#   'https://github.com/lettier/3d-game-shaders-for-beginners'),
#  ('aframevr', 'aframe', 17000, 'https://github.com/aframevr/aframe'),
#  ('blender', 'blender', 14700, 'https://github.com/blender/blender'),
#  ('CesiumGS', 'cesium', 13500, 'https://github.com/CesiumGS/cesium'),
#  ('4ian', 'GDevelop', 13500, 'https://github.com/4ian/GDevelop'),
#  ('isl-org', 'Open3D', 12100, 'https://github.com/isl-org/Open3D'),
#  ('MonoGame', 'MonoGame', 11900, 'https://github.com/MonoGame/MonoGame'),
#  ('mapbox', 'mapbox-gl-js', 11500, 'https://github.com/mapbox/mapbox-gl-js'),
#  ('metafizzy', 'zdog', 10500, 'https://github.com/metafizzy/zdog'),
#  ('nerfstudio-project',
#   'nerfstudio',
#   10000,
#   'https://github.com/nerfstudio-project/nerfstudio'),
#  ('timzhang642',
#   '3D-Machine-Learning',
#   9900,
#   'https://github.com/timzhang642/3D-Machine-Learning'),
#  ('DavidHDev', 'react-bits', 9900, 'https://github.com/DavidHDev/react-bits'),
#  ('microsoft', 'TRELLIS', 8700, 'https://github.com/microsoft/TRELLIS'),
#  ('cocos', 'cocos-engine', 8500, 'https://github.com/cocos/cocos-engine')]

# %%
len(repo_info_list)
# Out:
# 20

# %% [markdown]
# # 6 Results and Output

# %%
# Create a dictionary to organize repository data
repo_info_dict = {
    # The key 'Username' maps to the list of usernames for each repository
    "Username": [repo[0] for repo in repo_info_list],

    # The key 'Repository Name' maps to the list of repository names for each repository
    "Repository Name": [repo[1] for repo in repo_info_list],

    # The key 'Stars' maps to the list of stars for each repository
    "Stars": [repo[2] for repo in repo_info_list],

    # The key 'Repository URL' maps to the list of URLs for each repository
    "Repository URL": [repo[3] for repo in repo_info_list]
}

# Create a DataFrame from the repo_dict dictionary
repo_info_df = pd.DataFrame(repo_info_dict)

# %%
repo_info_df
# Out:
#               Username                Repository Name   Stars  \
# 0               mrdoob                       three.js  105000
# 1               pmndrs              react-three-fiber   28500
# 2               libgdx                         libgdx   23900
# 3            BabylonJS                     Babylon.js   23800
# 4              FreeCAD                        FreeCAD   23700
# 5                ssloy                   tinyrenderer   21600
# 6              lettier  3d-game-shaders-for-beginners   18500
# 7             aframevr                         aframe   17000
# 8              blender                        blender   14700
# 9             CesiumGS                         cesium   13500
# 10                4ian                       GDevelop   13500
# 11             isl-org                         Open3D   12100
# 12            MonoGame                       MonoGame   11900
# 13              mapbox                   mapbox-gl-js   11500
# 14           metafizzy                           zdog   10500
# 15  nerfstudio-project                     nerfstudio   10000
# 16         timzhang642            3D-Machine-Learning    9900
# 17           DavidHDev                     react-bits    9900
# 18           microsoft                        TRELLIS    8700
# 19               cocos                   cocos-engine    8500
#
#                                        Repository URL
# 0                  https://github.com/mrdoob/three.js
# 1         https://github.com/pmndrs/react-three-fiber
# 2                    https://github.com/libgdx/libgdx
# 3             https://github.com/BabylonJS/Babylon.js
# 4                  https://github.com/FreeCAD/FreeCAD
# 5               https://github.com/ssloy/tinyrenderer
# 6   https://github.com/lettier/3d-game-shaders-for...
# 7                  https://github.com/aframevr/aframe
# 8                  https://github.com/blender/blender
# 9                  https://github.com/CesiumGS/cesium
# 10                   https://github.com/4ian/GDevelop
# 11                  https://github.com/isl-org/Open3D
# 12               https://github.com/MonoGame/MonoGame
# 13             https://github.com/mapbox/mapbox-gl-js
# 14                  https://github.com/metafizzy/zdog
# 15   https://github.com/nerfstudio-project/nerfstudio
# 16  https://github.com/timzhang642/3D-Machine-Lear...
# 17            https://github.com/DavidHDev/react-bits
# 18               https://github.com/microsoft/TRELLIS
# 19              https://github.com/cocos/cocos-engine

# %% [markdown]
# **IMPORTANT COMMENT**
#   - The above repository information is for single topic only, **the (3D) topic**, but we have 30 different topics in total.
#   - So, we need to do the samething we need with 3D Topic for all other topics

# %%
def get_topic_page(topic_url):
    # Send an HTTP GET request to the topic URL
    response = requests.get(topic_url)
    if response.status_code != 200:
        raise Exception(f"Failed to load page {topic_url}")
    topic_doc = BeautifulSoup(response.text, 'html.parser')
    return topic_doc

# Function to extract repository information (username, repository name, star count, and repository URL)
def get_repo_info(h3_tag, star_tag):
    # Find all <a> tags within the <h3> tag
    a_tags = h3_tag.find_all('a')

    # Extract and clean the username (first <a> tag)
    username = a_tags[0].text.strip()

    # Extract and clean the repository name (second <a> tag)
    repo_name = a_tags[1].text.strip()

    # Construct the repository URL by concatenating the base URL and the href from the second <a> tag
    repo_url = base_url + a_tags[1]['href']

    # Parse and clean the star count using a helper function (assuming parse_star_count exists)
    stars = parse_star_count(star_tag.text.strip())

    # Return the extracted information as a tuple: (username, repo_name, stars, repo_url)
    return username, repo_name, stars, repo_url

def get_topic_repos(topic_doc):
    repo_tags = topic_doc.find_all('h3', class_=repo_tag_class) # Fixed indentation
    # Find all elements with the specified class
    star_tags = topic_doc.find_all(class_=star_class) # Fixed indentation

    topics_repos_dict = {
        "Username": [],
        "Repository Name": [],
        "Stars": [],
        "Repository URL": []
    }

    # Get repo info
    for i in range(len(repo_tags)):
        repo_info = get_repo_info(repo_tags[i], star_tags[i])
        topics_repos_dict["Username"].append(repo_info[0])
        topics_repos_dict["Repository Name"].append(repo_info[1])
        topics_repos_dict["Stars"].append(repo_info[2])
        topics_repos_dict["Repository URL"].append(repo_info[3])

    return pd.DataFrame(topics_repos_dict)

# %%
# Function to fetch and parse the topic webpage
def get_topic_page(topic_url):
    """
    Sends an HTTP GET request to the topic URL and parses the page using BeautifulSoup.

    Args:
        topic_url (str): The URL of the GitHub topic page.

    Returns:
        BeautifulSoup: Parsed HTML document.
    """
    response = requests.get(topic_url)

    # Check if the request was successful (status code 200)
    if response.status_code != 200:
        raise Exception(f"Failed to load page {topic_url}")

    # Parse the HTML content
    topic_doc = BeautifulSoup(response.text, 'html.parser')
    return topic_doc

# Function to extract repository information (username, repository name, star count, and repository URL)
def get_repo_info(h3_tag, star_tag):
    """
    Extracts repository details from the given HTML tags.

    Args:
        h3_tag (Tag): The <h3> tag containing repository details.
        star_tag (Tag): The tag containing the star count.

    Returns:
        tuple: (username, repo_name, stars, repo_url)
    """
    # Find all <a> tags within the <h3> tag (username and repository name are inside <a> tags)
    a_tags = h3_tag.find_all('a')

    # Extract the username from the first <a> tag
    username = a_tags[0].text.strip()

    # Extract the repository name from the second <a> tag
    repo_name = a_tags[1].text.strip()

    # Construct the full repository URL
    repo_url = base_url + a_tags[1]['href']

    # Parse and clean the star count (assuming parse_star_count is defined)
    stars = parse_star_count(star_tag.text.strip())

    return username, repo_name, stars, repo_url

# Function to extract repository data from a topic page
def get_topic_repos(topic_doc):
    """
    Extracts repository details from a given topic page.

    Args:
        topic_doc (BeautifulSoup): Parsed HTML document of a GitHub topic page.

    Returns:
        DataFrame: A pandas DataFrame containing repository information.
    """
    # Find all repository tags based on the given CSS class
    repo_tags = topic_doc.find_all('h3', class_=repo_tag_class)

    # Find all star count tags based on the given CSS class
    star_tags = topic_doc.find_all(class_=star_class)

    # Dictionary to store extracted repository data
    topics_repos_dict = {
        "Username": [],
        "Repository Name": [],
        "Stars": [],
        "Repository URL": []
    }

    # Loop through each repository found on the page
    for i in range(len(repo_tags)):
        repo_info = get_repo_info(repo_tags[i], star_tags[i])
        topics_repos_dict["Username"].append(repo_info[0])       # Store username
        topics_repos_dict["Repository Name"].append(repo_info[1])  # Store repository name
        topics_repos_dict["Stars"].append(repo_info[2])          # Store star count
        topics_repos_dict["Repository URL"].append(repo_info[3]) # Store repository URL

    # Convert the dictionary into a Pandas DataFrame
    return pd.DataFrame(topics_repos_dict)

# %%
# a link to each topic, we have 30 topics
urls
# Out:
# ['https://github.com/topics/3d',
#  'https://github.com/topics/ajax',
#  'https://github.com/topics/algorithm',
#  'https://github.com/topics/amphp',
#  'https://github.com/topics/android',
#  'https://github.com/topics/angular',
#  'https://github.com/topics/ansible',
#  'https://github.com/topics/api',
#  'https://github.com/topics/arduino',
#  'https://github.com/topics/aspnet',
#  'https://github.com/topics/awesome',
#  'https://github.com/topics/aws',
#  'https://github.com/topics/azure',
#  'https://github.com/topics/babel',
#  'https://github.com/topics/bash',
#  'https://github.com/topics/bitcoin',
#  'https://github.com/topics/bootstrap',
#  'https://github.com/topics/bot',
#  'https://github.com/topics/c',
#  'https://github.com/topics/chrome',
#  'https://github.com/topics/chrome-extension',
#  'https://github.com/topics/cli',
#  'https://github.com/topics/clojure',
#  'https://github.com/topics/code-quality',
#  'https://github.com/topics/code-review',
#  'https://github.com/topics/compiler',
#  'https://github.com/topics/continuous-integration',
#  'https://github.com/topics/cpp',
#  'https://github.com/topics/cryptocurrency',
#  'https://github.com/topics/crystal']

# %%
# Fetching a fifth link from our links
url4 = urls[4]

# %%
# printing the fifth link
url4
# Out:
# 'https://github.com/topics/android'

# %%
# Fetch and parse the HTML content of the topic page at url4
topic4_doc = get_topic_page(url4)

# %%
# Extract repository information from the parsed topic page
topic4_repos = get_topic_repos(topic4_doc)

# %%
# DataFrame containing repository details for topic4
topic4_repos
# Out:
#             Username               Repository Name   Stars  \
# 0            flutter                       flutter  169000
# 1           facebook                  react-native  121000
# 2         Genymobile                        scrcpy  120000
# 3          justjavac  free-programming-books-zh_CN  113000
# 4   Hack-with-Github               Awesome-Hacking   90600
# 5             Solido               awesome-flutter   55300
# 6         tldr-pages                          tldr   54500
# 7           wasabeef            awesome-android-ui   52000
# 8             google         material-design-icons   51300
# 9          laurent22                        joplin   48400
# 10          appwrite                      appwrite   47900
# 11            square                        okhttp   46300
# 12           android          architecture-samples   44900
# 13            square                      retrofit   43400
# 14            skylot                          jadx   43400
# 15          dcloudio                       uni-app   40600
# 16            termux                    termux-app   40100
# 17          fastlane                      fastlane   40000
# 18             2dust                       v2rayNG   39500
# 19          KRTirtho                       spotube   39100
#
#                                        Repository URL
# 0                  https://github.com/flutter/flutter
# 1            https://github.com/facebook/react-native
# 2                https://github.com/Genymobile/scrcpy
# 3   https://github.com/justjavac/free-programming-...
# 4   https://github.com/Hack-with-Github/Awesome-Ha...
# 5           https://github.com/Solido/awesome-flutter
# 6                  https://github.com/tldr-pages/tldr
# 7      https://github.com/wasabeef/awesome-android-ui
# 8     https://github.com/google/material-design-icons
# 9                 https://github.com/laurent22/joplin
# 10               https://github.com/appwrite/appwrite
# 11                   https://github.com/square/okhttp
# 12    https://github.com/android/architecture-samples
# 13                 https://github.com/square/retrofit
# 14                     https://github.com/skylot/jadx
# 15                https://github.com/dcloudio/uni-app
# 16               https://github.com/termux/termux-app
# 17               https://github.com/fastlane/fastlane
# 18                   https://github.com/2dust/v2rayNG
# 19                https://github.com/KRTirtho/spotube

# %% [markdown]
# **Alternatively,**

# %%
# link to fifth topic
urls[4]
# Out:
# 'https://github.com/topics/android'

# %%
# Fetch and extract repository information from the topic page at urls[4]
get_topic_repos(get_topic_page(urls[4]))
# Out:
#             Username               Repository Name   Stars  \
# 0            flutter                       flutter  169000
# 1           facebook                  react-native  121000
# 2         Genymobile                        scrcpy  120000
# 3          justjavac  free-programming-books-zh_CN  113000
# 4   Hack-with-Github               Awesome-Hacking   90600
# 5             Solido               awesome-flutter   55300
# 6         tldr-pages                          tldr   54500
# 7           wasabeef            awesome-android-ui   52000
# 8             google         material-design-icons   51300
# 9          laurent22                        joplin   48400
# 10          appwrite                      appwrite   47900
# 11            square                        okhttp   46300
# 12           android          architecture-samples   44900
# 13            square                      retrofit   43400
# 14            skylot                          jadx   43400
# 15          dcloudio                       uni-app   40600
# 16            termux                    termux-app   40100
# 17          fastlane                      fastlane   40000
# 18             2dust                       v2rayNG   39500
# 19          KRTirtho                       spotube   39100
#
#                                        Repository URL
# 0                  https://github.com/flutter/flutter
# 1            https://github.com/facebook/react-native
# 2                https://github.com/Genymobile/scrcpy
# 3   https://github.com/justjavac/free-programming-...
# 4   https://github.com/Hack-with-Github/Awesome-Ha...
# 5           https://github.com/Solido/awesome-flutter
# 6                  https://github.com/tldr-pages/tldr
# 7      https://github.com/wasabeef/awesome-android-ui
# 8     https://github.com/google/material-design-icons
# 9                 https://github.com/laurent22/joplin
# 10               https://github.com/appwrite/appwrite
# 11                   https://github.com/square/okhttp
# 12    https://github.com/android/architecture-samples
# 13                 https://github.com/square/retrofit
# 14                     https://github.com/skylot/jadx
# 15                https://github.com/dcloudio/uni-app
# 16               https://github.com/termux/termux-app
# 17               https://github.com/fastlane/fastlane
# 18                   https://github.com/2dust/v2rayNG
# 19                https://github.com/KRTirtho/spotube

# %%
# save file to csv
get_topic_repos(get_topic_page(urls[4])).to_csv('android.csv', index=None)

# %%
# to link to seventh urls[6]
urls[6]
# Out:
# 'https://github.com/topics/ansible'

# %%
# Fetch and extract repository information from the topic page at urls[6]
get_topic_repos(get_topic_page(urls[6]))
# Out:
#                Username               Repository Name  Stars  \
# 0          bregman-arie              devops-exercises  72500
# 1               ansible                       ansible  64500
# 2           trailofbits                          algo  29300
# 3           MichaelCade                90DaysOfDevOps  27800
# 4       StreisandEffect                     streisand  23300
# 5       kubernetes-sigs                     kubespray  16800
# 6               ansible                           awx  14500
# 7           semaphoreui                     semaphore  11600
# 8               easzlab                       kubeasz  10800
# 9            netbootxyz                   netboot.xyz  10000
# 10          geerlingguy            ansible-for-devops   8900
# 11              Tikam02                  DevOps-Guide   8600
# 12             khuedoan                       homelab   8500
# 13          geerlingguy              mac-dev-playbook   6400
# 14  Orange-Cyberdefense                          GOAD   6200
# 15              rundeck                       rundeck   5700
# 16       ChristianLempa                  boilerplates   5400
# 17         KubeOperator                  KubeOperator   5000
# 18                clong                  DetectionLab   4700
# 19              dev-sec  ansible-collection-hardening   4300
#
#                                        Repository URL
# 0    https://github.com/bregman-arie/devops-exercises
# 1                  https://github.com/ansible/ansible
# 2                 https://github.com/trailofbits/algo
# 3       https://github.com/MichaelCade/90DaysOfDevOps
# 4        https://github.com/StreisandEffect/streisand
# 5        https://github.com/kubernetes-sigs/kubespray
# 6                      https://github.com/ansible/awx
# 7            https://github.com/semaphoreui/semaphore
# 8                  https://github.com/easzlab/kubeasz
# 9           https://github.com/netbootxyz/netboot.xyz
# 10  https://github.com/geerlingguy/ansible-for-devops
# 11            https://github.com/Tikam02/DevOps-Guide
# 12                https://github.com/khuedoan/homelab
# 13    https://github.com/geerlingguy/mac-dev-playbook
# 14        https://github.com/Orange-Cyberdefense/GOAD
# 15                 https://github.com/rundeck/rundeck
# 16     https://github.com/ChristianLempa/boilerplates
# 17       https://github.com/KubeOperator/KubeOperator
# 18              https://github.com/clong/DetectionLab
# 19  https://github.com/dev-sec/ansible-collection-...

# %%
# save file to csv
get_topic_repos(get_topic_page(urls[4])).to_csv('ansible.csv', index=None)

# %%
# Fetch and extract repository information from the topic page at urls[20]
urls[20]
# Out:
# 'https://github.com/topics/chrome-extension'

# %%
# Fetch and extract repository information from the topic page at urls[20]
get_topic_repos(get_topic_page(urls[20]))
# Out:
#                Username           Repository Name  Stars  \
# 0            jaywcjlove             linux-command  33000
# 1        refined-github            refined-github  26100
# 2     openai-translator         openai-translator  24300
# 3            darkreader                darkreader  20500
# 4           dailydotdev                     daily  19300
# 5        gildas-lormeau                SingleFile  17200
# 6             AutomaApp                    automa  16200
# 7               checkly         headless-recorder  15100
# 8   immersive-translate       immersive-translate  15000
# 9                 unbug                    codelf  14200
# 10            alyssaxuu                 screenity  13900
# 11                wong2  chatgpt-google-extension  13200
# 12              Anarios    return-youtube-dislike  13000
# 13                crimx              ext-saladict  12400
# 14            xifangczy                 cat-catch  12100
# 15              listen1  listen1_chrome_extension  11600
# 16             PlasmoHQ                    plasmo  11400
# 17               ajayyy              SponsorBlock  11100
# 18            josStorer                chatGPTBox  10500
# 19          chathub-dev                   chathub  10200
#
#                                        Repository URL
# 0         https://github.com/jaywcjlove/linux-command
# 1    https://github.com/refined-github/refined-github
# 2   https://github.com/openai-translator/openai-tr...
# 3            https://github.com/darkreader/darkreader
# 4                https://github.com/dailydotdev/daily
# 5        https://github.com/gildas-lormeau/SingleFile
# 6                 https://github.com/AutomaApp/automa
# 7        https://github.com/checkly/headless-recorder
# 8   https://github.com/immersive-translate/immersi...
# 9                     https://github.com/unbug/codelf
# 10             https://github.com/alyssaxuu/screenity
# 11  https://github.com/wong2/chatgpt-google-extension
# 12  https://github.com/Anarios/return-youtube-dislike
# 13              https://github.com/crimx/ext-saladict
# 14             https://github.com/xifangczy/cat-catch
# 15  https://github.com/listen1/listen1_chrome_exte...
# 16                 https://github.com/PlasmoHQ/plasmo
# 17             https://github.com/ajayyy/SponsorBlock
# 18            https://github.com/josStorer/chatGPTBox
# 19             https://github.com/chathub-dev/chathub

# %%
# save file to csv
get_topic_repos(get_topic_page(urls[4])).to_csv('chrome-extension.csv', index=None)

# %% [markdown]
# # 6 Technical Comments
#
# **Techniques to avoid being banned when scraping**
#
# 1. in addition to time.sleep, consider using the rotating proxy to avoid your IP being blocked when scraping websites.
# 2. Rotating Proxies (Use services like ScraperAPI, Bright Data, or free proxy lists)
#
# 3. Randomized User-Agents (Switch browser headers with fake_useragent)
#
# 4. Session Persistence (Use requests.Session() to maintain cookies)
#
# 5. Delays & Randomization (time.sleep(random.uniform(3, 10)) to vary delays)
#
# 6. Headless Browsing (Use Selenium or Playwright when necessary)

# %% [markdown]
# #7 NEXT ACTIVITY
#
# 1. Get the list of topics from the topic page (https://github.com/topics)
#   - https://github.com/topics, is a topic page
# 2. Get the list of top repos from the individual topic pages (Example: https://github.com/topics/3d)
#   - 3D is a topic
#   - https://github.com/topics/3d, is a 3D topic page
# 3. For each topic, create a CSV of the top repos for the topic

# %% [markdown]
# **Loops through URLs, fetches data from each, extracts repository info**
# - repository info has (username, repository name, and stars)

# %%
for url in urls:  # Loop through each URL in the list
    repo_info = get_topic_repos(get_topic_page(url))  # Fetch and extract repo info
    print(repo_info)  # Print or store the extracted information
# Out:
#               Username                Repository Name   Stars  \
# 0               mrdoob                       three.js  105000
# 1               pmndrs              react-three-fiber   28500
# 2               libgdx                         libgdx   23900
# 3            BabylonJS                     Babylon.js   23800
# 4              FreeCAD                        FreeCAD   23700
# 5                ssloy                   tinyrenderer   21600
# 6              lettier  3d-game-shaders-for-beginners   18500
# 7             aframevr                         aframe   17000
# 8              blender                        blender   14700
# 9             CesiumGS                         cesium   13500
# 10                4ian                       GDevelop   13500
# 11             isl-org                         Open3D   12100
# 12            MonoGame                       MonoGame   11900
# 13              mapbox                   mapbox-gl-js   11500
# 14           metafizzy                           zdog   10500
# 15  nerfstudio-project                     nerfstudio   10000
# 16         timzhang642            3D-Machine-Learning    9900
# 17           DavidHDev                     react-bits    9900
# 18           microsoft                        TRELLIS    8700
# 19               cocos                   cocos-engine    8500
#
#                                        Repository URL
# 0                  https://github.com/mrdoob/three.js
# 1         https://github.com/pmndrs/react-three-fiber
# 2                    https://github.com/libgdx/libgdx
# 3             https://github.com/BabylonJS/Babylon.js
# 4                  https://github.com/FreeCAD/FreeCAD
# 5               https://github.com/ssloy/tinyrenderer
# 6   https://github.com/lettier/3d-game-shaders-for...
# 7                  https://github.com/aframevr/aframe
# 8                  https://github.com/blender/blender
# 9                  https://github.com/CesiumGS/cesium
# 10                   https://github.com/4ian/GDevelop
# 11                  https://github.com/isl-org/Open3D
# 12               https://github.com/MonoGame/MonoGame
# 13             https://github.com/mapbox/mapbox-gl-js
# 14                  https://github.com/metafizzy/zdog
# 15   https://github.com/nerfstudio-project/nerfstudio
# 16  https://github.com/timzhang642/3D-Machine-Lear...
# 17            https://github.com/DavidHDev/react-bits
# 18               https://github.com/microsoft/TRELLIS
# 19              https://github.com/cocos/cocos-engine
#                   Username                                    Repository Name  \
# 0                 ljianshu                                               Blog
# 1                metafizzy                                    infinite-scroll
# 2               olifolkerd                                          tabulator
# 3                developit                                            unfetch
# 4              jquery-form                                               form
# 5                  elbywan                                             wretch
# 6                Studio-42                                           elFinder
# 7                  alovajs                                              alova
# 8                     dwyl  learn-to-send-email-via-google-script-html-no-...
# 9                      ded                                            reqwest
# 10                  wendux                                          ajax-hook
# 11                LeaVerou                                              bliss
# 12                noelboss                                       featherlight
# 13                craftpip                                     jquery-confirm
# 14                     k8w                                              tsrpc
# 15                   nette                                              tracy
# 16                taoensso                                              sente
# 17               loadingio                                        css-spinner
# 18  codingforentrepreneurs                                          eCommerce
# 19               joaomilho                                         Enterprise
#
#     Stars                                     Repository URL
# 0    7900                   https://github.com/ljianshu/Blog
# 1    7500       https://github.com/metafizzy/infinite-scroll
# 2    7000            https://github.com/olifolkerd/tabulator
# 3    5700               https://github.com/developit/unfetch
# 4    5200                https://github.com/jquery-form/form
# 5    4900                  https://github.com/elbywan/wretch
# 6    4700              https://github.com/Studio-42/elFinder
# 7    3200                   https://github.com/alovajs/alova
# 8    3200  https://github.com/dwyl/learn-to-send-email-vi...
# 9    2900                     https://github.com/ded/reqwest
# 10   2600                https://github.com/wendux/ajax-hook
# 11   2400                  https://github.com/LeaVerou/bliss
# 12   2100           https://github.com/noelboss/featherlight
# 13   1900         https://github.com/craftpip/jquery-confirm
# 14   1800                       https://github.com/k8w/tsrpc
# 15   1800                     https://github.com/nette/tracy
# 16   1800                  https://github.com/taoensso/sente
# 17   1800           https://github.com/loadingio/css-spinner
# 18   1600  https://github.com/codingforentrepreneurs/eCom...
# 19   1600            https://github.com/joaomilho/Enterprise
#                 Username                Repository Name   Stars  \
# 0                jwasham    coding-interview-university  314000
# 1          TheAlgorithms                         Python  199000
# 2               trekhleb          javascript-algorithms  191000
# 3                CyC2018                       CS-Notes  180000
# 4               yangshun        tech-interview-handbook  125000
# 5                krahets                     hello-algo  111000
# 6                 kdn251                     interviews   64000
# 7          TheAlgorithms                           Java   61200
# 8           azl397985856                       leetcode   55200
# 9        youngyangyang04                leetcode-master   55100
# 10  algorithm-visualizer           algorithm-visualizer   47300
# 11                huihut                      interview   35800
# 12              halfrost                    LeetCode-Go   33400
# 13         TheAlgorithms                     JavaScript   33000
# 14         TheAlgorithms                    C-Plus-Plus   31500
# 15           donnemartin  interactive-coding-challenges   30100
# 16          crossoverJie                       JCSprout   27100
# 17          AtsushiSakai                 PythonRobotics   24600
# 18                  keon                     algorithms   24400
# 19                 mxgmn           WaveFunctionCollapse   23900
#
#                                        Repository URL
# 0   https://github.com/jwasham/coding-interview-un...
# 1             https://github.com/TheAlgorithms/Python
# 2   https://github.com/trekhleb/javascript-algorithms
# 3                 https://github.com/CyC2018/CS-Notes
# 4   https://github.com/yangshun/tech-interview-han...
# 5               https://github.com/krahets/hello-algo
# 6                https://github.com/kdn251/interviews
# 7               https://github.com/TheAlgorithms/Java
# 8            https://github.com/azl397985856/leetcode
# 9   https://github.com/youngyangyang04/leetcode-ma...
# 10  https://github.com/algorithm-visualizer/algori...
# 11                https://github.com/huihut/interview
# 12            https://github.com/halfrost/LeetCode-Go
# 13        https://github.com/TheAlgorithms/JavaScript
# 14       https://github.com/TheAlgorithms/C-Plus-Plus
# 15  https://github.com/donnemartin/interactive-cod...
# 16           https://github.com/crossoverJie/JCSprout
# 17     https://github.com/AtsushiSakai/PythonRobotics
# 18                 https://github.com/keon/algorithms
# 19      https://github.com/mxgmn/WaveFunctionCollapse
#            Username     Repository Name  Stars  \
# 0             amphp                 amp   4300
# 1             danog       MadelineProto   3000
# 2             amphp            parallel    809
# 3          unreal4u        telegram-api    795
# 4             amphp         http-client    713
# 5             amphp         byte-stream    378
# 6             amphp               mysql    370
# 7   php-service-bus         service-bus    347
# 8             amphp  parallel-functions    272
# 9         xtrime-ru         TelegramRSS    263
# 10            amphp              socket    244
# 11            amphp             process    239
# 12            amphp                sync    172
# 13            amphp                 dns    171
# 14            amphp               redis    163
# 15            amphp    websocket-client    152
# 16            amphp       serialization    120
# 17          kelunik                acme    120
# 18            amphp    websocket-server    119
# 19            amphp               cache    110
#
#                                     Repository URL
# 0                     https://github.com/amphp/amp
# 1           https://github.com/danog/MadelineProto
# 2                https://github.com/amphp/parallel
# 3         https://github.com/unreal4u/telegram-api
# 4             https://github.com/amphp/http-client
# 5             https://github.com/amphp/byte-stream
# 6                   https://github.com/amphp/mysql
# 7   https://github.com/php-service-bus/service-bus
# 8      https://github.com/amphp/parallel-functions
# 9         https://github.com/xtrime-ru/TelegramRSS
# 10                 https://github.com/amphp/socket
# 11                https://github.com/amphp/process
# 12                   https://github.com/amphp/sync
# 13                    https://github.com/amphp/dns
# 14                  https://github.com/amphp/redis
# 15       https://github.com/amphp/websocket-client
# 16          https://github.com/amphp/serialization
# 17                 https://github.com/kelunik/acme
# 18       https://github.com/amphp/websocket-server
# 19                  https://github.com/amphp/cache
#             Username               Repository Name   Stars  \
# 0            flutter                       flutter  169000
# 1           facebook                  react-native  121000
# 2         Genymobile                        scrcpy  120000
# 3          justjavac  free-programming-books-zh_CN  113000
# 4   Hack-with-Github               Awesome-Hacking   90600
# 5             Solido               awesome-flutter   55300
# 6         tldr-pages                          tldr   54500
# 7           wasabeef            awesome-android-ui   52000
# 8             google         material-design-icons   51300
# 9          laurent22                        joplin   48400
# 10          appwrite                      appwrite   47900
# 11            square                        okhttp   46300
# 12           android          architecture-samples   44900
# 13            square                      retrofit   43400
# 14            skylot                          jadx   43400
# 15          dcloudio                       uni-app   40600
# 16            termux                    termux-app   40100
# 17          fastlane                      fastlane   40000
# 18             2dust                       v2rayNG   39500
# 19          KRTirtho                       spotube   39100
#
#                                        Repository URL
# 0                  https://github.com/flutter/flutter
# 1            https://github.com/facebook/react-native
# 2                https://github.com/Genymobile/scrcpy
# 3   https://github.com/justjavac/free-programming-...
# 4   https://github.com/Hack-with-Github/Awesome-Ha...
# 5           https://github.com/Solido/awesome-flutter
# 6                  https://github.com/tldr-pages/tldr
# 7      https://github.com/wasabeef/awesome-android-ui
# 8     https://github.com/google/material-design-icons
# 9                 https://github.com/laurent22/joplin
# 10               https://github.com/appwrite/appwrite
# 11                   https://github.com/square/okhttp
# 12    https://github.com/android/architecture-samples
# 13                 https://github.com/square/retrofit
# 14                     https://github.com/skylot/jadx
# 15                https://github.com/dcloudio/uni-app
# 16               https://github.com/termux/termux-app
# 17               https://github.com/fastlane/fastlane
# 18                   https://github.com/2dust/v2rayNG
# 19                https://github.com/KRTirtho/spotube
#           Username                    Repository Name   Stars  \
# 0        justjavac       free-programming-books-zh_CN  113000
# 1          angular                            angular   97400
# 2      storybookjs                          storybook   86300
# 3      leonardomso                     33-js-concepts   65000
# 4       ionic-team                    ionic-framework   51600
# 5         prettier                           prettier   50200
# 6         Asabeneh              30-Days-Of-JavaScript   44100
# 7          SheetJS                            sheetjs   35500
# 8         wailsapp                              wails   27500
# 9          angular                        angular-cli   26900
# 10   paperless-ngx                      paperless-ngx   26100
# 11        sudheerj     javascript-interview-questions   25300
# 12            nrwl                                 nx   25100
# 13    NativeScript                       NativeScript   24700
# 14         angular                         components   24600
# 15    goldbergyoni  javascript-testing-best-practices   24300
# 16          pubkey                               rxdb   22200
# 17        jhipster                 generator-jhipster   21800
# 18         teambit                                bit   18000
# 19  jasontaylordev                  CleanArchitecture   17800
#
#                                        Repository URL
# 0   https://github.com/justjavac/free-programming-...
# 1                  https://github.com/angular/angular
# 2            https://github.com/storybookjs/storybook
# 3       https://github.com/leonardomso/33-js-concepts
# 4       https://github.com/ionic-team/ionic-framework
# 5                https://github.com/prettier/prettier
# 6   https://github.com/Asabeneh/30-Days-Of-JavaScript
# 7                  https://github.com/SheetJS/sheetjs
# 8                   https://github.com/wailsapp/wails
# 9              https://github.com/angular/angular-cli
# 10     https://github.com/paperless-ngx/paperless-ngx
# 11  https://github.com/sudheerj/javascript-intervi...
# 12                         https://github.com/nrwl/nx
# 13       https://github.com/NativeScript/NativeScript
# 14              https://github.com/angular/components
# 15  https://github.com/goldbergyoni/javascript-tes...
# 16                     https://github.com/pubkey/rxdb
# 17     https://github.com/jhipster/generator-jhipster
# 18                     https://github.com/teambit/bit
# 19  https://github.com/jasontaylordev/CleanArchite...
#                Username               Repository Name  Stars  \
# 0          bregman-arie              devops-exercises  72500
# 1               ansible                       ansible  64500
# 2           trailofbits                          algo  29300
# 3           MichaelCade                90DaysOfDevOps  27800
# 4       StreisandEffect                     streisand  23300
# 5       kubernetes-sigs                     kubespray  16800
# 6               ansible                           awx  14500
# 7           semaphoreui                     semaphore  11600
# 8               easzlab                       kubeasz  10800
# 9            netbootxyz                   netboot.xyz  10000
# 10          geerlingguy            ansible-for-devops   8900
# 11              Tikam02                  DevOps-Guide   8600
# 12             khuedoan                       homelab   8500
# 13          geerlingguy              mac-dev-playbook   6400
# 14  Orange-Cyberdefense                          GOAD   6200
# 15              rundeck                       rundeck   5700
# 16       ChristianLempa                  boilerplates   5400
# 17         KubeOperator                  KubeOperator   5000
# 18                clong                  DetectionLab   4700
# 19              dev-sec  ansible-collection-hardening   4300
#
#                                        Repository URL
# 0    https://github.com/bregman-arie/devops-exercises
# 1                  https://github.com/ansible/ansible
# 2                 https://github.com/trailofbits/algo
# 3       https://github.com/MichaelCade/90DaysOfDevOps
# 4        https://github.com/StreisandEffect/streisand
# 5        https://github.com/kubernetes-sigs/kubespray
# 6                      https://github.com/ansible/awx
# 7            https://github.com/semaphoreui/semaphore
# 8                  https://github.com/easzlab/kubeasz
# 9           https://github.com/netbootxyz/netboot.xyz
# 10  https://github.com/geerlingguy/ansible-for-devops
# 11            https://github.com/Tikam02/DevOps-Guide
# 12                https://github.com/khuedoan/homelab
# 13    https://github.com/geerlingguy/mac-dev-playbook
# 14        https://github.com/Orange-Cyberdefense/GOAD
# 15                 https://github.com/rundeck/rundeck
# 16     https://github.com/ChristianLempa/boilerplates
# 17       https://github.com/KubeOperator/KubeOperator
# 18              https://github.com/clong/DetectionLab
# 19  https://github.com/dev-sec/ansible-collection-...
#         Username        Repository Name   Stars  \
# 0    public-apis            public-apis  334000
# 1         neovim                 neovim   88000
# 2        fastapi                fastapi   82700
# 3     hoppscotch             hoppscotch   70600
# 4         strapi                 strapi   65900
# 5        ocornut                  imgui   64200
# 6    meilisearch            meilisearch   50000
# 7        QuivrHQ                  quivr   37600
# 8           trpc                   trpc   36700
# 9      slatedocs                  slate   36100
# 10          Kong               insomnia   35900
# 11          ccxt                   ccxt   35300
# 12        httpie                    cli   35200
# 13        hasura         graphql-engine   31400
# 14        mudler                LocalAI   31300
# 15     Binaryify   NeteaseCloudMusicApi   30300
# 16      directus               directus   29700
# 17        encode  django-rest-framework   29000
# 18  chatanywhere           GPT_API_free   28600
# 19          YMFE                   yapi   27500
#
#                                        Repository URL
# 0          https://github.com/public-apis/public-apis
# 1                    https://github.com/neovim/neovim
# 2                  https://github.com/fastapi/fastapi
# 3            https://github.com/hoppscotch/hoppscotch
# 4                    https://github.com/strapi/strapi
# 5                    https://github.com/ocornut/imgui
# 6          https://github.com/meilisearch/meilisearch
# 7                    https://github.com/QuivrHQ/quivr
# 8                        https://github.com/trpc/trpc
# 9                  https://github.com/slatedocs/slate
# 10                   https://github.com/Kong/insomnia
# 11                       https://github.com/ccxt/ccxt
# 12                      https://github.com/httpie/cli
# 13           https://github.com/hasura/graphql-engine
# 14                  https://github.com/mudler/LocalAI
# 15  https://github.com/Binaryify/NeteaseCloudMusicApi
# 16               https://github.com/directus/directus
# 17    https://github.com/encode/django-rest-framework
# 18       https://github.com/chatanywhere/GPT_API_free
# 19                       https://github.com/YMFE/yapi
#             Username                 Repository Name  Stars  \
# 0            arendst                         Tasmota  23000
# 1     MarlinFirmware                          Marlin  16600
# 2         tinygo-org                          tinygo  16000
# 3          espressif                   arduino-esp32  14500
# 4            arduino                         Arduino  14300
# 5      SpacehuhnTech                esp8266_deauther  13900
# 6           rwaldron                     johnny-five  13300
# 7            gurugio  lowlevelprogramming-university  11800
# 8        hybridgroup                           gobot   9100
# 9         platformio                 platformio-core   8200
# 10    justcallmekoko                   ESP32Marauder   7200
# 11         bblanchon                     ArduinoJson   6900
# 12             tzapu                     WiFiManager   6800
# 13         ggerganov                          ggwave   6300
# 14          olikraus                            u8g2   5500
# 15     Serial-Studio                   Serial-Studio   5300
# 16         omriharel                            deej   5000
# 17    ClemensElflein                       OpenMower   4800
# 18  Arduino-IRremote                Arduino-IRremote   4700
# 19           arduino                     arduino-cli   4500
#
#                                        Repository URL
# 0                  https://github.com/arendst/Tasmota
# 1            https://github.com/MarlinFirmware/Marlin
# 2                https://github.com/tinygo-org/tinygo
# 3          https://github.com/espressif/arduino-esp32
# 4                  https://github.com/arduino/Arduino
# 5   https://github.com/SpacehuhnTech/esp8266_deauther
# 6             https://github.com/rwaldron/johnny-five
# 7   https://github.com/gurugio/lowlevelprogramming...
# 8                https://github.com/hybridgroup/gobot
# 9       https://github.com/platformio/platformio-core
# 10    https://github.com/justcallmekoko/ESP32Marauder
# 11           https://github.com/bblanchon/ArduinoJson
# 12               https://github.com/tzapu/WiFiManager
# 13                https://github.com/ggerganov/ggwave
# 14                   https://github.com/olikraus/u8g2
# 15     https://github.com/Serial-Studio/Serial-Studio
# 16                  https://github.com/omriharel/deej
# 17        https://github.com/ClemensElflein/OpenMower
# 18  https://github.com/Arduino-IRremote/Arduino-IR...
# 19             https://github.com/arduino/arduino-cli
#              Username               Repository Name  Stars  \
# 0           bitwarden                        server  16300
# 1        abpframework                           abp  13300
# 2              dotnet               AspNetCore.Docs  12800
# 3   aspnetboilerplate             aspnetboilerplate  11900
# 4        nopSolutions                   nopCommerce   9600
# 5         ElectronNET                  Electron.NET   7400
# 6          thangchung             clean-code-dotnet   7400
# 7           RicoSuter                         NSwag   7000
# 8       FastEndpoints                 FastEndpoints   5100
# 9              dotnet         aspnet-api-versioning   3100
# 10         mjebrahimi  Awesome-Microservices-DotNet   2900
# 11             milanm      DotNet-Developer-Roadmap   2800
# 12        loic-sharma                         BaGet   2700
# 13         smartstore                 SmartStoreNET   2600
# 14        serenity-is                      Serenity   2600
# 15  JimBobSquarePants                ImageProcessor   2500
# 16           TrilonIO  aspnetcore-angular-universal   1500
# 17         smartstore                    Smartstore   1300
# 18         MarimerLLC                          csla   1300
# 19           TrilonIO        aspnetcore-Vue-starter   1200
#
#                                        Repository URL
# 0                 https://github.com/bitwarden/server
# 1                 https://github.com/abpframework/abp
# 2           https://github.com/dotnet/AspNetCore.Docs
# 3   https://github.com/aspnetboilerplate/aspnetboi...
# 4         https://github.com/nopSolutions/nopCommerce
# 5         https://github.com/ElectronNET/Electron.NET
# 6     https://github.com/thangchung/clean-code-dotnet
# 7                  https://github.com/RicoSuter/NSwag
# 8      https://github.com/FastEndpoints/FastEndpoints
# 9     https://github.com/dotnet/aspnet-api-versioning
# 10  https://github.com/mjebrahimi/Awesome-Microser...
# 11  https://github.com/milanm/DotNet-Developer-Roa...
# 12               https://github.com/loic-sharma/BaGet
# 13        https://github.com/smartstore/SmartStoreNET
# 14            https://github.com/serenity-is/Serenity
# 15  https://github.com/JimBobSquarePants/ImageProc...
# 16  https://github.com/TrilonIO/aspnetcore-angular...
# 17           https://github.com/smartstore/Smartstore
# 18                 https://github.com/MarimerLLC/csla
# 19  https://github.com/TrilonIO/aspnetcore-Vue-sta...
#               Username               Repository Name   Stars  \
# 0         sindresorhus                       awesome  354000
# 1                vinta                awesome-python  239000
# 2   awesome-selfhosted            awesome-selfhosted  223000
# 3            trimstray  the-book-of-secret-knowledge  162000
# 4              avelino                    awesome-go  141000
# 5         521xueweihan                   HelloGitHub  101000
# 6       papers-we-love                papers-we-love   92000
# 7     Hack-with-Github               Awesome-Hacking   90600
# 8           jaywcjlove                   awesome-mac   81500
# 9            DopplerHQ   awesome-interview-questions   74100
# 10             MunGell         awesome-for-beginners   72800
# 11               enaqx                 awesome-react   67400
# 12             fffaraz                   awesome-cpp   62700
# 13       binhnguyennus           awesome-scalability   61200
# 14        sindresorhus                awesome-nodejs   60300
# 15         prakhar1989               awesome-courses   59700
# 16              Solido               awesome-flutter   55300
# 17            wasabeef            awesome-android-ui   52000
# 18           tiimgreen            github-cheat-sheet   50100
# 19     rust-unofficial                  awesome-rust   49500
#
#                                        Repository URL
# 0             https://github.com/sindresorhus/awesome
# 1             https://github.com/vinta/awesome-python
# 2   https://github.com/awesome-selfhosted/awesome-...
# 3   https://github.com/trimstray/the-book-of-secre...
# 4               https://github.com/avelino/awesome-go
# 5         https://github.com/521xueweihan/HelloGitHub
# 6    https://github.com/papers-we-love/papers-we-love
# 7   https://github.com/Hack-with-Github/Awesome-Ha...
# 8           https://github.com/jaywcjlove/awesome-mac
# 9   https://github.com/DopplerHQ/awesome-interview...
# 10   https://github.com/MunGell/awesome-for-beginners
# 11             https://github.com/enaqx/awesome-react
# 12             https://github.com/fffaraz/awesome-cpp
# 13  https://github.com/binhnguyennus/awesome-scala...
# 14     https://github.com/sindresorhus/awesome-nodejs
# 15     https://github.com/prakhar1989/awesome-courses
# 16          https://github.com/Solido/awesome-flutter
# 17     https://github.com/wasabeef/awesome-android-ui
# 18    https://github.com/tiimgreen/github-cheat-sheet
# 19    https://github.com/rust-unofficial/awesome-rust
#                Username                 Repository Name  Stars  \
# 0          bregman-arie                devops-exercises  72500
# 1          ByteByteGoHq               system-design-101  71300
# 2            localstack                      localstack  58300
# 3            serverless                      serverless  46600
# 4           donnemartin  data-science-ipython-notebooks  28000
# 5           danny-avila                       LibreChat  23800
# 6                pulumi                          pulumi  22700
# 7               getsops                            sops  18100
# 8       kubernetes-sigs                       kubespray  16800
# 9                   aws                         aws-cli  15900
# 10               milanm                  DevOps-Roadmap  15400
# 11          ramitsurana              awesome-kubernetes  15300
# 12             caprover                        caprover  13800
# 13  GoogleCloudPlatform                     terraformer  13400
# 14          donnemartin                     awesome-aws  12800
# 15                  aws                         aws-cdk  12000
# 16        prowler-cloud                         prowler  11400
# 17            infracost                       infracost  11400
# 18               apereo                             cas  11100
# 19                  aws                         chalice  10800
#
#                                        Repository URL
# 0    https://github.com/bregman-arie/devops-exercises
# 1   https://github.com/ByteByteGoHq/system-design-101
# 2            https://github.com/localstack/localstack
# 3            https://github.com/serverless/serverless
# 4   https://github.com/donnemartin/data-science-ip...
# 5            https://github.com/danny-avila/LibreChat
# 6                    https://github.com/pulumi/pulumi
# 7                     https://github.com/getsops/sops
# 8        https://github.com/kubernetes-sigs/kubespray
# 9                      https://github.com/aws/aws-cli
# 10           https://github.com/milanm/DevOps-Roadmap
# 11  https://github.com/ramitsurana/awesome-kubernetes
# 12               https://github.com/caprover/caprover
# 13  https://github.com/GoogleCloudPlatform/terrafo...
# 14         https://github.com/donnemartin/awesome-aws
# 15                     https://github.com/aws/aws-cdk
# 16           https://github.com/prowler-cloud/prowler
# 17             https://github.com/infracost/infracost
# 18                      https://github.com/apereo/cas
# 19                     https://github.com/aws/chalice
#          Username              Repository Name  Stars  \
# 0       microsoft  generative-ai-for-beginners  76500
# 1    bregman-arie             devops-exercises  72500
# 2     danny-avila                    LibreChat  23800
# 3          pulumi                       pulumi  22700
# 4         getsops                         sops  18100
# 5          milanm               DevOps-Roadmap  15400
# 6     ramitsurana           awesome-kubernetes  15300
# 7           Azure   azure-quickstart-templates  14300
# 8        caprover                     caprover  13800
# 9   prowler-cloud                      prowler  11400
# 10      infracost                    infracost  11400
# 11         budtmo               docker-android  10500
# 12      microsoft       computervision-recipes   9600
# 13         google                     go-cloud   9600
# 14        Netflix                     metaflow   8700
# 15  YSGStudyHards                  DotNetGuide   8000
# 16      microsoft              azuredatastudio   7700
# 17       midwayjs                       midway   7500
# 18   bridgecrewio                      checkov   7500
# 19     thangchung            clean-code-dotnet   7400
#
#                                        Repository URL
# 0   https://github.com/microsoft/generative-ai-for...
# 1    https://github.com/bregman-arie/devops-exercises
# 2            https://github.com/danny-avila/LibreChat
# 3                    https://github.com/pulumi/pulumi
# 4                     https://github.com/getsops/sops
# 5            https://github.com/milanm/DevOps-Roadmap
# 6   https://github.com/ramitsurana/awesome-kubernetes
# 7   https://github.com/Azure/azure-quickstart-temp...
# 8                https://github.com/caprover/caprover
# 9            https://github.com/prowler-cloud/prowler
# 10             https://github.com/infracost/infracost
# 11           https://github.com/budtmo/docker-android
# 12  https://github.com/microsoft/computervision-re...
# 13                 https://github.com/google/go-cloud
# 14                https://github.com/Netflix/metaflow
# 15       https://github.com/YSGStudyHards/DotNetGuide
# 16       https://github.com/microsoft/azuredatastudio
# 17                 https://github.com/midwayjs/midway
# 18            https://github.com/bridgecrewio/checkov
# 19    https://github.com/thangchung/clean-code-dotnet
#                       Username              Repository Name  Stars  \
# 0                        babel                        babel  43500
# 1                  swc-project                          swc  32000
# 2                        nylas                   nylas-mail  24800
# 3   electron-react-boilerplate   electron-react-boilerplate  23600
# 4                SimulatedGREG                 electron-vue  15500
# 5                         grab              front-end-guide  15200
# 6                  jamiebuilds               babel-handbook  12100
# 7                    developit                          htm   8800
# 8                     ast-grep                     ast-grep   8400
# 9                      grommet                      grommet   8400
# 10                ben-rogerson                   twin.macro   8000
# 11                      fkling                  astexplorer   6300
# 12           angular-fullstack  generator-angular-fullstack   6100
# 13                         thx                     gogocode   5900
# 14             documentationjs                documentation   5800
# 15                       insin                          nwb   5600
# 16                     thinkjs                      thinkjs   5300
# 17                      egoist                          poi   5200
# 18                duxianwei520                        react   5100
# 19                       babel                 babel-loader   4900
#
#                                        Repository URL
# 0                      https://github.com/babel/babel
# 1                  https://github.com/swc-project/swc
# 2                 https://github.com/nylas/nylas-mail
# 3   https://github.com/electron-react-boilerplate/...
# 4       https://github.com/SimulatedGREG/electron-vue
# 5             https://github.com/grab/front-end-guide
# 6       https://github.com/jamiebuilds/babel-handbook
# 7                    https://github.com/developit/htm
# 8                https://github.com/ast-grep/ast-grep
# 9                  https://github.com/grommet/grommet
# 10         https://github.com/ben-rogerson/twin.macro
# 11              https://github.com/fkling/astexplorer
# 12  https://github.com/angular-fullstack/generator...
# 13                    https://github.com/thx/gogocode
# 14   https://github.com/documentationjs/documentation
# 15                       https://github.com/insin/nwb
# 16                 https://github.com/thinkjs/thinkjs
# 17                      https://github.com/egoist/poi
# 18              https://github.com/duxianwei520/react
# 19              https://github.com/babel/babel-loader
#            Username          Repository Name   Stars  \
# 0             jlevy  the-art-of-command-line  155000
# 1            nvm-sh                      nvm   83100
# 2          junegunn                      fzf   69000
# 3          starship                 starship   47800
# 4            google                       zx   43800
# 5           LeCoupa      awesome-cheatsheets   42000
# 6   acmesh-official                  acme.sh   42000
# 7          koalaman               shellcheck   37200
# 8        dylanaraps          pure-bash-bible   36900
# 9           alebcay            awesome-shell   34000
# 10       jaywcjlove            linux-command   33000
# 11    mathiasbynens                 dotfiles   30700
# 12      kingToolbox                 WindTerm   25700
# 13      ajeetdsouza                   zoxide   25700
# 14          withfig             autocomplete   24800
# 15          asdf-vm                     asdf   23200
# 16          atuinsh                    atuin   23100
# 17       warpdotdev                     Warp   22900
# 18       dylanaraps                 neofetch   22700
# 19              Nyr          openvpn-install   19700
#
#                                       Repository URL
# 0   https://github.com/jlevy/the-art-of-command-line
# 1                      https://github.com/nvm-sh/nvm
# 2                    https://github.com/junegunn/fzf
# 3               https://github.com/starship/starship
# 4                       https://github.com/google/zx
# 5     https://github.com/LeCoupa/awesome-cheatsheets
# 6         https://github.com/acmesh-official/acme.sh
# 7             https://github.com/koalaman/shellcheck
# 8      https://github.com/dylanaraps/pure-bash-bible
# 9           https://github.com/alebcay/awesome-shell
# 10       https://github.com/jaywcjlove/linux-command
# 11         https://github.com/mathiasbynens/dotfiles
# 12           https://github.com/kingToolbox/WindTerm
# 13             https://github.com/ajeetdsouza/zoxide
# 14           https://github.com/withfig/autocomplete
# 15                   https://github.com/asdf-vm/asdf
# 16                  https://github.com/atuinsh/atuin
# 17                https://github.com/warpdotdev/Warp
# 18            https://github.com/dylanaraps/neofetch
# 19            https://github.com/Nyr/openvpn-install
#             Username   Repository Name  Stars  \
# 0            bitcoin           bitcoin  82700
# 1          freqtrade         freqtrade  37600
# 2               ccxt              ccxt  35300
# 3        bitcoinbook       bitcoinbook  24200
# 4       HelloZeroNet           ZeroNet  18500
# 5        solana-labs            solana  14000
# 6           bbfamily               abu  13300
# 7         hummingbot        hummingbot  12100
# 8           UFund-Me              Qbot  10800
# 9            askmike             gekko  10100
# 10         getumbrel            umbrel   8600
# 11               dvf        blockchain   7900
# 12  lightningnetwork               lnd   7900
# 13          spesmilo          electrum   7800
# 14            lbryio          lbry-sdk   7200
# 15             yeasy  blockchain_guide   6900
# 16      btcpayserver      btcpayserver   6700
# 17          btcsuite              btcd   6400
# 18          jesse-ai             jesse   6200
# 19         bitcoinjs     bitcoinjs-lib   5800
#
#                                   Repository URL
# 0             https://github.com/bitcoin/bitcoin
# 1         https://github.com/freqtrade/freqtrade
# 2                   https://github.com/ccxt/ccxt
# 3     https://github.com/bitcoinbook/bitcoinbook
# 4        https://github.com/HelloZeroNet/ZeroNet
# 5          https://github.com/solana-labs/solana
# 6                https://github.com/bbfamily/abu
# 7       https://github.com/hummingbot/hummingbot
# 8               https://github.com/UFund-Me/Qbot
# 9               https://github.com/askmike/gekko
# 10           https://github.com/getumbrel/umbrel
# 11             https://github.com/dvf/blockchain
# 12       https://github.com/lightningnetwork/lnd
# 13          https://github.com/spesmilo/electrum
# 14            https://github.com/lbryio/lbry-sdk
# 15     https://github.com/yeasy/blockchain_guide
# 16  https://github.com/btcpayserver/btcpayserver
# 17              https://github.com/btcsuite/btcd
# 18             https://github.com/jesse-ai/jesse
# 19    https://github.com/bitcoinjs/bitcoinjs-lib
#             Username                       Repository Name   Stars  \
# 0               twbs                             bootstrap  172000
# 1         ColorlibHQ                              AdminLTE   44500
# 2             tabler                                tabler   39000
# 3        mdbootstrap                            mdb-ui-kit   24300
# 4    react-bootstrap                       react-bootstrap   22500
# 5         ColorlibHQ                            gentelella   21100
# 6            verekia                 js-stack-from-scratch   20100
# 7         thomaspark                            bootswatch   14700
# 8      bootstrap-vue                         bootstrap-vue   14500
# 9          selectize                          selectize.js   13100
# 10       uxsolutions                  bootstrap-datepicker   12700
# 11            coreui  coreui-free-bootstrap-admin-template   12100
# 12         wenzhixin                       bootstrap-table   11800
# 13        Templarian                        MaterialDesign   11100
# 14        reactstrap                            reactstrap   10600
# 15  snapappointments                      bootstrap-select    9900
# 16    StartBootstrap             startbootstrap-sb-admin-2    9800
# 17       mdbootstrap         material-design-for-bootstrap    9300
# 18         cotes2020                   jekyll-theme-chirpy    8400
# 19      ng-bootstrap                          ng-bootstrap    8200
#
#                                        Repository URL
# 0                   https://github.com/twbs/bootstrap
# 1              https://github.com/ColorlibHQ/AdminLTE
# 2                    https://github.com/tabler/tabler
# 3           https://github.com/mdbootstrap/mdb-ui-kit
# 4   https://github.com/react-bootstrap/react-boots...
# 5            https://github.com/ColorlibHQ/gentelella
# 6    https://github.com/verekia/js-stack-from-scratch
# 7            https://github.com/thomaspark/bootswatch
# 8      https://github.com/bootstrap-vue/bootstrap-vue
# 9           https://github.com/selectize/selectize.js
# 10  https://github.com/uxsolutions/bootstrap-datep...
# 11  https://github.com/coreui/coreui-free-bootstra...
# 12       https://github.com/wenzhixin/bootstrap-table
# 13       https://github.com/Templarian/MaterialDesign
# 14           https://github.com/reactstrap/reactstrap
# 15  https://github.com/snapappointments/bootstrap-...
# 16  https://github.com/StartBootstrap/startbootstr...
# 17  https://github.com/mdbootstrap/material-design...
# 18   https://github.com/cotes2020/jekyll-theme-chirpy
# 19       https://github.com/ng-bootstrap/ng-bootstrap
#                Username               Repository Name  Stars  \
# 0                  ccxt                          ccxt  35300
# 1              feder-cr  Jobs_Applier_AI_Agent_AIHawk  27800
# 2   python-telegram-bot           python-telegram-bot  27200
# 3             discordjs                    discord.js  25800
# 4               wechaty                       wechaty  21300
# 5                RasaHQ                          rasa  19900
# 6               InstaPy                       InstaPy  17200
# 7               hubotio                         hubot  16700
# 8           pedroslopez               whatsapp-web.js  16500
# 9               leon-ai                          leon  16100
# 10               Rapptz                    discord.py  15300
# 11     tgbot-collection                      YYeTsBot  15100
# 12               lss233                     kirara-ai  14800
# 13           gunthercox                    ChatterBot  14300
# 14           hummingbot                    hummingbot  12100
# 15              howdyai                        botkit  11500
# 16                Mrs4s                     go-cqhttp  10500
# 17               sfyc23                EverydayWechat  10100
# 18                yagop         node-telegram-bot-api   8700
# 19             telegraf                      telegraf   8600
#
#                                        Repository URL
# 0                        https://github.com/ccxt/ccxt
# 1   https://github.com/feder-cr/Jobs_Applier_AI_Ag...
# 2   https://github.com/python-telegram-bot/python-...
# 3             https://github.com/discordjs/discord.js
# 4                  https://github.com/wechaty/wechaty
# 5                      https://github.com/RasaHQ/rasa
# 6                  https://github.com/InstaPy/InstaPy
# 7                    https://github.com/hubotio/hubot
# 8      https://github.com/pedroslopez/whatsapp-web.js
# 9                     https://github.com/leon-ai/leon
# 10               https://github.com/Rapptz/discord.py
# 11       https://github.com/tgbot-collection/YYeTsBot
# 12                https://github.com/lss233/kirara-ai
# 13           https://github.com/gunthercox/ChatterBot
# 14           https://github.com/hummingbot/hummingbot
# 15                  https://github.com/howdyai/botkit
# 16                 https://github.com/Mrs4s/go-cqhttp
# 17           https://github.com/sfyc23/EverydayWechat
# 18     https://github.com/yagop/node-telegram-bot-api
# 19               https://github.com/telegraf/telegraf
#          Username          Repository Name   Stars  \
# 0      Genymobile                   scrcpy  120000
# 1          neovim                   neovim   88000
# 2      obsproject               obs-studio   63200
# 3         fffaraz              awesome-cpp   62700
# 4             git                      git   54100
# 5          FFmpeg                   FFmpeg   48800
# 6   serhii-londar  open-source-mac-os-apps   43400
# 7             vim                      vim   37800
# 8            curl                     curl   37300
# 9          huihut                interview   35800
# 10     mpv-player                      mpv   30200
# 11     kovidgoyal                    kitty   26900
# 12          ossrs                      srs   26600
# 13         ggreer      the_silver_searcher   26400
# 14        raysan5                   raylib   25600
# 15      microsoft                    vcpkg   24400
# 16         google              flatbuffers   24000
# 17           ruby                     ruby   22500
# 18        hashcat                  hashcat   22300
# 19    forthespada                 CS-Books   22200
#
#                                        Repository URL
# 0                https://github.com/Genymobile/scrcpy
# 1                    https://github.com/neovim/neovim
# 2            https://github.com/obsproject/obs-studio
# 3              https://github.com/fffaraz/awesome-cpp
# 4                          https://github.com/git/git
# 5                    https://github.com/FFmpeg/FFmpeg
# 6   https://github.com/serhii-londar/open-source-m...
# 7                          https://github.com/vim/vim
# 8                        https://github.com/curl/curl
# 9                 https://github.com/huihut/interview
# 10                  https://github.com/mpv-player/mpv
# 11                https://github.com/kovidgoyal/kitty
# 12                       https://github.com/ossrs/srs
# 13      https://github.com/ggreer/the_silver_searcher
# 14                  https://github.com/raysan5/raylib
# 15                 https://github.com/microsoft/vcpkg
# 16              https://github.com/google/flatbuffers
# 17                       https://github.com/ruby/ruby
# 18                 https://github.com/hashcat/hashcat
# 19            https://github.com/forthespada/CS-Books
#             Username               Repository Name   Stars  \
# 0           electron                      electron  116000
# 1          puppeteer                     puppeteer   90200
# 2          microsoft                    playwright   71000
# 3        FiloSottile                        mkcert   52800
# 4         jaywcjlove                 linux-command   33000
# 5           feder-cr  Jobs_Applier_AI_Agent_AIHawk   27800
# 6              ovity                      octotree   23000
# 7   segment-boneyard                     nightmare   19600
# 8     gildas-lormeau                    SingleFile   17200
# 9       GoogleChrome     chrome-extensions-samples   16200
# 10           checkly             headless-recorder   15100
# 11            google               WebFundamentals   13900
# 12        schickling                    chromeless   13200
# ...
# 16      simplecov-ruby                  simplecov   4800
# 17               phpro                    grumphp   4200
# 18            htmlhint                   HTMLHint   3100
# 19            crate-ci                      typos   3000
#
#                                        Repository URL
# 0                  https://github.com/realm/SwiftLint
# 1                   https://github.com/facebook/infer
# 2   https://github.com/analysis-tools-dev/static-a...
# 3   https://github.com/federico-busato/Modern-CPP-...
# 4    https://github.com/Kristories/awesome-guidelines
# 5        https://github.com/super-linter/super-linter
# 6            https://github.com/SonarSource/sonarqube
# 7            https://github.com/checkstyle/checkstyle
# 8              https://github.com/reviewdog/reviewdog
# 9              https://github.com/facebook/pyre-check
# 10                   https://github.com/detekt/detekt
# 11  https://github.com/trekhleb/state-of-the-art-s...
# 12  https://github.com/import-js/eslint-plugin-import
# 13               https://github.com/pylint-dev/pylint
# 14                         https://github.com/pmd/pmd
# 15                https://github.com/kucherenko/jscpd
# 16        https://github.com/simplecov-ruby/simplecov
# 17                   https://github.com/phpro/grumphp
# 18               https://github.com/htmlhint/HTMLHint
# 19                  https://github.com/crate-ci/typos
#                   Username             Repository Name  Stars  \
# 0                    ovity                    octotree  23000
# 1                gitpod-io                      gitpod  13200
# 2                reviewdog                   reviewdog   8300
# 3                  qodo-ai                    pr-agent   7400
# 4                   danger                      danger   5500
# 5                   danger                   danger-js   5300
# 6                     joho         awesome-code-review   4500
# 7              ajinabraham                  nodejsscan   2500
# 8                microsoft  vscode-pull-request-github   2400
# 9                 crev-dev                  cargo-crev   2200
# 10                     mbj                      mutant   2000
# 11                 houndci                       hound   2000
# 12              mattzcarey             code-review-gpt   1900
# 13                 Tencent                CodeAnalysis   1700
# 14            coderabbitai              ai-pr-reviewer   1700
# 15             reviewboard                 reviewboard   1600
# 16           ryanmcdermott            code-review-tips   1500
# 17                 bit4woo                  python_sec   1300
# 18  code-review-checklists            java-concurrency   1300
# 19             jiangsir404              Audit-Learning    979
#
#                                        Repository URL
# 0                   https://github.com/ovity/octotree
# 1                 https://github.com/gitpod-io/gitpod
# 2              https://github.com/reviewdog/reviewdog
# 3                 https://github.com/qodo-ai/pr-agent
# 4                    https://github.com/danger/danger
# 5                 https://github.com/danger/danger-js
# 6         https://github.com/joho/awesome-code-review
# 7           https://github.com/ajinabraham/nodejsscan
# 8   https://github.com/microsoft/vscode-pull-reque...
# 9              https://github.com/crev-dev/cargo-crev
# 10                      https://github.com/mbj/mutant
# 11                   https://github.com/houndci/hound
# 12      https://github.com/mattzcarey/code-review-gpt
# 13            https://github.com/Tencent/CodeAnalysis
# 14     https://github.com/coderabbitai/ai-pr-reviewer
# 15         https://github.com/reviewboard/reviewboard
# 16  https://github.com/ryanmcdermott/code-review-tips
# 17              https://github.com/bit4woo/python_sec
# 18  https://github.com/code-review-checklists/java...
# 19      https://github.com/jiangsir404/Audit-Learning
#            Username Repository Name   Stars  \
# 0            vercel         next.js  131000
# 1         rust-lang            rust  102000
# 2          sveltejs          svelte   82000
# 3           webpack         webpack   65200
# 4          FuelLabs            sway   62400
# 5          gatsbyjs          gatsby   55800
# 6         JetBrains          kotlin   50300
# 7    parcel-bundler          parcel   43700
# 8             babel           babel   43500
# 9             evanw         esbuild   38800
# 10            typst           typst   38700
# 11          ziglang             zig   38300
# 12            vlang               v   36200
# 13         markedjs          marked   34300
# 14  carbon-language     carbon-lang   32800
# 15      swc-project             swc   32000
# 16           vercel             pkg   24400
# 17               v8              v8   23900
# 18           oracle           graal   20700
# 19       RustPython      RustPython   19800
#
#                                     Repository URL
# 0                https://github.com/vercel/next.js
# 1                https://github.com/rust-lang/rust
# 2               https://github.com/sveltejs/svelte
# 3               https://github.com/webpack/webpack
# 4                 https://github.com/FuelLabs/sway
# 5               https://github.com/gatsbyjs/gatsby
# 6              https://github.com/JetBrains/kotlin
# 7         https://github.com/parcel-bundler/parcel
# 8                   https://github.com/babel/babel
# 9                 https://github.com/evanw/esbuild
# 10                  https://github.com/typst/typst
# 11                  https://github.com/ziglang/zig
# 12                      https://github.com/vlang/v
# 13              https://github.com/markedjs/marked
# 14  https://github.com/carbon-language/carbon-lang
# 15              https://github.com/swc-project/swc
# 16                   https://github.com/vercel/pkg
# 17                        https://github.com/v8/v8
# 18                 https://github.com/oracle/graal
# 19        https://github.com/RustPython/RustPython
#          Username             Repository Name  Stars  \
# 0      localstack                  localstack  58300
# 1         harness                     harness  32600
# 2       jenkinsci                     jenkins  23800
# 3          milanm              DevOps-Roadmap  15400
# 4      auchenberg                  volkswagen  15000
# 5          dagger                      dagger  13400
# 6       openshift                      origin   8500
# 7       concourse                   concourse   7500
# 8            gocd                        gocd   7200
# 9       Flagsmith                   flagsmith   5500
# 10       buildbot                    buildbot   5300
# 11  gaia-pipeline                        gaia   5200
# 12    TheLartians            ModernCppStarter   4700
# 13            ovh                         cds   4700
# 14      jenkins-x                          jx   4600
# 15     Strider-CD                     strider   4600
# 16      JamesIves  github-pages-deploy-action   4400
# 17           werf                        werf   4400
# 18    SamKirkland           FTP-Deploy-Action   4200
# 19      iterative                         cml   4100
#
#                                        Repository URL
# 0            https://github.com/localstack/localstack
# 1                  https://github.com/harness/harness
# 2                https://github.com/jenkinsci/jenkins
# 3            https://github.com/milanm/DevOps-Roadmap
# 4            https://github.com/auchenberg/volkswagen
# 5                    https://github.com/dagger/dagger
# 6                 https://github.com/openshift/origin
# 7              https://github.com/concourse/concourse
# 8                        https://github.com/gocd/gocd
# 9              https://github.com/Flagsmith/flagsmith
# 10               https://github.com/buildbot/buildbot
# 11              https://github.com/gaia-pipeline/gaia
# 12    https://github.com/TheLartians/ModernCppStarter
# 13                         https://github.com/ovh/cds
# 14                    https://github.com/jenkins-x/jx
# 15              https://github.com/Strider-CD/strider
# 16  https://github.com/JamesIves/github-pages-depl...
# 17                       https://github.com/werf/werf
# 18   https://github.com/SamKirkland/FTP-Deploy-Action
# 19                   https://github.com/iterative/cml
#                         Username         Repository Name   Stars  \
# 0            practical-tutorials  project-based-learning  223000
# 1                        CyC2018                CS-Notes  180000
# 2                        fffaraz             awesome-cpp   62700
# 3                   azl397985856                leetcode   55200
# 4                youngyangyang04         leetcode-master   55100
# 5                        WerWolv                   ImHex   47600
# 6                     Light-City         CPlusPlusThings   40700
# 7                     ClickHouse              ClickHouse   39800
# 8                         huihut               interview   35800
# 9                          doocs                leetcode   33500
# 10               carbon-language             carbon-lang   32800
# 11  CMU-Perceptual-Computing-Lab                openpose   32200
# 12                 TheAlgorithms             C-Plus-Plus   31500
# 13                      aseprite                aseprite   31400
# 14                     microsoft              calculator   30200
# 15                   dragonflydb               dragonfly   27600
# 16                        gabime                  spdlog   25700
# 17                      changkun     modern-cpp-tutorial   24600
# 18                     microsoft                   vcpkg   24400
# 19                      ethereum                solidity   24200
#
#                                        Repository URL
# 0   https://github.com/practical-tutorials/project...
# 1                 https://github.com/CyC2018/CS-Notes
# 2              https://github.com/fffaraz/awesome-cpp
# 3            https://github.com/azl397985856/leetcode
# 4   https://github.com/youngyangyang04/leetcode-ma...
# 5                    https://github.com/WerWolv/ImHex
# 6       https://github.com/Light-City/CPlusPlusThings
# 7            https://github.com/ClickHouse/ClickHouse
# 8                 https://github.com/huihut/interview
# 9                   https://github.com/doocs/leetcode
# 10     https://github.com/carbon-language/carbon-lang
# 11  https://github.com/CMU-Perceptual-Computing-La...
# 12       https://github.com/TheAlgorithms/C-Plus-Plus
# 13               https://github.com/aseprite/aseprite
# 14            https://github.com/microsoft/calculator
# 15           https://github.com/dragonflydb/dragonfly
# 16                   https://github.com/gabime/spdlog
# 17    https://github.com/changkun/modern-cpp-tutorial
# 18                 https://github.com/microsoft/vcpkg
# 19               https://github.com/ethereum/solidity
#             Username             Repository Name  Stars  \
# 0            bitcoin                     bitcoin  82700
# 1          freqtrade                   freqtrade  37600
# 2               ccxt                        ccxt  35300
# 3           dogecoin                    dogecoin  14900
# 4         hummingbot                  hummingbot  12100
# 5     monero-project                      monero   9300
# 6              xmrig                       xmrig   9100
# 7                dvf                  blockchain   7900
# 8         StockSharp                  StockSharp   7900
# 9   lightningnetwork                         lnd   7900
# 10     kroma-network                     tachyon   7800
# 11            firmai  financial-machine-learning   7700
# 12            lbryio                    lbry-sdk   7200
# 13            cosmos                  cosmos-sdk   6500
# 14        sammchardy              python-binance   6500
# 15          jesse-ai                       jesse   6200
# 16        tendermint                  tendermint   5800
# 17        chrisleekr         binance-trading-bot   5300
# 18      sea-protocol                 seaprotocol   5100
# 19      mimblewimble                        grin   5100
#
#                                        Repository URL
# 0                  https://github.com/bitcoin/bitcoin
# 1              https://github.com/freqtrade/freqtrade
# 2                        https://github.com/ccxt/ccxt
# 3                https://github.com/dogecoin/dogecoin
# 4            https://github.com/hummingbot/hummingbot
# 5            https://github.com/monero-project/monero
# 6                      https://github.com/xmrig/xmrig
# 7                   https://github.com/dvf/blockchain
# 8            https://github.com/StockSharp/StockSharp
# 9             https://github.com/lightningnetwork/lnd
# 10           https://github.com/kroma-network/tachyon
# 11  https://github.com/firmai/financial-machine-le...
# 12                 https://github.com/lbryio/lbry-sdk
# 13               https://github.com/cosmos/cosmos-sdk
# 14       https://github.com/sammchardy/python-binance
# 15                  https://github.com/jesse-ai/jesse
# 16           https://github.com/tendermint/tendermint
# 17  https://github.com/chrisleekr/binance-trading-bot
# 18        https://github.com/sea-protocol/seaprotocol
# 19               https://github.com/mimblewimble/grin
#               Username                  Repository Name  Stars  \
# 0         crystal-lang                          crystal  19700
# 1              kemalcr                            kemal   3700
# 2             veelenga                  awesome-crystal   3400
# 3       luckyframework                            lucky   2600
# 4       amberframework                            amber   2600
# 5            vitobotta                      hetzner-k3s   2300
# 6             getmango                            Mango   1800
# 7                ffwff                           lilith   1200
# 8            drujensen                              fib    887
# 9           hanabi1224  Programming-Language-Benchmarks    705
# 10          owasp-noir                             noir    677
# 11  amethyst-framework                         amethyst    646
# 12                askn               crystal-by-example    555
# 13       crystal-ameba                            ameba    527
# 14   crystal-community                              icr    505
# 15             elbywan                      crystalline    467
# 16                will                       crystal-pg    466
# 17     martenframework                           marten    434
# 18            imdrasil                      jennifer.cr    422
# 19         vim-crystal                      vim-crystal    422
#
#                                        Repository URL
# 0             https://github.com/crystal-lang/crystal
# 1                    https://github.com/kemalcr/kemal
# 2         https://github.com/veelenga/awesome-crystal
# 3             https://github.com/luckyframework/lucky
# 4             https://github.com/amberframework/amber
# 5            https://github.com/vitobotta/hetzner-k3s
# 6                   https://github.com/getmango/Mango
# 7                     https://github.com/ffwff/lilith
# 8                    https://github.com/drujensen/fib
# 9   https://github.com/hanabi1224/Programming-Lang...
# 10                 https://github.com/owasp-noir/noir
# 11     https://github.com/amethyst-framework/amethyst
# 12         https://github.com/askn/crystal-by-example
# 13             https://github.com/crystal-ameba/ameba
# 14           https://github.com/crystal-community/icr
# 15             https://github.com/elbywan/crystalline
# 16                 https://github.com/will/crystal-pg
# 17          https://github.com/martenframework/marten
# 18            https://github.com/imdrasil/jennifer.cr
# 19         https://github.com/vim-crystal/vim-crystal

# %% [markdown]
# **For each topic, create a CSV of the top repos for the topic**

# %%
import pandas as pd
from urllib.parse import quote

# List of topic names (these can be read from a file or defined manually)
topic_titles = [
    '3D', 'Ajax', 'Algorithm', 'Amp', 'Android', 'Angular', 'Ansible', 'API', 'Arduino',
    'ASP.NET', 'Awesome Lists', 'Amazon Web Services', 'Azure', 'Babel', 'Bash', 'Bitcoin',
    'Bootstrap', 'Bot', 'C', 'Chrome', 'Chrome extension', 'Command-line interface', 'Clojure',
    'Code quality', 'Code review', 'Compiler', 'Continuous integration', 'C++', 'Cryptocurrency', 'Crystal'
]


from urllib.parse import quote

# Dynamically generate URLs from topic titles
urls = [f'https://github.com/topics/{quote(topic.lower().replace(" ", "-"))}' for topic in topic_titles]

# Now, you can loop through the URLs and topics
for url, topic in zip(urls, topic_titles):
    print(f"Fetching data for topic: {topic} from URL: {url}")

    # Fetch and process the repositories (replace with your actual fetching code)
    try:
        page_content = get_topic_page(url)  # Replace with your actual method
        repo_info = get_topic_repos(page_content)  # Replace with your actual method

        if repo_info:
            # Create DataFrame and save to CSV
            df = pd.DataFrame(repo_info)
            df['Topic'] = topic
            filename = f"{topic.replace(' ', '_').replace('/', '_')}_repos.csv"
            df.to_csv(filename, index=False)
            print(f"Saved data for {topic} to {filename}")
        else:
            print(f"No data available for {topic} at {url}")
    except Exception as e:
        print(f"Failed to load page for {topic} at {url}: {e}")
# Out:
# Fetching data for topic: 3D from URL: https://github.com/topics/3d
# Saved data for 3D to 3D_repos.csv
# Fetching data for topic: Ajax from URL: https://github.com/topics/ajax
# Saved data for Ajax to Ajax_repos.csv
# Fetching data for topic: Algorithm from URL: https://github.com/topics/algorithm
# Saved data for Algorithm to Algorithm_repos.csv
# Fetching data for topic: Amp from URL: https://github.com/topics/amp
# Saved data for Amp to Amp_repos.csv
# Fetching data for topic: Android from URL: https://github.com/topics/android
# Saved data for Android to Android_repos.csv
# Fetching data for topic: Angular from URL: https://github.com/topics/angular
# Saved data for Angular to Angular_repos.csv
# Fetching data for topic: Ansible from URL: https://github.com/topics/ansible
# Saved data for Ansible to Ansible_repos.csv
# Fetching data for topic: API from URL: https://github.com/topics/api
# Saved data for API to API_repos.csv
# Fetching data for topic: Arduino from URL: https://github.com/topics/arduino
# Saved data for Arduino to Arduino_repos.csv
# Fetching data for topic: ASP.NET from URL: https://github.com/topics/asp.net
# Saved data for ASP.NET to ASP.NET_repos.csv
# Fetching data for topic: Awesome Lists from URL: https://github.com/topics/awesome-lists
# Saved data for Awesome Lists to Awesome_Lists_repos.csv
# Fetching data for topic: Amazon Web Services from URL: https://github.com/topics/amazon-web-services
# Saved data for Amazon Web Services to Amazon_Web_Services_repos.csv
# Fetching data for topic: Azure from URL: https://github.com/topics/azure
# Saved data for Azure to Azure_repos.csv
# Fetching data for topic: Babel from URL: https://github.com/topics/babel
# Saved data for Babel to Babel_repos.csv
# Fetching data for topic: Bash from URL: https://github.com/topics/bash
# Saved data for Bash to Bash_repos.csv
# Fetching data for topic: Bitcoin from URL: https://github.com/topics/bitcoin
# Saved data for Bitcoin to Bitcoin_repos.csv
# Fetching data for topic: Bootstrap from URL: https://github.com/topics/bootstrap
# Saved data for Bootstrap to Bootstrap_repos.csv
# Fetching data for topic: Bot from URL: https://github.com/topics/bot
# Saved data for Bot to Bot_repos.csv
# Fetching data for topic: C from URL: https://github.com/topics/c
# Saved data for C to C_repos.csv
# Fetching data for topic: Chrome from URL: https://github.com/topics/chrome
# Saved data for Chrome to Chrome_repos.csv
# Fetching data for topic: Chrome extension from URL: https://github.com/topics/chrome-extension
# Saved data for Chrome extension to Chrome_extension_repos.csv
# Fetching data for topic: Command-line interface from URL: https://github.com/topics/command-line-interface
# Saved data for Command-line interface to Command-line_interface_repos.csv
# Fetching data for topic: Clojure from URL: https://github.com/topics/clojure
# Saved data for Clojure to Clojure_repos.csv
# Fetching data for topic: Code quality from URL: https://github.com/topics/code-quality
# Saved data for Code quality to Code_quality_repos.csv
# Fetching data for topic: Code review from URL: https://github.com/topics/code-review
# Saved data for Code review to Code_review_repos.csv
# Fetching data for topic: Compiler from URL: https://github.com/topics/compiler
# Saved data for Compiler to Compiler_repos.csv
# Fetching data for topic: Continuous integration from URL: https://github.com/topics/continuous-integration
# Saved data for Continuous integration to Continuous_integration_repos.csv
# Fetching data for topic: C++ from URL: https://github.com/topics/c%2B%2B
# Failed to load page for C++ at https://github.com/topics/c%2B%2B: Failed to load page https://github.com/topics/c%2B%2B
# Fetching data for topic: Cryptocurrency from URL: https://github.com/topics/cryptocurrency
# Saved data for Cryptocurrency to Cryptocurrency_repos.csv
# Fetching data for topic: Crystal from URL: https://github.com/topics/crystal
# Saved data for Crystal to Crystal_repos.csv

# %% [markdown]
# **Key Note**
#
# - Our data has a shape (30, 20, 4), this means:
# -  30 URLs (30 topics)
# - Each URL gives 20 repositories
# - Each repository contains 4 attributes (username, repository name, star count, and a link)
